# %%
from pyomo.environ import ConcreteModel, SolverFactory
                           
from idaes.core import FlowsheetBlock
                           
from idaes.generic_models.properties.core.generic.generic_property import (
        GenericParameterBlock)
                           
from R32_pf6_k import configuration

from idaes.generic_models.unit_models import Flash

from idaes.core.util.model_statistics import degrees_of_freedom

import idaes.logger as idaeslog

# Import plotting functions
import matplotlib.pyplot as plt

# Import numpy library 
import numpy as np

# %%
m = ConcreteModel()

m.fs = FlowsheetBlock(default={"dynamic": False})

m.fs.properties = GenericParameterBlock(default=configuration)

m.fs.F101 = Flash(default={"property_package": m.fs.properties,
                           "has_heat_transfer": False,
                           "has_pressure_change": False})
# Out:
# 2021-07-19 14:06:20 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.

# %%
DOF_initial = degrees_of_freedom(m)
print("The initial DOF is {0}".format(DOF_initial))
# Out:
# The initial DOF is 5

# %%
m.fs.F101.inlet.flow_mol.fix(1)
m.fs.F101.inlet.temperature.fix(298)
m.fs.F101.inlet.pressure.fix(100000)

m.fs.F101.inlet.mole_frac_comp[0, "R32"].fix(0.4)
m.fs.F101.inlet.mole_frac_comp[0, "bmimPF6"].fix(0.6)
# m.fs.F101.vap_outlet.pressure.fix(399800)

# m.fs.F101.vap_outlet.temperature.fix(286)

# %%
degrees_of_freedom(m.fs.F101)
# Out:
# 0

# %%
# Initialize the flash unit
m.fs.F101.initialize()
# Out:
# 2021-07-19 14:06:20 [INFO] idaes.init.fs.F101.control_volume.properties_in: Starting initialization
# 2021-07-19 14:06:21 [INFO] idaes.init.fs.F101.control_volume.properties_in: Dew and bubble point initialization: optimal - Optimal Solution Found.
# 2021-07-19 14:06:21 [INFO] idaes.init.fs.F101.control_volume.properties_in: Equilibrium temperature initialization completed.
# 2021-07-19 14:06:21 [INFO] idaes.init.fs.F101.control_volume.properties_in: Phase equilibrium initialization: optimal - Optimal Solution Found.
# 2021-07-19 14:06:21 [INFO] idaes.init.fs.F101.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2021-07-19 14:06:21 [INFO] idaes.init.fs.F101.control_volume.properties_out: Starting initialization
# 2021-07-19 14:06:21 [INFO] idaes.init.fs.F101.control_volume.properties_out: Dew and bubble point initialization: optimal - Optimal Solution Found.
# 2021-07-19 14:06:21 [INFO] idaes.init.fs.F101.control_volume.properties_out: Equilibrium temperature initialization completed.
# 2021-07-19 14:06:22 [INFO] idaes.init.fs.F101.control_volume.properties_out: Phase equilibrium initialization: optimal - Optimal Solution Found.
# 2021-07-19 14:06:22 [INFO] idaes.init.fs.F101.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2021-07-19 14:06:22 [INFO] idaes.init.fs.F101.control_volume: Initialization Complete
# 2021-07-19 14:06:22 [INFO] idaes.init.fs.F101: Initialization Complete: optimal - Optimal Solution Found

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6}

# %%
status = solver.solve(m, tee = False)

# %%
m.fs.F101.report()
# Out:
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                               Inlet    Vapor Outlet  Liquid Outlet
#     flow_mol                   1.0000      0.36136       0.63864
#     mole_frac_comp bmimPF6    0.60000   1.0000e-08       0.93950
#     mole_frac_comp R32        0.40000       1.0000      0.060501
#     temperature                298.00       298.00        298.00
#     pressure               1.0000e+05   1.0000e+05    1.0000e+05
# ====================================================================================

# %%
m.display()
# Out:
# Model unknown
#
#   Variables:
#     None
#
#   Objectives:
#     None
#
#   Constraints:
#     None
#
#   Blocks:
#     Block fs
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         None
#
#       Blocks:
#         Block fs.properties
#
#           Variables:
#             PR_kappa_A : PRA binary interaction parameters
#                 Size=4, Index=fs.properties.PR_kappa_A_index
#                 Key                    : Lower : Value : Upper : Fixed : Stale : Domain
#                         ('R32', 'R32') :  None :   0.0 :  None :  True :  True :  Reals
#                     ('R32', 'bmimPF6') :  None :   0.0 :  None :  True :  True :  Reals
#                     ('bmimPF6', 'R32') :  None :   0.0 :  None :  True :  True :  Reals
#                 ('bmimPF6', 'bmimPF6') :  None :   0.0 :  None :  True :  True :  Reals
#             PR_kappa_B : PRB binary interaction parameters
#                 Size=4, Index=fs.properties.PR_kappa_B_index
#                 Key                    : Lower : Value : Upper : Fixed : Stale : Domain
#                         ('R32', 'R32') :  None :   0.0 :  None :  True :  True :  Reals
#                     ('R32', 'bmimPF6') :  None :   0.0 :  None :  True :  True :  Reals
#                     ('bmimPF6', 'R32') :  None :   0.0 :  None :  True :  True :  Reals
#                 ('bmimPF6', 'bmimPF6') :  None :   0.0 :  None :  True :  True :  Reals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#
#           Blocks:
#             Block fs.properties.Liq
#
#               Variables:
#                 None
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.Vap
#
#               Variables:
#                 None
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.bmimPF6
#
#               Variables:
#                 pressure_crit : Size=1, Index=None, Units=kg/m/s**2
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 2400000.0 :  None :  True :  True :  Reals
#                 temperature_crit : Size=1, Index=None, Units=K
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None :   860 :  None :  True :  True :  Reals
#                 omega : Size=1, Index=None
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : 0.7917 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_A : Parameter A for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K/mol
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 3259.5745 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_B : Parameter B for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**2/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : -28.561 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_C : Parameter C for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**3/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 0.09354 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_D : Parameter D for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**4/mol
#                     Key  : Lower : Value         : Upper : Fixed : Stale : Domain
#                     None :  None : -0.0001000673 :  None :  True :  True :  Reals
#                 enth_mol_form_vap_comp_ref : Vapor phase molar heat of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/mol/s**2
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 0.145 :  None :  True :  True :  Reals
#                 entr_mol_form_vap_comp_ref : Vapor phase molar entropy of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/K/mol/s**2
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 137.5 :  None :  True :  True :  Reals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.R32
#
#               Variables:
#                 pressure_crit : Size=1, Index=None, Units=kg/m/s**2
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 5785000.0 :  None :  True :  True :  Reals
#                 temperature_crit : Size=1, Index=None, Units=K
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 351.3 :  None :  True :  True :  Reals
#                 omega : Size=1, Index=None
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 0.277 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_A : Parameter A for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K/mol
#                     Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                     None :  None : 4785.106 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_B : Parameter B for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**2/mol
#                     Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                     None :  None : -68.0944 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_C : Parameter C for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**3/mol
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : 0.3278 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_D : Parameter D for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**4/mol
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : -0.000524 :  None :  True :  True :  Reals
#                 enth_mol_form_vap_comp_ref : Vapor phase molar heat of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/mol/s**2
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 21200.0 :  None :  True :  True :  Reals
#                 entr_mol_form_vap_comp_ref : Vapor phase molar entropy of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/K/mol/s**2
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : -269.0 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_A : Antoine A coefficient for calculating Psat
#                     Size=1, Index=None
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 4.26224 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_B : Antoine B coefficient for calculating Psat
#                     Size=1, Index=None, Units=K
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 821.092 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_C : Antoine C coefficient for calculating Psat
#                     Size=1, Index=None, Units=K
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : -28.554 :  None :  True :  True :  Reals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#         Block fs.F101
#
#           Variables:
#             _flow_mol_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  1000 :  True :  True : NonNegativeReals
#             _mole_frac_comp_inlet_ref : Size=2, Index=fs.F101._mole_frac_comp_inlet_ref_index
#                 Key              : Lower : Value : Upper : Fixed : Stale : Domain
#                     (0.0, 'R32') :     0 :   0.4 :  None :  True :  True :  Reals
#                 (0.0, 'bmimPF6') :     0 :   0.6 :  None :  True :  True :  Reals
#             _temperature_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :    10 :   298 :   500 :  True :  True : NonNegativeReals
#             _pressure_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower  : Value  : Upper         : Fixed : Stale : Domain
#                 0.0 : 0.0005 : 100000 : 10000000000.0 :  True :  True : NonNegativeReals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#
#           Blocks:
#             Block fs.F101.control_volume
#
#               Variables:
#                 None
#
#               Objectives:
#                 None
#
#               Constraints:
#                 material_balances : Size=2
#                     Key              : Lower : Body                  : Upper
#                         (0.0, 'R32') :   0.0 : 5.551115123125783e-17 :   0.0
#                     (0.0, 'bmimPF6') :   0.0 :                   0.0 :   0.0
#                 enthalpy_balances : Size=1
#                     Key : Lower : Body                  : Upper
#                     0.0 :   0.0 : 3.766035661101341e-08 :   0.0
#                 pressure_balance : Size=1
#                     Key : Lower : Body : Upper
#                     0.0 :   0.0 :  0.0 :   0.0
#
#               Blocks:
#                 Block fs.F101.control_volume.properties_in[0.0]
#
#                   Variables:
#                     flow_mol :  Total molar flowrate
#                         Size=1, Index=None, Units=mol/s
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :     0 :     1 :  1000 :  True :  True : NonNegativeReals
#                     mole_frac_comp : Mixture mole fractions
#                         Size=2, Index=fs.properties.component_list
#                         Key     : Lower : Value : Upper : Fixed : Stale : Domain
#                             R32 :     0 :   0.4 :  None :  True :  True :  Reals
#                         bmimPF6 :     0 :   0.6 :  None :  True :  True :  Reals
#                     pressure : State pressure
#                         Size=1, Index=None, Units=kg/m/s**2
#                         Key  : Lower  : Value  : Upper         : Fixed : Stale : Domain
#                         None : 0.0005 : 100000 : 10000000000.0 :  True :  True : NonNegativeReals
#                     temperature : State temperature
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :    10 :   298 :   500 :  True :  True : NonNegativeReals
#                     flow_mol_phase : Phase molar flow rates
#                         Size=2, Index=fs.properties.phase_list, Units=mol/s
#                         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                         Liq :     0 : 0.6386379578928113 :  1000 : False : False : NonNegativeReals
#                         Vap :     0 : 0.3613620421071887 :  1000 : False : False : NonNegativeReals
#                     mole_frac_phase_comp : Phase mole fractions
#                         Size=3, Index=fs.properties._phase_component_set
#                         Key                : Lower : Value               : Upper : Fixed : Stale : Domain
#                             ('Liq', 'R32') :     0 : 0.06050056595492294 :  None : False : False :  Reals
#                         ('Liq', 'bmimPF6') :     0 :  0.9394994340450771 :  None : False : False :  Reals
#                             ('Vap', 'R32') :     0 :                 1.0 :  None : False : False :  Reals
#                     phase_frac : Phase fractions
#                         Size=2, Index=fs.properties.phase_list
#                         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                         Liq :     0 : 0.6386379578928113 :  None : False : False :  Reals
#                         Vap :     0 : 0.3613620421071887 :  None : False : False :  Reals
#                     _teq : Temperature for calculating phase equilibrium
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :  None : 298.0000003227533 :  None : False : False :  Reals
#                     _t1_Vap_Liq : Intermediate temperature for calculating Teq
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#                         None :  None : 298.0000003227533 :  None : False : False :  Reals
#                     temperature_bubble : Bubble point temperature
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value              : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :    10 : 220.54144041963306 :   500 : False : False :  Reals
#                     _mole_frac_tbub : Vapor mole fractions at bubble temperature
#                         Size=2, Index=fs.F101.control_volume.properties_in[0.0]._mole_frac_tbub_index
#                         Key                       : Lower : Value                 : Upper : Fixed : Stale : Domain
#                             ('Vap', 'Liq', 'R32') :     0 :                   1.0 :  None : False : False :  Reals
#                         ('Vap', 'Liq', 'bmimPF6') :     0 : 9.900000000000295e-07 :  None : False : False :  Reals
#
#                   Objectives:
#                     None
#
#                   Constraints:
#                     total_flow_balance : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     component_flow_balances : Size=2
#                         Key     : Lower : Body : Upper
#                             R32 :   0.0 :  0.0 :   0.0
#                         bmimPF6 :   0.0 :  0.0 :   0.0
#                     sum_mole_frac : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     phase_fraction_constraint : Size=2
#                         Key : Lower : Body : Upper
#                         Liq :   0.0 :  0.0 :   0.0
#                         Vap :   0.0 :  0.0 :   0.0
#                     _t1_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body                  : Upper
#                         None :   0.0 : 5.684341886080802e-14 :   0.0
#                     eq_temperature_bubble : Size=2
#                         Key                       : Lower : Body                   : Upper
#                             ('Vap', 'Liq', 'R32') :   0.0 : -9.062172155634152e-07 :   0.0
#                         ('Vap', 'Liq', 'bmimPF6') :   0.0 :  9.900000000000295e-07 :   0.0
#                     eq_mole_frac_tbub : Size=1
#                         Key            : Lower : Body : Upper
#                         ('Vap', 'Liq') :   1.0 :  1.0 :   1.0
#                     _teq_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     equilibrium_constraint : Size=1
#                         Key                   : Lower : Body                   : Upper
#                         ('Vap', 'Liq', 'R32') :   0.0 : 1.3898986128690893e-12 :   0.0
#                 Block fs.F101.control_volume.properties_out[0.0]
#
#                   Variables:
#                     flow_mol :  Total molar flowrate
#                         Size=1, Index=None, Units=mol/s
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :     0 :   1.0 :  1000 : False : False : NonNegativeReals
#                     mole_frac_comp : Mixture mole fractions
#                         Size=2, Index=fs.properties.component_list
#                         Key     : Lower : Value : Upper : Fixed : Stale : Domain
#                             R32 :     0 :   0.4 :  None : False : False :  Reals
#                         bmimPF6 :     0 :   0.6 :  None : False : False :  Reals
#                     pressure : State pressure
#                         Size=1, Index=None, Units=kg/m/s**2
#                         Key  : Lower  : Value    : Upper         : Fixed : Stale : Domain
#                         None : 0.0005 : 100000.0 : 10000000000.0 : False : False : NonNegativeReals
#                     temperature : State temperature
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value              : Upper : Fixed : Stale : Domain
#                         None :    10 : 297.99999999991894 :   500 : False : False : NonNegativeReals
#                     flow_mol_phase : Phase molar flow rates
#                         Size=2, Index=fs.properties.phase_list, Units=mol/s
#                         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                         Liq :     0 : 0.6386379578927702 :  1000 : False : False : NonNegativeReals
#                         Vap :     0 : 0.3613620421072298 :  1000 : False : False : NonNegativeReals
#                     mole_frac_phase_comp : Phase mole fractions
#                         Size=3, Index=fs.properties._phase_component_set
#                         Key                : Lower : Value               : Upper : Fixed : Stale : Domain
#                             ('Liq', 'R32') :     0 : 0.06050056595486247 :  None : False : False :  Reals
#                         ('Liq', 'bmimPF6') :     0 :  0.9394994340451375 :  None : False : False :  Reals
#                             ('Vap', 'R32') :     0 :  0.9999999999999999 :  None : False : False :  Reals
#                     phase_frac : Phase fractions
#                         Size=2, Index=fs.properties.phase_list
#                         Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                         Liq :     0 : 0.6386379578927702 :  None : False : False :  Reals
#                         Vap :     0 : 0.3613620421072298 :  None : False : False :  Reals
#                     _teq : Temperature for calculating phase equilibrium
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :  None : 298.0000003226722 :  None : False : False :  Reals
#                     _t1_Vap_Liq : Intermediate temperature for calculating Teq
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#                         None :  None : 298.0000003226722 :  None : False : False :  Reals
#                     temperature_bubble : Bubble point temperature
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value              : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :    10 : 220.54144041963306 :   500 : False : False :  Reals
#                     _mole_frac_tbub : Vapor mole fractions at bubble temperature
#                         Size=2, Index=fs.F101.control_volume.properties_out[0.0]._mole_frac_tbub_index
#                         Key                       : Lower : Value                 : Upper : Fixed : Stale : Domain
#                             ('Vap', 'Liq', 'R32') :     0 :                   1.0 :  None : False : False :  Reals
#                         ('Vap', 'Liq', 'bmimPF6') :     0 : 9.900000000000295e-07 :  None : False : False :  Reals
#
#                   Objectives:
#                     None
#
#                   Constraints:
#                     sum_mole_frac_out : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   1.0 :  1.0 :   1.0
#                     total_flow_balance : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     component_flow_balances : Size=2
#                         Key     : Lower : Body                  : Upper
#                             R32 :   0.0 : 5.551115123125783e-17 :   0.0
#                         bmimPF6 :   0.0 :                   0.0 :   0.0
#                     sum_mole_frac : Size=1
#                         Key  : Lower : Body                   : Upper
#                         None :   0.0 : 1.1102230246251565e-16 :   0.0
#                     phase_fraction_constraint : Size=2
#                         Key : Lower : Body : Upper
#                         Liq :   0.0 :  0.0 :   0.0
#                         Vap :   0.0 :  0.0 :   0.0
#                     _t1_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     eq_temperature_bubble : Size=2
#                         Key                       : Lower : Body                   : Upper
#                             ('Vap', 'Liq', 'R32') :   0.0 : -9.062172155634152e-07 :   0.0
#                         ('Vap', 'Liq', 'bmimPF6') :   0.0 :  9.900000000000295e-07 :   0.0
#                     eq_mole_frac_tbub : Size=1
#                         Key            : Lower : Body : Upper
#                         ('Vap', 'Liq') :   1.0 :  1.0 :   1.0
#                     _teq_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     equilibrium_constraint : Size=1
#                         Key                   : Lower : Body                   : Upper
#                         ('Vap', 'Liq', 'R32') :   0.0 : 5.5647500496469604e-12 :   0.0
#             Block fs.F101.split
#
#               Variables:
#                 _flow_mol_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                     0.0 :     0 :   1.0 :  1000 : False : False : NonNegativeReals
#                 _mole_frac_comp_inlet_ref : Size=2, Index=fs.F101.split._mole_frac_comp_inlet_ref_index
#                     Key              : Lower : Value : Upper : Fixed : Stale : Domain
#                         (0.0, 'R32') :     0 :   0.4 :  None : False : False :  Reals
#                     (0.0, 'bmimPF6') :     0 :   0.6 :  None : False : False :  Reals
#                 _temperature_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 297.99999999991894 :   500 : False : False : NonNegativeReals
#                 _pressure_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value    : Upper         : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 100000.0 : 10000000000.0 : False : False : NonNegativeReals
#                 _Vap_temperature_ref : Size=1, Index=fs._time
#                     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 297.99999999991894 :   500 : False : False : NonNegativeReals
#                 _Vap_pressure_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value    : Upper         : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 100000.0 : 10000000000.0 : False : False : NonNegativeReals
#                 _Liq_temperature_ref : Size=1, Index=fs._time
#                     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 297.99999999991894 :   500 : False : False : NonNegativeReals
#                 _Liq_pressure_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value    : Upper         : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 100000.0 : 10000000000.0 : False : False : NonNegativeReals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None

# %%
# m.pprint()
