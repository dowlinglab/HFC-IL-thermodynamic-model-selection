# %% [markdown]
# # Parameter Estimation Using NRTL
#
# Jaffer Version
#
# Fitting: R32/emimTF2N using composition objective

# %% [markdown]
# # Imports

# %%
# Todo: import ConcreteModel from pyomo.environ
from pyomo.environ import ConcreteModel, value

# Todo: import FlowsheetBlock from idaes.core
from idaes.core import FlowsheetBlock

# %%
from hfc32_emimtf2n_nrtl_VLE import HFCILParameterBlock
import idaes.logger as idaeslog

# %%
import pyomo.contrib.parmest.parmest as parmest
import pandas as pd
import numpy as np
from idaes.core.util.model_statistics import degrees_of_freedom

# %% [markdown]
# # Set Up Initialized Model

# %% [markdown]
# ### Grid Search

# %%
tau21 = np.linspace(-20,20,20)
tau12 = np.linspace(-20,20,20)

for i in range(len(tau21)):
    for j in range(len(tau12)):
        print("Trying tau21:",tau21[i])
        print("Trying tau12:",tau12[j])
        
        try:
            def NRTL_model(data):

                #Todo: Create a ConcreteModel object
                m = ConcreteModel()

                #Todo: Create FlowsheetBlock object
                m.fs = FlowsheetBlock(default={"dynamic": False})


                #Todo: Create a properties parameter object with the following options:
                # "valid_phase": ('Liq', 'Vap')
                # "activity_coeff_model": 'NRTL'
                m.fs.properties = HFCILParameterBlock(default={"valid_phase":
                                                             ('Liq', 'Vap'),
                                                             "activity_coeff_model":
                                                             'NRTL'})
                m.fs.state_block = m.fs.properties.state_block_class(
                    default={"parameters": m.fs.properties,
                             "defined_state": True})


                # Fix the state variables on the state block
                # hint: state variables exist on the state block i.e. on m.fs.state_block

                m.fs.state_block.flow_mol.fix(1)
                m.fs.state_block.temperature.fix(298)
                m.fs.state_block.pressure.fix(101325)
                m.fs.state_block.mole_frac_comp["R32"].fix(0.3)
                m.fs.state_block.mole_frac_comp["emimTf2N"].fix(0.7)

                # Fix NRTL specific parameters. 

                # non-randomness parameter - alpha_ij (set at 0.3, 0 if i=j)
                m.fs.properties.\
                    alpha["R32", "R32"].fix(0)
                m.fs.properties.\
                    alpha["R32", "emimTf2N"].fix(0.3)
                m.fs.properties.\
                    alpha["emimTf2N", "emimTf2N"].fix(0)
                m.fs.properties.\
                    alpha["emimTf2N", "R32"].fix(0.3)

                # binary interaction parameter - tau_ij (0 if i=j, else to be estimated later but fixing to initialize)
                m.fs.properties.\
                    tau["R32", "R32"].fix(0)
                m.fs.properties.\
                    tau["R32", "emimTf2N"].fix(tau12[j])
                m.fs.properties.\
                    tau["emimTf2N", "emimTf2N"].fix(0)
                m.fs.properties.\
                    tau["emimTf2N", "R32"].fix(tau21[i])

                # Initialize the flash unit
                print('Trying Init')
                m.fs.state_block.initialize(outlvl=idaeslog.INFO_HIGH)
                print('Finished Init')

                # Fix at actual temperature
                m.fs.state_block.temperature.fix(float(data["temperature"]))

                # Set bounds on variables to be estimated
                m.fs.properties.\
                    tau["R32", "emimTf2N"].setlb(-20)
                m.fs.properties.\
                    tau["R32", "emimTf2N"].setub(20)

                m.fs.properties.\
                    tau["emimTf2N", "R32"].setlb(-20)
                m.fs.properties.\
                    tau["emimTf2N", "R32"].setub(20)

                # Return initialized flash model
                return m
          
            # Testing the initialized model
            test_data = {"temperature": 298}

            m = NRTL_model(test_data)
            
            print(degrees_of_freedom(m))
            
            print('Worked')
            
        except:
            'Skip'
# Out:
# Trying tau21: -20.0
# Trying tau12: -20.0
# Trying Init
# 2022-08-01 15:32:06 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:32:09 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:11 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:14 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:16 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: -17.894736842105264
# Trying Init
# 2022-08-01 15:32:16 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:32:19 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:22 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:24 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:27 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: -15.789473684210527
# Trying Init
# 2022-08-01 15:32:27 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:32:30 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:32 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:35 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:37 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: -13.68421052631579
# Trying Init
# 2022-08-01 15:32:38 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:32:40 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:43 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:45 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:48 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: -11.578947368421053
# Trying Init
# 2022-08-01 15:32:48 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:32:51 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:54 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:56 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:32:56 [INFO] idaes.init.fs.state_block: Initialization Step 5 unbounded - Iterates diverging; problem might be unbounded..
# Trying tau21: -20.0
# Trying tau12: -9.473684210526317
# Trying Init
# 2022-08-01 15:32:56 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:32:59 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:02 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:04 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:07 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: -7.368421052631579
# Trying Init
# 2022-08-01 15:33:07 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:33:09 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:12 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: -5.2631578947368425
# Trying Init
# 2022-08-01 15:33:14 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:33:17 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:20 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:22 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:25 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: -3.157894736842106
# Trying Init
# 2022-08-01 15:33:25 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:33:28 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:31 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:34 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:36 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: -1.05263157894737
# Trying Init
# 2022-08-01 15:33:36 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:33:39 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:42 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:44 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:47 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 1.0526315789473664
# Trying Init
# 2022-08-01 15:33:47 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:33:49 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:52 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:55 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:33:57 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 3.1578947368421026
# Trying Init
# 2022-08-01 15:33:57 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:34:00 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:03 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:05 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:08 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 5.2631578947368425
# Trying Init
# 2022-08-01 15:34:08 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:34:11 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:13 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:16 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:19 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 7.368421052631579
# Trying Init
# 2022-08-01 15:34:19 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:34:22 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:25 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:27 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:30 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 9.473684210526315
# Trying Init
# 2022-08-01 15:34:30 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:34:33 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:35 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:38 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:40 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 11.578947368421051
# Trying Init
# 2022-08-01 15:34:40 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:34:43 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:46 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:49 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:52 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 13.684210526315788
# Trying Init
# Trying tau21: -20.0
# Trying tau12: 15.789473684210527
# Trying Init
# 2022-08-01 15:34:52 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:34:55 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:34:58 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:01 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:04 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 17.89473684210526
# Trying Init
# 2022-08-01 15:35:04 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:35:07 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:10 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:12 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:15 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -20.0
# Trying tau12: 20.0
# Trying Init
# 2022-08-01 15:35:15 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:35:17 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:20 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:23 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:26 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: -20.0
# Trying Init
# Trying tau21: -17.894736842105264
# Trying tau12: -17.894736842105264
# Trying Init
# Trying tau21: -17.894736842105264
# Trying tau12: -15.789473684210527
# Trying Init
# 2022-08-01 15:35:26 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:35:29 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:32 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:34 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:37 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: -13.68421052631579
# Trying Init
# 2022-08-01 15:35:37 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:35:40 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:42 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:45 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:47 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: -11.578947368421053
# Trying Init
# 2022-08-01 15:35:47 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:35:50 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:53 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:55 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:35:58 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: -9.473684210526317
# Trying Init
# 2022-08-01 15:35:58 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:36:01 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:04 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:07 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:09 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: -7.368421052631579
# Trying Init
# 2022-08-01 15:36:09 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:36:12 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:15 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:17 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:20 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: -5.2631578947368425
# Trying Init
# 2022-08-01 15:36:20 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:36:22 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:25 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:28 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:30 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: -3.157894736842106
# Trying Init
# 2022-08-01 15:36:30 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:36:33 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:36 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:38 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:41 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: -1.05263157894737
# Trying Init
# 2022-08-01 15:36:41 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:36:44 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:47 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:50 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:52 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 1.0526315789473664
# Trying Init
# 2022-08-01 15:36:53 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:36:56 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:36:58 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:01 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:03 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 3.1578947368421026
# Trying Init
# 2022-08-01 15:37:03 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:37:06 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:09 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:11 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:14 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 5.2631578947368425
# Trying Init
# Trying tau21: -17.894736842105264
# Trying tau12: 7.368421052631579
# Trying Init
# 2022-08-01 15:37:15 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:37:18 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:21 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:23 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:26 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 9.473684210526315
# Trying Init
# 2022-08-01 15:37:26 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:37:29 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:32 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:35 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:37 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 11.578947368421051
# Trying Init
# 2022-08-01 15:37:37 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:37:40 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:43 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:45 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:49 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 13.684210526315788
# Trying Init
# 2022-08-01 15:37:49 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:37:53 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:56 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:37:58 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:01 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 15.789473684210527
# Trying Init
# 2022-08-01 15:38:01 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:38:04 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:06 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:09 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:11 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 17.89473684210526
# Trying Init
# 2022-08-01 15:38:11 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:38:14 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:17 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:20 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:22 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -17.894736842105264
# Trying tau12: 20.0
# Trying Init
# 2022-08-01 15:38:22 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:38:25 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:28 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:30 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:33 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -20.0
# Trying Init
# 2022-08-01 15:38:34 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:38:36 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:39 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:42 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:45 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -17.894736842105264
# Trying Init
# 2022-08-01 15:38:45 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:38:47 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:50 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:53 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:38:55 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -15.789473684210527
# Trying Init
# 2022-08-01 15:38:55 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:38:58 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:00 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:03 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:05 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -13.68421052631579
# Trying Init
# 2022-08-01 15:39:05 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:39:08 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:11 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:13 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:13 [INFO] idaes.init.fs.state_block: Initialization Step 5 unbounded - Iterates diverging; problem might be unbounded..
# Trying tau21: -15.789473684210527
# Trying tau12: -11.578947368421053
# Trying Init
# 2022-08-01 15:39:14 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:39:16 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:19 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:21 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:24 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -9.473684210526317
# Trying Init
# 2022-08-01 15:39:24 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:39:27 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:29 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:32 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:34 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -7.368421052631579
# Trying Init
# 2022-08-01 15:39:34 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:39:37 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:40 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:43 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:45 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -5.2631578947368425
# Trying Init
# 2022-08-01 15:39:45 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:39:48 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:51 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:53 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:39:56 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -3.157894736842106
# Trying Init
# 2022-08-01 15:39:56 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:39:58 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:01 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:03 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:06 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: -1.05263157894737
# Trying Init
# 2022-08-01 15:40:06 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:40:08 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:11 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:13 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:16 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 1.0526315789473664
# Trying Init
# 2022-08-01 15:40:16 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:40:18 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:21 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:23 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:26 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 3.1578947368421026
# Trying Init
# 2022-08-01 15:40:26 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:40:28 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:31 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:33 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:35 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 5.2631578947368425
# Trying Init
# 2022-08-01 15:40:35 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:40:38 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:40 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:43 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:45 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 7.368421052631579
# Trying Init
# 2022-08-01 15:40:45 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:40:47 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:50 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:53 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:40:55 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 9.473684210526315
# Trying Init
# 2022-08-01 15:40:55 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:40:57 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:00 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:02 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:05 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 11.578947368421051
# Trying Init
# 2022-08-01 15:41:05 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:41:07 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:10 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:12 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:15 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 13.684210526315788
# Trying Init
# 2022-08-01 15:41:15 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:41:17 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:19 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:22 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:24 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 15.789473684210527
# Trying Init
# 2022-08-01 15:41:24 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:41:27 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:29 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:32 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:34 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 17.89473684210526
# Trying Init
# 2022-08-01 15:41:34 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:41:36 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:39 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:41 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:44 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -15.789473684210527
# Trying tau12: 20.0
# Trying Init
# 2022-08-01 15:41:44 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:41:46 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:48 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:51 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:53 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -20.0
# Trying Init
# 2022-08-01 15:41:53 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:41:56 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:41:58 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:01 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:03 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -17.894736842105264
# Trying Init
# 2022-08-01 15:42:03 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:42:06 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:08 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:11 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:13 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -15.789473684210527
# Trying Init
# 2022-08-01 15:42:13 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:42:16 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:18 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:21 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:23 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -13.68421052631579
# Trying Init
# 2022-08-01 15:42:23 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:42:26 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:28 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:30 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:33 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -11.578947368421053
# Trying Init
# 2022-08-01 15:42:33 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:42:35 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:38 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:40 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:42 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -9.473684210526317
# Trying Init
# 2022-08-01 15:42:42 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:42:45 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:47 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:50 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:52 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -7.368421052631579
# Trying Init
# 2022-08-01 15:42:52 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:42:55 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:42:57 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:43:00 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:43:02 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -5.2631578947368425
# Trying Init
# 2022-08-01 15:43:02 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:43:05 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:43:07 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:43:10 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:43:12 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -13.68421052631579
# Trying tau12: -3.157894736842106
# Trying Init
# 2022-08-01 15:43:12 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:43:15 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:43:17 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:43:20 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# ...
# 2022-08-01 15:47:35 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:47:37 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -11.578947368421053
# Trying tau12: 11.578947368421051
# Trying Init
# 2022-08-01 15:47:38 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:47:40 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:47:42 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:47:45 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:47:47 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -11.578947368421053
# Trying tau12: 13.684210526315788
# Trying Init
# 2022-08-01 15:47:47 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:47:50 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:47:52 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:47:55 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:47:57 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -11.578947368421053
# Trying tau12: 15.789473684210527
# Trying Init
# 2022-08-01 15:47:57 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:48:00 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:02 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:05 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:07 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -11.578947368421053
# Trying tau12: 17.89473684210526
# Trying Init
# 2022-08-01 15:48:07 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:48:10 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:12 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:14 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:17 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -11.578947368421053
# Trying tau12: 20.0
# Trying Init
# 2022-08-01 15:48:17 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:48:19 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:22 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:24 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:27 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -20.0
# Trying Init
# 2022-08-01 15:48:27 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:48:29 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:32 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:34 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:36 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -17.894736842105264
# Trying Init
# 2022-08-01 15:48:37 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:48:39 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:41 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:44 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:46 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -15.789473684210527
# Trying Init
# 2022-08-01 15:48:47 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:48:49 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:51 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:54 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:48:56 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -13.68421052631579
# Trying Init
# 2022-08-01 15:48:57 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:48:59 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:02 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:04 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:07 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -11.578947368421053
# Trying Init
# 2022-08-01 15:49:07 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:49:09 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:12 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:14 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:17 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -9.473684210526317
# Trying Init
# 2022-08-01 15:49:17 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:49:19 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:22 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:24 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:26 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -7.368421052631579
# Trying Init
# 2022-08-01 15:49:27 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:49:29 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:31 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:34 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:38 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -5.2631578947368425
# Trying Init
# 2022-08-01 15:49:38 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:49:41 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:43 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:46 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:48 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -3.157894736842106
# Trying Init
# 2022-08-01 15:49:48 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:49:50 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:53 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:55 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:49:58 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: -1.05263157894737
# Trying Init
# 2022-08-01 15:49:58 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:50:00 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:02 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:05 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:07 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: 1.0526315789473664
# Trying Init
# 2022-08-01 15:50:07 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:50:10 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:12 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:15 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:17 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: 3.1578947368421026
# Trying Init
# 2022-08-01 15:50:17 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 15:50:19 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:22 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:24 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 15:50:27 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: 5.2631578947368425
# Trying Init
# 2022-08-01 15:50:27 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 16:15:38 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:15:40 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:15:43 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:15:45 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: 7.368421052631579
# Trying Init
# 2022-08-01 16:15:45 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 16:15:57 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:16:00 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:16:03 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:16:05 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: 9.473684210526315
# Trying Init
# 2022-08-01 16:16:05 [INFO] idaes.init.fs.state_block: Initialization Step 1 infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# Trying tau21: -9.473684210526317
# Trying tau12: 11.578947368421051
# Trying Init
# 2022-08-01 16:16:06 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 16:16:08 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:16:10 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:16:13 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:16:19 [INFO] idaes.init.fs.state_block: Initialization Step 5 maxIterations - Maximum Number of Iterations Exceeded..
# Trying tau21: -9.473684210526317
# Trying tau12: 13.684210526315788
# Trying Init
# 2022-08-01 16:16:19 [INFO] idaes.init.fs.state_block: Initialization Step 1 unbounded - Iterates diverging; problem might be unbounded..
# 2022-08-01 16:16:24 [INFO] idaes.init.fs.state_block: Initialization Step 2 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:16:27 [INFO] idaes.init.fs.state_block: Initialization Step 3 maxIterations - Maximum Number of Iterations Exceeded..
# 2022-08-01 16:16:30 [INFO] idaes.init.fs.state_block: Initialization Step 4 maxIterations - Maximum Number of Iterations Exceeded..

# %%
def NRTL_model(data):
    
    #Todo: Create a ConcreteModel object
    m = ConcreteModel()
    
    #Todo: Create FlowsheetBlock object
    m.fs = FlowsheetBlock(default={"dynamic": False})
    

    #Todo: Create a properties parameter object with the following options:
    # "valid_phase": ('Liq', 'Vap')
    # "activity_coeff_model": 'NRTL'
    m.fs.properties = HFCILParameterBlock(default={"valid_phase":
                                                 ('Liq', 'Vap'),
                                                 "activity_coeff_model":
                                                 'NRTL'})
    m.fs.state_block = m.fs.properties.state_block_class(
        default={"parameters": m.fs.properties,
                 "defined_state": True})

    
    # Fix the state variables on the state block
    # hint: state variables exist on the state block i.e. on m.fs.state_block
    
    m.fs.state_block.flow_mol.fix(1)
    m.fs.state_block.temperature.fix(298)
    m.fs.state_block.pressure.fix(101325)
    m.fs.state_block.mole_frac_comp["R32"].fix(0.3)
    m.fs.state_block.mole_frac_comp["emimTf2N"].fix(0.7)

    # Fix NRTL specific parameters. 
    
    # non-randomness parameter - alpha_ij (set at 0.3, 0 if i=j)
    m.fs.properties.\
        alpha["R32", "R32"].fix(0)
    m.fs.properties.\
        alpha["R32", "emimTf2N"].fix(0.3)
    m.fs.properties.\
        alpha["emimTf2N", "emimTf2N"].fix(0)
    m.fs.properties.\
        alpha["emimTf2N", "R32"].fix(0.3)

    # binary interaction parameter - tau_ij (0 if i=j, else to be estimated later but fixing to initialize)
    m.fs.properties.\
        tau["R32", "R32"].fix(0)
    m.fs.properties.\
        tau["R32", "emimTf2N"].fix(15)
    m.fs.properties.\
        tau["emimTf2N", "emimTf2N"].fix(0)
    m.fs.properties.\
        tau["emimTf2N", "R32"].fix(-15)

    # Initialize the flash unit
    m.fs.state_block.initialize(outlvl=idaeslog.DEBUG)

    # Fix at actual temperature
    m.fs.state_block.temperature.fix(float(data["temperature"]))

    # Set bounds on variables to be estimated
    m.fs.properties.\
        tau["R32", "emimTf2N"].setlb(-20)
    m.fs.properties.\
        tau["R32", "emimTf2N"].setub(20)

    m.fs.properties.\
        tau["emimTf2N", "R32"].setlb(-20)
    m.fs.properties.\
        tau["emimTf2N", "R32"].setub(20)

    # Return initialized flash model
    return m

# %%
from idaes.core.util.model_statistics import degrees_of_freedom
import pytest

# Testing the initialized model
test_data = {"temperature": 298}

m = NRTL_model(test_data)

# Check that degrees of freedom is 0
assert degrees_of_freedom(m) == 0

# Check for output values
assert value(m.fs.state_block.mole_frac_phase_comp['Liq', 'R32']) == pytest.approx(0.218, abs=1e-2)
assert value(m.fs.state_block.mole_frac_phase_comp['Vap', 'R32']) == pytest.approx(1.0, abs=1e-2)

assert value(m.fs.state_block.mole_frac_phase_comp['Liq', 'emimTf2N']) == pytest.approx(0.782, abs=1e-2)
assert value(m.fs.state_block.mole_frac_phase_comp['Vap', 'emimTf2N']) == pytest.approx(0.0, abs=1e-2)
