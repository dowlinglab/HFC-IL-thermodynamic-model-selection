# %% [markdown]
# # Final Analysis for R32/emimTF2N model selection case study

# %%
import pandas as pd
import numpy as np
import sys

sys.path.append('../')

# %% [markdown]
# ## Import Data

# %%
PR_1param_Opt1_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_1param_Opt1.csv',header=None).T
PR_1param_Opt1_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_1param_Opt1_opt['CN'] = PR_1param_Opt1_opt['max_eigval']/PR_1param_Opt1_opt['min_eigval']
PR_1param_Opt1_AIC = pd.read_csv('AIC/PR_AIC_1param_Opt1.csv',index_col=0)
PR_1param_Opt1_AIC['name'] = 'PR_1param_Opt1'
PR_1param_Opt1 = pd.concat([PR_1param_Opt1_opt,PR_1param_Opt1_AIC],axis=1)

PR_1param_Opt2_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_1param_Opt2.csv',header=None).T
PR_1param_Opt2_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_1param_Opt2_opt['CN'] = PR_1param_Opt2_opt['max_eigval']/PR_1param_Opt2_opt['min_eigval']
PR_1param_Opt2_AIC = pd.read_csv('AIC/PR_AIC_1param_Opt2.csv',index_col=0)
PR_1param_Opt2_AIC['name'] = 'PR_1param_Opt2'
PR_1param_Opt2 = pd.concat([PR_1param_Opt2_opt,PR_1param_Opt2_AIC],axis=1)

PR_1param_Opt2_GF_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_1param_Opt2_GF.csv',header=None).T
PR_1param_Opt2_GF_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_1param_Opt2_GF_opt['CN'] = PR_1param_Opt2_GF_opt['max_eigval']/PR_1param_Opt2_GF_opt['min_eigval']
PR_1param_Opt2_GF_AIC = pd.read_csv('AIC/PR_AIC_1param_Opt2_GF.csv',index_col=0)
PR_1param_Opt2_GF_AIC['name'] = 'PR_1param_Opt2_GF'
PR_1param_Opt2_GF = pd.concat([PR_1param_Opt2_GF_opt,PR_1param_Opt2_GF_AIC],axis=1)

PR_noTdep_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_noTdep.csv',header=None).T
PR_noTdep_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_noTdep_opt['CN'] = PR_noTdep_opt['max_eigval']/PR_noTdep_opt['min_eigval']
PR_noTdep_AIC = pd.read_csv('AIC/PR_AIC_noTdep.csv',index_col=0)
PR_noTdep_AIC['name'] = 'PR_noTdep'
PR_noTdep = pd.concat([PR_noTdep_opt,PR_noTdep_AIC],axis=1)

PR_3params_Opt1_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_3params_Opt1.csv',header=None).T
PR_3params_Opt1_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_3params_Opt1_opt['CN'] = PR_3params_Opt1_opt['max_eigval']/PR_3params_Opt1_opt['min_eigval']
PR_3params_Opt1_AIC = pd.read_csv('AIC/PR_AIC_3params_Opt1.csv',index_col=0)
PR_3params_Opt1_AIC['name'] = 'PR_3params_Opt1'
PR_3params_Opt1 = pd.concat([PR_3params_Opt1_opt,PR_3params_Opt1_AIC],axis=1)

PR_3params_Opt2_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_3params_Opt2.csv',header=None).T
PR_3params_Opt2_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_3params_Opt2_opt['CN'] = PR_3params_Opt2_opt['max_eigval']/PR_3params_Opt2_opt['min_eigval']
PR_3params_Opt2_AIC = pd.read_csv('AIC/PR_AIC_3params_Opt2.csv',index_col=0)
PR_3params_Opt2_AIC['name'] = 'PR_3params_Opt2'
PR_3params_Opt2 = pd.concat([PR_3params_Opt2_opt,PR_3params_Opt2_AIC],axis=1)

PR_linTdep_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_linTdep.csv',header=None).T
PR_linTdep_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_linTdep_opt['CN'] = PR_linTdep_opt['max_eigval']/PR_linTdep_opt['min_eigval']
PR_linTdep_AIC = pd.read_csv('AIC/PR_AIC_linTdep.csv',index_col=0)
PR_linTdep_AIC['name'] = 'PR_linTdep'
PR_linTdep = pd.concat([PR_linTdep_opt,PR_linTdep_AIC],axis=1)

PR_quadTdep_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_quadTdep.csv',header=None).T
PR_quadTdep_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_quadTdep_opt['CN'] = PR_quadTdep_opt['max_eigval']/PR_quadTdep_opt['min_eigval']
PR_quadTdep_AIC = pd.read_csv('AIC/PR_AIC_quadTdep.csv',index_col=0)
PR_quadTdep_AIC['name'] = 'PR_quadTdep'
PR_quadTdep = pd.concat([PR_quadTdep_opt,PR_quadTdep_AIC],axis=1)

PR_polyTdep_opt = pd.read_csv('EigenAnalysis/PR_FIMtrdet_polyTdep.csv',header=None).T
PR_polyTdep_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
PR_polyTdep_opt['CN'] = PR_polyTdep_opt['max_eigval']/PR_polyTdep_opt['min_eigval']
PR_polyTdep_AIC = pd.read_csv('AIC/PR_AIC_polyTdep.csv',index_col=0)
PR_polyTdep_AIC['name'] = 'PR_polyTdep'
PR_polyTdep = pd.concat([PR_polyTdep_opt,PR_polyTdep_AIC],axis=1)

# %%
SRK_1param_Opt1_opt = pd.read_csv('EigenAnalysis/SRK_FIMtrdet_1param_Opt1.csv',header=None).T
SRK_1param_Opt1_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
SRK_1param_Opt1_opt['CN'] = SRK_1param_Opt1_opt['max_eigval']/SRK_1param_Opt1_opt['min_eigval']
SRK_1param_Opt1_AIC = pd.read_csv('AIC/SRK_AIC_1param_Opt1.csv',index_col=0)
SRK_1param_Opt1_AIC['name'] = 'SRK_1param_Opt1'
SRK_1param_Opt1 = pd.concat([SRK_1param_Opt1_opt,SRK_1param_Opt1_AIC],axis=1)

SRK_1param_Opt2_opt = pd.read_csv('EigenAnalysis/SRK_FIMtrdet_1param_Opt2.csv',header=None).T
SRK_1param_Opt2_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
SRK_1param_Opt2_opt['CN'] = SRK_1param_Opt2_opt['max_eigval']/SRK_1param_Opt2_opt['min_eigval']
SRK_1param_Opt2_AIC = pd.read_csv('AIC/SRK_AIC_1param_Opt2.csv',index_col=0)
SRK_1param_Opt2_AIC['name'] = 'SRK_1param_Opt2'
SRK_1param_Opt2 = pd.concat([SRK_1param_Opt2_opt,SRK_1param_Opt2_AIC],axis=1)

SRK_noTdep_opt = pd.read_csv('EigenAnalysis/SRK_FIMtrdet_noTdep.csv',header=None).T
SRK_noTdep_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
SRK_noTdep_opt['CN'] = SRK_noTdep_opt['max_eigval']/SRK_noTdep_opt['min_eigval']
SRK_noTdep_AIC = pd.read_csv('AIC/SRK_AIC_noTdep.csv',index_col=0)
SRK_noTdep_AIC['name'] = 'SRK_noTdep'
SRK_noTdep = pd.concat([SRK_noTdep_opt,SRK_noTdep_AIC],axis=1)

SRK_3params_Opt1_opt = pd.read_csv('EigenAnalysis/SRK_FIMtrdet_3params_Opt1.csv',header=None).T
SRK_3params_Opt1_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
SRK_3params_Opt1_opt['CN'] = SRK_3params_Opt1_opt['max_eigval']/SRK_3params_Opt1_opt['min_eigval']
SRK_3params_Opt1_AIC = pd.read_csv('AIC/SRK_AIC_3params_Opt1.csv',index_col=0)
SRK_3params_Opt1_AIC['name'] = 'SRK_3params_Opt1'
SRK_3params_Opt1 = pd.concat([SRK_3params_Opt1_opt,SRK_3params_Opt1_AIC],axis=1)

SRK_3params_Opt2_opt = pd.read_csv('EigenAnalysis/SRK_FIMtrdet_3params_Opt2.csv',header=None).T
SRK_3params_Opt2_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
SRK_3params_Opt2_opt['CN'] = SRK_3params_Opt2_opt['max_eigval']/SRK_3params_Opt2_opt['min_eigval']
SRK_3params_Opt2_AIC = pd.read_csv('AIC/SRK_AIC_3params_Opt2.csv',index_col=0)
SRK_3params_Opt2_AIC['name'] = 'SRK_3params_Opt2'
SRK_3params_Opt2 = pd.concat([SRK_3params_Opt2_opt,SRK_3params_Opt2_AIC],axis=1)

SRK_linTdep_opt = pd.read_csv('EigenAnalysis/SRK_FIMtrdet_linTdep.csv',header=None).T
SRK_linTdep_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
SRK_linTdep_opt['CN'] = SRK_linTdep_opt['max_eigval']/SRK_linTdep_opt['min_eigval']
SRK_linTdep_AIC = pd.read_csv('AIC/SRK_AIC_linTdep.csv',index_col=0)
SRK_linTdep_AIC['name'] = 'SRK_linTdep'
SRK_linTdep = pd.concat([SRK_linTdep_opt,SRK_linTdep_AIC],axis=1)

SRK_quadTdep_opt = pd.read_csv('EigenAnalysis/SRK_FIMtrdet_quadTdep.csv',header=None).T
SRK_quadTdep_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
SRK_quadTdep_opt['CN'] = SRK_quadTdep_opt['max_eigval']/SRK_quadTdep_opt['min_eigval']
SRK_quadTdep_AIC = pd.read_csv('AIC/SRK_AIC_quadTdep.csv',index_col=0)
SRK_quadTdep_AIC['name'] = 'SRK_quadTdep'
SRK_quadTdep = pd.concat([SRK_quadTdep_opt,SRK_quadTdep_AIC],axis=1)

SRK_polyTdep_opt = pd.read_csv('EigenAnalysis/SRK_FIMtrdet_polyTdep.csv',header=None).T
SRK_polyTdep_opt.columns = ['cov_trace','FIM_trace','determinant','min_eigval','max_eigval']
SRK_polyTdep_opt['CN'] = SRK_polyTdep_opt['max_eigval']/SRK_polyTdep_opt['min_eigval']
SRK_polyTdep_AIC = pd.read_csv('AIC/SRK_AIC_polyTdep.csv',index_col=0)
SRK_polyTdep_AIC['name'] = 'SRK_polyTdep'
SRK_polyTdep = pd.concat([SRK_polyTdep_opt,SRK_polyTdep_AIC],axis=1)

# %%
PR = pd.concat([PR_1param_Opt1,PR_1param_Opt2,PR_1param_Opt2_GF,PR_noTdep,PR_3params_Opt1,PR_3params_Opt2,PR_linTdep,PR_quadTdep,PR_polyTdep])

# %%
SRK = pd.concat([SRK_1param_Opt1,SRK_1param_Opt2,SRK_noTdep,SRK_3params_Opt1,SRK_3params_Opt2,SRK_linTdep,SRK_quadTdep,SRK_polyTdep])

# %%
Results = pd.concat([PR,SRK],ignore_index=True)

# %%
first_column = Results.pop('name')
Results.insert(0, 'name', first_column)

# %%
Results['Likelihood'] = np.exp((Results['AIC'].min() - Results['AIC'])/2)

# %%
Results
# Out:
#                  name     cov_trace     FIM_trace   determinant    min_eigval  \
# 0      PR_1param_Opt1  8.129928e-06  1.230023e+05  1.230023e+05  1.230023e+05
# 1      PR_1param_Opt2  6.693686e-13  1.493945e+12  1.493945e+12  1.493945e+12
# 2   PR_1param_Opt2_GF  1.696092e-04  5.895907e+03  5.895907e+03  5.895907e+03
# 3           PR_noTdep  3.715839e-04  6.309260e+05  1.697937e+09  2.702760e+03
# 4     PR_3params_Opt1  6.945755e-04  4.071249e+06  8.258536e+13  1.627693e+03
# 5     PR_3params_Opt2  2.816079e-01  6.150469e+05  1.046210e+10  3.553673e+00
# 6          PR_linTdep  3.215929e-02  1.801476e+07  4.116967e+17  3.121947e+01
# 7         PR_quadTdep  1.899295e+01  3.209560e+07  2.035821e+19  5.287526e-02
# 8         PR_polyTdep  3.743503e+02  4.605952e+08  2.925709e+26  2.730920e-03
# 9     SRK_1param_Opt1  9.478329e-06  1.055038e+05  1.055038e+05  1.055038e+05
# 10    SRK_1param_Opt2  2.442303e-12  4.094495e+11  4.094495e+11  4.094495e+11
# ...

# %%
Results_Ranked = Results.sort_values(['Likelihood'],ascending=False,ignore_index=True)

# %%
Results_Ranked.drop(['Objective, Pa^2'],axis=1)
# Out:
#                  name     cov_trace     FIM_trace   determinant    min_eigval  \
# 0         PR_quadTdep  1.899295e+01  3.209560e+07  2.035821e+19  5.287526e-02
# 1        SRK_quadTdep  2.063175e+01  2.965074e+07  1.281556e+19  4.867407e-02
# 2          PR_linTdep  3.215929e-02  1.801476e+07  4.116967e+17  3.121947e+01
# 3         SRK_linTdep  3.578783e-02  1.620366e+07  2.723002e+17  2.805321e+01
# 4         PR_polyTdep  3.743503e+02  4.605952e+08  2.925709e+26  2.730920e-03
# 5        SRK_polyTdep  4.159454e+02 -6.399312e+09 -2.549296e+27 -6.438416e+09
# 6     PR_3params_Opt1  6.945755e-04  4.071249e+06  8.258536e+13  1.627693e+03
# 7    SRK_3params_Opt1  7.533364e-04  3.723385e+06  6.394050e+13  1.501667e+03
# 8           PR_noTdep  3.715839e-04  6.309260e+05  1.697937e+09  2.702760e+03
# 9     PR_3params_Opt2  2.816079e-01  6.150469e+05  1.046210e+10  3.553673e+00
# 10         SRK_noTdep  4.803294e-04  4.843418e+05  1.008353e+09  2.090931e+03
# ...

# %%
Results.drop(['cov_trace','N','MSE','k','AIC','Likelihood','Objective, Pa^2'],axis=1)
# Out:
#                  name     FIM_trace   determinant    min_eigval    max_eigval  \
# 0      PR_1param_Opt1  1.230023e+05  1.230023e+05  1.230023e+05  1.230023e+05
# 1      PR_1param_Opt2  1.493945e+12  1.493945e+12  1.493945e+12  1.493945e+12
# 2   PR_1param_Opt2_GF  5.895907e+03  5.895907e+03  5.895907e+03  5.895907e+03
# 3           PR_noTdep  6.309260e+05  1.697937e+09  2.702760e+03  6.282232e+05
# 4     PR_3params_Opt1  4.071249e+06  8.258536e+13  1.627693e+03  4.057116e+06
# 5     PR_3params_Opt2  6.150469e+05  1.046210e+10  3.553673e+00  6.102188e+05
# 6          PR_linTdep  1.801476e+07  4.116967e+17  3.121947e+01  1.792059e+07
# 7         PR_quadTdep  3.209560e+07  2.035821e+19  5.287526e-02  3.186740e+07
# 8         PR_polyTdep  4.605952e+08  2.925709e+26  2.730920e-03  4.358782e+08
# 9     SRK_1param_Opt1  1.055038e+05  1.055038e+05  1.055038e+05  1.055038e+05
# 10    SRK_1param_Opt2  4.094495e+11  4.094495e+11  4.094495e+11  4.094495e+11
# ...
