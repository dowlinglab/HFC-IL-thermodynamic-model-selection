# %% [markdown]
# # Model Discrimination for  R32/emimTF2N system
#
# EoS: PR vs. SRK
#
# Parameter T dependence: Linear
#
# N (total fitting parameters): 4

# %% [markdown]
# ## Import Functions

# %%
import idaes

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize

import sys
sys.path.append('../')

from pyomo.environ import (Constraint,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value)
from pyomo.opt import TerminationCondition, SolverStatus

from idaes.core import FlowsheetBlock
import idaes.logger as idaeslog
# Import the Generic Parameter Block
from idaes.generic_models.properties.core.generic.generic_property import (
        GenericParameterBlock)
# Import unit models from the model library
from idaes.generic_models.unit_models import Flash
# Import degrees of freedom tool
from idaes.core.util.model_statistics import degrees_of_freedom

import scipy.stats as stats

# %% [markdown]
# ## Make model functions

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6}

# %%
def calc_PR2mod_P(x_HFC,T):
    '''
    Define function to calculate the PR 2 parameter model pressure given a composition and temperature
    
    Inputs:
    x_HFC - HFC compositions
    T - temperature to run
    
    Output: 
    P: pressure
    
    '''
    
    m = ConcreteModel()

    m.fs = FlowsheetBlock(default={"dynamic": False})
    
    # Configuration
    from hfc32_emimtf2n_PR import configuration as config_PR_2

    m.fs.properties = GenericParameterBlock(default=config_PR_2)

    m.fs.F101 = Flash(default={"property_package": m.fs.properties,
                               "has_heat_transfer": True,
                               "has_pressure_change": True})

    m.fs.F101.inlet.flow_mol.fix(1)
    m.fs.F101.inlet.temperature.fix(323.15)
    m.fs.F101.inlet.pressure.fix(399800)
    m.fs.F101.inlet.mole_frac_comp[0,'R32'].fix(0.5)
    
    # Model params
    params_PR_2 = pd.read_csv('../Params/PR_params_noTdep.csv',header=None)
    
    m.fs.properties.PR_kappa_A['R32','emimTf2N'] = float(params_PR_2.iloc[1])
    m.fs.properties.PR_kappa_A['emimTf2N','R32'] = float(params_PR_2.iloc[0])
    
    # Initialize the flash unit
    m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)

    # Fix the state variables on the state block
    # m.fs.F101.inlet.pressure.unfix()
    m.fs.F101.inlet.mole_frac_comp[0,'emimTf2N'].unfix()

    m.fs.liq = Param(mutable=True,default=0.040)
    m.fs.liquid = Constraint(expr=m.fs.F101.liq_outlet.mole_frac_comp[0, "emimTf2N"] == m.fs.liq)
    
    # Calc pressure
    x_IL = 1-x_HFC
    if 0.05 <= x_HFC <= 0.09:
        guess_P = 90000
    elif 0.09 < x_HFC <= 0.15:
        guess_P = 200000
    elif 0.15 < x_HFC <= 0.3:
        guess_P = 250000
    else:
        guess_P = 400000
    
    m.fs.liq = x_IL
    m.fs.F101.inlet.temperature.fix(T)
    m.fs.F101.inlet.pressure.fix(guess_P)
    m.fs.F101.inlet.mole_frac_comp[0,'R32'].fix(x_HFC+0.1)
    m.fs.F101.inlet.mole_frac_comp[0,'emimTf2N'].fix(float(1-(x_HFC+0.1)))
    m.fs.F101.vap_outlet.temperature.fix(float(T))
    
    try:
        m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)
        
    except:
        print('Initialization Error')
        
    try:

        status = solver.solve(m, tee = False)
        
        if (status.solver.status == SolverStatus.ok) and (status.solver.termination_condition == TerminationCondition.optimal):
            print('Feasible/Optimal Solution')
            x_HFC_final = value(m.fs.F101.liq_outlet.mole_frac_comp[0,'R32']) 
            P_final = value(m.fs.F101.vap_outlet.pressure[0])
        else:
            print('Infeasible Solution')
            x_HFC_final = np.nan
            P_final = np.nan
            
    except ValueError:
        x_HFC_final = np.nan
        P_final = np.nan
        print('Solver Error')
    
    return P_final

# %%
def calc_PR4mod_P(x_HFC,T):
    '''
    Define function to calculate the PR 4 parameter model pressure given a composition and temperature
    
    Inputs:
    x_HFC - HFC compositions
    T - temperature to run
    
    Output: 
    P: pressure
    
    '''
    
    m = ConcreteModel()

    m.fs = FlowsheetBlock(default={"dynamic": False})
    
    # Configuration
    from hfc32_emimtf2n_PR import configuration as config_PR_4

    m.fs.properties = GenericParameterBlock(default=config_PR_4)

    m.fs.F101 = Flash(default={"property_package": m.fs.properties,
                               "has_heat_transfer": True,
                               "has_pressure_change": True})

    m.fs.F101.inlet.flow_mol.fix(1)
    m.fs.F101.inlet.temperature.fix(323.15)
    m.fs.F101.inlet.pressure.fix(399800)
    m.fs.F101.inlet.mole_frac_comp[0,'R32'].fix(0.5)
    
    # Model params
    params_PR_4 = pd.read_csv('../Params/PR_params_linTdep.csv',header=None)
    
    m.fs.properties.PR_kappa_A['R32','emimTf2N'] = float(params_PR_4.iloc[0])
    m.fs.properties.PR_kappa_A['emimTf2N','R32'] = float(params_PR_4.iloc[1])
    m.fs.properties.PR_kappa_B['R32','emimTf2N'] = float(params_PR_4.iloc[2])
    m.fs.properties.PR_kappa_B['emimTf2N','R32'] = float(params_PR_4.iloc[3])
    
    # Initialize the flash unit
    m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)

    # Fix the state variables on the state block
    # m.fs.F101.inlet.pressure.unfix()
    m.fs.F101.inlet.mole_frac_comp[0,'emimTf2N'].unfix()

    m.fs.liq = Param(mutable=True,default=0.040)
    m.fs.liquid = Constraint(expr=m.fs.F101.liq_outlet.mole_frac_comp[0, "emimTf2N"] == m.fs.liq)
    
    # Calc pressure
    x_IL = 1-x_HFC
    if 0.05 <= x_HFC <= 0.09:
        guess_P = 90000
    elif 0.09 < x_HFC <= 0.15:
        guess_P = 200000
    elif 0.15 < x_HFC <= 0.3:
        guess_P = 250000
    else:
        guess_P = 400000
    
    m.fs.liq = x_IL
    m.fs.F101.inlet.temperature.fix(T)
    m.fs.F101.inlet.pressure.fix(guess_P)
    m.fs.F101.inlet.mole_frac_comp[0,'R32'].fix(x_HFC+0.1)
    m.fs.F101.inlet.mole_frac_comp[0,'emimTf2N'].fix(float(1-(x_HFC+0.1)))
    m.fs.F101.vap_outlet.temperature.fix(float(T))
    
    try:
        m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)
        
    except:
        print('Initialization Error')
        
    try:

        status = solver.solve(m, tee = False)
        
        if (status.solver.status == SolverStatus.ok) and (status.solver.termination_condition == TerminationCondition.optimal):
            print('Feasible/Optimal Solution')
            x_HFC_final = value(m.fs.F101.liq_outlet.mole_frac_comp[0,'R32']) 
            P_final = value(m.fs.F101.vap_outlet.pressure[0])
        else:
            print('Infeasible Solution')
            x_HFC_final = np.nan
            P_final = np.nan
            
    except ValueError:
        x_HFC_final = np.nan
        P_final = np.nan
        print('Solver Error')
    
    return P_final

# %%
def error(params):
    '''
    Function which calculates the squared error between two models
 
    Inputs:
    params:
        x_HFC - HFC compositions
        T - temperature to run
    
    Ouputs:
    error - squared error between two models, made negative
    '''
    
    x_HFC = params[0]
    T = params[1]
    
    print('Trying x_HFC:',x_HFC)
    print('Trying T:',T)
    
    P_PR_2 = calc_PR2mod_P(x_HFC,T)
    
    P_PR_4 = calc_PR4mod_P(x_HFC,T)
    
    error = (P_PR_2 - P_PR_4)**2
    
    print('error:',error)
    
    return error*(-1)

# %% [markdown]
# ## Setup Optimization Problem for Model Discrimination

# %%
var_guess = (0.4,280)
bnds = ((0.15,0.6),(275,360))
results = scipy.optimize.minimize(error,var_guess,bounds=bnds,tol=1E-4)
# Out:
# Trying x_HFC: 0.4
# Trying T: 280.0
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 770218187.1703261
# Trying x_HFC: 0.40000001
# Trying T: 280.0
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 770218181.4009006
# Trying x_HFC: 0.4
# Trying T: 280.00000001
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 770218187.299082
# Trying x_HFC: 0.15
# Trying T: 360.0
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 2766125792.504709
# Trying x_HFC: 0.15000001
# Trying T: 360.0
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 2766126062.5575147
# Trying x_HFC: 0.15
# Trying T: 359.99999999
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 2766125790.3634872
# Trying x_HFC: 0.6
# Trying T: 360.0
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 110265576392.92918
# Trying x_HFC: 0.5999999899999999
# Trying T: 360.0
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 110265550004.05554
# Trying x_HFC: 0.6
# Trying T: 359.99999999
# Feasible/Optimal Solution
# Feasible/Optimal Solution
# error: 110265576314.41801

# %%
results
# Out:
#       fun: -110265576392.92918
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.63888735e+12, -7.85111072e+09])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 9
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([  0.6, 360. ])

# %%
var_guess = (0.1,280)
bnds = ((0.0755,0.8),(272.5,360))
results = scipy.optimize.minimize(error,var_guess,bounds=bnds,tol=1E-4)

# %%
results

# %%
var_guess = (0.6,280)
bnds = ((0.15,0.8),(265,360))
results = scipy.optimize.minimize(error,var_guess,bounds=bnds,tol=1E-4)

# %%
results
