# %% [markdown]
# # Organize LH sample for SRK poly LHS multistart

# %%
import pandas as pd
import numpy as np

import sys
sys.path.append('../../')

# %%
SRK_quad_results = pd.read_csv('Final_Results/Data/Init_Final/LHS_Output/SRK_quadTdep_LHS_final.csv',index_col=0)

# %%
SRK_quad_results.dropna(axis=0)
# Out:
#         Param1    Param2    Param3    Param4    Param5    Param6  sc_param1  \
# 461   0.322917  0.558144  0.409933  0.246390  0.802685  0.715946  -0.708620
# 1501  0.375854  0.647447  0.573016  0.094414  0.485069  0.750320  -0.496796
# 2268  0.577432  0.069101  0.063235  0.746237  0.804114  0.671634   0.309795
# 3196  0.219315  0.052459  0.172854  0.901598  0.970125  0.539986  -1.123173
# 3319  0.080298  0.188618  0.844589  0.755908  0.535566  0.532437  -1.679435
# 3509  0.094904  0.350023  0.228243  0.142143  0.783457  0.936461  -1.620993
# 3534  0.613879  0.048818  0.229303  0.452727  0.849661  0.895539   0.455636
# 3964  0.385865  0.054794  0.138114  0.418697  0.864634  0.926236  -0.456740
# 4123  0.457181  0.069687  0.098625  0.412596  0.661289  0.907472  -0.171374
# 4475  0.340152  0.018430  0.548103  0.617827  0.507984  0.847794  -0.639658
# 4873  0.046049  0.045816  0.932074  0.806436  0.429535  0.628984  -1.816478
#
# ...

# %%
quad_3196 = SRK_quad_results.iloc[3196]

# %%
lhs = pd.read_csv('../../LHS_5000x8.txt')

# %%
lhs['sc_param7'] = ((lhs['Param7']-lhs['Param7'].min())/(lhs['Param7'].max()-lhs['Param7'].min()))*4+(-2)
lhs['sc_param8'] = ((lhs['Param8']-lhs['Param8'].min())/(lhs['Param8'].max()-lhs['Param8'].min()))*4+(-2)

# %%
quad_3196 = quad_3196[['sc_param1','sc_param2','sc_param3','sc_param4','sc_param5','sc_param6']]

# %%
quad_3196_sc_df = pd.DataFrame(quad_3196).T
sc = pd.concat([quad_3196_sc_df]*5000,ignore_index=True)
sc_lhs = pd.concat([sc,lhs[['sc_param7','sc_param8']]],axis=1,ignore_index=True)
sc_lhs.columns = ['sc_param1','sc_param2','sc_param3','sc_param4','sc_param5','sc_param6','sc_param7','sc_param8']
sc_lhs.to_csv('Final_Results/Data/Init_Final/SRK_polyTdep_fromquad_init.csv',sep=',')

# %%
sc_lhs
# Out:
#       sc_param1  sc_param2  sc_param3  sc_param4  sc_param5  sc_param6  \
# 0     -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# 1     -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# 2     -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# 3     -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# 4     -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# ...         ...        ...        ...        ...        ...        ...
# 4995  -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# 4996  -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# 4997  -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# 4998  -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
# 4999  -1.123173  -1.790506   -1.30863   1.606775    1.88068   0.159922
#
#       sc_param7  sc_param8
# 0     -1.864270  -0.490373
# 1      0.451423   1.493513
# 2      0.420224   1.786663
# ...

# %%
# quad_33_act_df = pd.DataFrame(quad_33_act).T
# quad_33_act_df.columns = ['sc_param1','sc_param2','sc_param3','sc_param4','sc_param5','sc_param6']
# act = pd.concat([quad_33_act_df]*250,ignore_index=True)
# act_lhs = pd.concat([act,lhs[['sc_param7','sc_param8']]],axis=1,ignore_index=True)
# act_lhs.columns = ['sc_param1','sc_param2','sc_param3','sc_param4','sc_param5','sc_param6','sc_param7','sc_param8']
# act_lhs.to_csv('Data/Fits/LHS_Fits/SRK_polyTdep_actLHS.csv',sep=',')

# %%
sc_lhs

# %%
act_lhs
