# %% [markdown]
# # AIC Table of Models for R125/emimTF2N system

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import AIC Data

# %%
PR_1param_Opt1 = pd.read_csv('PR_AIC_1param_Opt1.csv',index_col=0)
PR_1param_Opt1['name'] = 'PR_1param_Opt1'

PR_1param_Opt2 = pd.read_csv('PR_AIC_1param_Opt2.csv',index_col=0)
PR_1param_Opt2['name'] = 'PR_1param_Opt2'

PR_noTdep = pd.read_csv('PR_AIC_noTdep.csv',index_col=0)
PR_noTdep['name'] = 'PR_noTdep'

PR_3params_Opt1 = pd.read_csv('PR_AIC_3params_Opt1.csv',index_col=0)
PR_3params_Opt1['name'] = 'PR_3params_Opt1'

PR_3params_Opt2 = pd.read_csv('PR_AIC_3params_Opt2.csv',index_col=0)
PR_3params_Opt2['name'] = 'PR_3params_Opt2'

PR_linTdep = pd.read_csv('PR_AIC_linTdep.csv',index_col=0)
PR_linTdep['name'] = 'PR_linTdep'

PR_quadTdep = pd.read_csv('PR_AIC_quadTdep.csv',index_col=0)
PR_quadTdep['name'] = 'PR_quadTdep'

PR_polyTdep = pd.read_csv('PR_AIC_polyTdep.csv',index_col=0)
PR_polyTdep['name'] = 'PR_polyTdep'

# %%
SRK_1param_Opt1 = pd.read_csv('SRK_AIC_1param_Opt1.csv',index_col=0)
SRK_1param_Opt1['name'] = 'SRK_1param_Opt1'

SRK_1param_Opt2 = pd.read_csv('SRK_AIC_1param_Opt2.csv',index_col=0)
SRK_1param_Opt2['name'] = 'SRK_1param_Opt2'

SRK_noTdep = pd.read_csv('SRK_AIC_noTdep.csv',index_col=0)
SRK_noTdep['name'] = 'SRK_noTdep'

SRK_3params_Opt1 = pd.read_csv('SRK_AIC_3params_Opt1.csv',index_col=0)
SRK_3params_Opt1['name'] = 'SRK_3params_Opt1'

SRK_3params_Opt2 = pd.read_csv('SRK_AIC_3params_Opt2.csv',index_col=0)
SRK_3params_Opt2['name'] = 'SRK_3params_Opt2'

SRK_linTdep = pd.read_csv('SRK_AIC_linTdep.csv',index_col=0)
SRK_linTdep['name'] = 'SRK_linTdep'

SRK_quadTdep = pd.read_csv('SRK_AIC_quadTdep.csv',index_col=0)
SRK_quadTdep['name'] = 'SRK_quadTdep'

SRK_polyTdep = pd.read_csv('SRK_AIC_polyTdep.csv',index_col=0)
SRK_polyTdep['name'] = 'SRK_polyTdep'

# %%
PR = pd.concat([PR_1param_Opt1,PR_1param_Opt2,PR_noTdep,PR_3params_Opt1,PR_3params_Opt2,PR_linTdep,PR_quadTdep,PR_polyTdep])

# %%
SRK = pd.concat([SRK_1param_Opt1,SRK_1param_Opt2,SRK_noTdep,SRK_3params_Opt1,SRK_3params_Opt2,SRK_linTdep,SRK_quadTdep,SRK_polyTdep])

# %%
AICTable = pd.concat([PR,SRK],ignore_index=True)

# %%
AICTable
# Out:
#        N       MSE    k  Objective, Pa^2         AIC              name
# 0   32.0  0.009222  1.0         0.295091 -147.958630    PR_1param_Opt1
# 1   32.0  0.080853  1.0         2.587292  -78.483973    PR_1param_Opt2
# 2   32.0  0.005817  2.0         0.186145 -160.702947         PR_noTdep
# 3   32.0  0.003675  3.0         0.117613 -173.394944   PR_3params_Opt1
# 4   32.0  0.005299  3.0         0.169553 -161.690507   PR_3params_Opt2
# 5   32.0  0.003667  4.0         0.117352 -171.466136        PR_linTdep
# 6   32.0  0.003537  6.0        11.317267 -168.626447       PR_quadTdep
# 7   32.0  0.003433  8.0        10.985124 -165.579650       PR_polyTdep
# 8   32.0  0.011635  1.0         0.372310 -140.520479   SRK_1param_Opt1
# 9   32.0  0.250058  1.0         8.001842  -42.354053   SRK_1param_Opt2
# 10  32.0  0.004161  2.0         0.133158 -171.422490        SRK_noTdep
# 11  32.0  0.003705  3.0         0.118557 -173.139173  SRK_3params_Opt1
# 12  32.0  0.004035  3.0         0.129105 -170.411622  SRK_3params_Opt2
# 13  32.0  0.003705  4.0         0.118554 -171.140040       SRK_linTdep
# 14  32.0  0.003531  6.0        11.299368 -168.677099      SRK_quadTdep
# 15  32.0  0.003429  8.0        10.972701 -165.615859      SRK_polyTdep

# %%
AICTable['Relative_Log_Likelihood'] = (AICTable['AIC'].min() - AICTable['AIC'])/2

# %%
AICTable
# Out:
#        N       MSE    k  Objective, Pa^2         AIC              name  \
# 0   32.0  0.009222  1.0         0.295091 -147.958630    PR_1param_Opt1
# 1   32.0  0.080853  1.0         2.587292  -78.483973    PR_1param_Opt2
# 2   32.0  0.005817  2.0         0.186145 -160.702947         PR_noTdep
# 3   32.0  0.003675  3.0         0.117613 -173.394944   PR_3params_Opt1
# 4   32.0  0.005299  3.0         0.169553 -161.690507   PR_3params_Opt2
# 5   32.0  0.003667  4.0         0.117352 -171.466136        PR_linTdep
# 6   32.0  0.003537  6.0        11.317267 -168.626447       PR_quadTdep
# 7   32.0  0.003433  8.0        10.985124 -165.579650       PR_polyTdep
# 8   32.0  0.011635  1.0         0.372310 -140.520479   SRK_1param_Opt1
# 9   32.0  0.250058  1.0         8.001842  -42.354053   SRK_1param_Opt2
# 10  32.0  0.004161  2.0         0.133158 -171.422490        SRK_noTdep
# 11  32.0  0.003705  3.0         0.118557 -173.139173  SRK_3params_Opt1
# 12  32.0  0.004035  3.0         0.129105 -170.411622  SRK_3params_Opt2
# 13  32.0  0.003705  4.0         0.118554 -171.140040       SRK_linTdep
# 14  32.0  0.003531  6.0        11.299368 -168.677099      SRK_quadTdep
# 15  32.0  0.003429  8.0        10.972701 -165.615859      SRK_polyTdep
#
#     Relative_Log_Likelihood
# 0                -12.718157
# 1                -47.455486
# 2                 -6.345999
# 3                  0.000000
# 4                 -5.852219
# 5                 -0.964404
# 6                 -2.384248
# 7                 -3.907647
# 8                -16.437233
# 9                -65.520445
# 10                -0.986227
# 11                -0.127886
# 12                -1.491661
# 13                -1.127452
# 14                -2.358923
# 15                -3.889543

# %%
AICTable_Ranked = AICTable.sort_values(['Relative_Log_Likelihood'],ascending=False,ignore_index=True)

# %%
AICTable_Ranked.drop(['Objective, Pa^2'],axis=1)
# Out:
#        N       MSE    k         AIC              name  Relative_Log_Likelihood
# 0   32.0  0.003675  3.0 -173.394944   PR_3params_Opt1                 0.000000
# 1   32.0  0.003705  3.0 -173.139173  SRK_3params_Opt1                -0.127886
# 2   32.0  0.003667  4.0 -171.466136        PR_linTdep                -0.964404
# 3   32.0  0.004161  2.0 -171.422490        SRK_noTdep                -0.986227
# 4   32.0  0.003705  4.0 -171.140040       SRK_linTdep                -1.127452
# 5   32.0  0.004035  3.0 -170.411622  SRK_3params_Opt2                -1.491661
# 6   32.0  0.003531  6.0 -168.677099      SRK_quadTdep                -2.358923
# 7   32.0  0.003537  6.0 -168.626447       PR_quadTdep                -2.384248
# 8   32.0  0.003429  8.0 -165.615859      SRK_polyTdep                -3.889543
# 9   32.0  0.003433  8.0 -165.579650       PR_polyTdep                -3.907647
# 10  32.0  0.005299  3.0 -161.690507   PR_3params_Opt2                -5.852219
# 11  32.0  0.005817  2.0 -160.702947         PR_noTdep                -6.345999
# 12  32.0  0.009222  1.0 -147.958630    PR_1param_Opt1               -12.718157
# 13  32.0  0.011635  1.0 -140.520479   SRK_1param_Opt1               -16.437233
# 14  32.0  0.080853  1.0  -78.483973    PR_1param_Opt2               -47.455486
# 15  32.0  0.250058  1.0  -42.354053   SRK_1param_Opt2               -65.520445
