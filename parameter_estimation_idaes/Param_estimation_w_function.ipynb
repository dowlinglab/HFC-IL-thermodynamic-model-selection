# %%
from binary_param2 import binary_params_peng

from R32_bmimPF6_PR import configuration

# %%
binary_params_peng('R32IL298.csv', configuration, 'R32', 'bmimPF6', "x_R32", "x_bmimPF6", 
    init_temp = 323.15, init_press = 399800, init_x_c1 = 0.5, init_x_c2 = 0.5,
    init_kappa_2_1 = -0.05, init_kappa_1_2 = -0.03, eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2021-08-17 15:36:36 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:36:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-08-17 15:36:37 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:36:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-08-17 15:36:38 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:36:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-08-17 15:36:39 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:36:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-08-17 15:36:39 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:36:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-08-17 15:36:40 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:36:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-08-17 15:36:41 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:36:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-08-17 15:36:41 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:36:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.12.13: bound_relax_factor=0
# honor_original_bounds=no
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      268
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      272
#
# Total number of variables............................:      112
#                      variables with only lower bounds:       48
#                 variables with lower and upper bounds:       48
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      110
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.46e-01 1.42e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.8876668e-02 2.25e-01 4.67e+01  -1.0 7.94e+03    -  5.44e-01 9.90e-01h  1
#    2  3.4263183e-02 2.28e-02 1.77e+02  -1.0 3.84e+03    -  8.13e-01 9.90e-01h  1
#    3  3.6540959e-02 4.62e-04 2.46e+01  -1.0 4.71e+02    -  9.90e-01 9.90e-01h  1
#    4  3.4264720e-02 8.30e-06 1.29e+04  -1.0 7.64e+02    -  9.89e-01 9.90e-01h  1
#    5  2.8103341e-02 3.89e-06 4.01e+03  -1.0 4.73e+03    -  9.90e-01 9.90e-01H  1
#    6  2.7418068e-02 1.29e-08 8.66e+01  -3.8 1.24e+03    -  1.00e+00 1.00e+00H  1
# In iteration 6, 8 Slacks too small, adjusting variable bounds
#    7  2.7418038e-02 4.90e-10 2.26e+04  -5.7 8.05e+00    -  1.00e+00 1.00e+00h  1
#    8  2.7418038e-02 1.41e-12 1.84e-11  -5.7 2.14e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.7418038368065799e-02    2.7418038368065799e-02
# Dual infeasibility......:   1.8449568832289417e-11    1.8449568832289417e-11
# Constraint violation....:   1.4135359549527493e-12    1.4135359549527493e-12
# Complementarity.........:   1.8449178662366827e-06    1.8449178662366827e-06
# Overall NLP error.......:   2.8867062159906191e-12    1.8449178662366827e-06
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.010
# Total CPU secs in NLP function evaluations           =      0.044
#
# EXIT: Optimal Solution Found.
# Warning: estimated values of mu do not seem consistent - using mu=10^(-8.6)
# The SSE at the optimal solution is 0.027418
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa[bmimPF6,R32] = -0.10192807999393622
# fs.properties.PR_kappa[R32,bmimPF6] = -0.032234253622997394
# covariance_matrix                                      fs.properties.PR_kappa[bmimPF6,R32]  \
# fs.properties.PR_kappa[bmimPF6,R32]                             0.000159
# fs.properties.PR_kappa[R32,bmimPF6]                             0.000017
#
#                                      fs.properties.PR_kappa[R32,bmimPF6]
# fs.properties.PR_kappa[bmimPF6,R32]                             0.000017
# fs.properties.PR_kappa[R32,bmimPF6]                             0.000002
# C:\Users\agarc\Anaconda32\envs\examples_modules\lib\site-packages\pyomo\contrib\interior_point\interface.py:418: RuntimeWarning: divide by zero encountered in true_divide
#   data = (duals_primals_lb/(primals - self._nlp.primals_lb()) +

# %%
from R125_bmimPF6_PR import configuration

binary_params_peng('R125IL.csv', configuration, 'R125', 'bmimPF6', "x_R125", "x_bmimPF6", 
    init_temp = 298.15, init_press = 799600, init_x_c1 = 0.739, init_x_c2 = 0.261,
    init_kappa_2_1 = 0.1, init_kappa_1_2 = 0.1, eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2021-08-17 15:37:12 [INFO] idaes.generic_models.properties.core.generic.generic_property: DEPRECATED - definiton of generic property packages is moving to using static classes instead of modules. Please refer to the IDAES documentation.
# 2021-08-17 15:37
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1602883496995040e+02    1.1602883496995040e+02
# Dual infeasibility......:   3.0779915913846388e+09    3.0779915913846388e+09
# Constraint violation....:   1.2507754734469950e+01    1.2507754734469950e+01
# Complementarity.........:   2.2068431718247359e+00    2.2068431718247359e+00
# Overall NLP error.......:   3.0779915913846388e+09    3.0779915913846388e+09
#
#
# Number of objective function evaluations             = 511
# Number of objective gradient evaluations             = 101
# Number of equality constraint evaluations            = 511
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 106
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 104
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.149
# Total CPU secs in NLP function evaluations           =      4.632
#
# EXIT: Restoration Failed!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20364/518493427.py in <module>
#       1 from R125_bmimPF6_PR import configuration
#       2
# ----> 3 binary_params_peng('R125IL.csv', configuration, 'R125', 'bmimPF6', "x_R125", "x_bmimPF6",
#       4     init_temp = 298.15, init_press = 799600, init_x_c1 = 0.739, init_x_c2 = 0.261,
#       5     init_kappa_2_1 = 0.1, init_kappa_1_2 = 0.1, eps = 0.1, scaling_fac = 1e-9)
#
# ~\Desktop\Me\Dowlinglab\CO2_IL\extractive-distillation2\parameter_estimation_idaes\binary_param2.py in binary_params_peng(file, configuration, comp_1, comp_2, x_comp_1, x_comp_2, init_temp, init_press, init_x_c1, init_x_c2, init_kappa_1_2, init_kappa_2_1, eps, scaling_fac)
#     120     pest = parmest.Estimator(PR_model, data, variable_name, SSE, tee=True)
#     121
# --> 122     obj_value, parameters,a= pest.theta_est(calc_cov=True)
#     123
#     124     print_params(obj_value, parameters)
#
# ~\Anaconda32\envs\examples_modules\lib\site-packages\pyomo\contrib\parmest\parmest.py in theta_est(self, solver, return_values, bootlist, calc_cov)
#     672         assert isinstance(bootlist, (type(None), list))
#     673
# --> 674         return self._Q_opt(solver=solver, return_values=return_values,
#     675                            bootlist=bootlist, calc_cov=calc_cov)
#     676
#
# ~\Anaconda32\envs\examples_modules\lib\site-packages\pyomo\contrib\parmest\parmest.py in _Q_opt(self, ThetaVals, solver, return_values, bootlist, calc_cov)
#     457                 # calculate the reduced hessian
#     458                 solve_result, inv_red_hes = \
# --> 459                     inverse_reduced_hessian.inv_reduced_hessian_barrier(
#     460                         self.ef_instance,
#     461                         independent_variables= ind_vars,
#
# ~\Anaconda32\envs\examples_modules\lib\site-packages\pyomo\contrib\interior_point\inverse_reduced_hessian.py in inv_reduced_hessian_barrier(model, independent_variables, bound_tolerance, solver_options, tee)
#      80
#      81     # solve the problem
# ---> 82     status = solver.solve(m, tee=tee)
#      83     if not check_optimal_termination(status):
#      84         return status, None
#
# ~\Anaconda32\envs\examples_modules\lib\site-packages\pyomo\opt\base\solvers.py in solve(self, *args, **kwds)
#     624                 else:
#     625                     if self._load_solutions:
# --> 626                         _model.solutions.load_from(
#     627                             result,
#     628                             select=self._select_index,
#
# ~\Anaconda32\envs\examples_modules\lib\site-packages\pyomo\core\base\PyomoModel.py in load_from(self, results, allow_consistent_values_for_fixed_vars, comparison_tolerance_for_fixed_vars, ignore_invalid_labels, id, delete_symbol_map, clear, default_variable_value, select, ignore_fixed_vars)
#     222                     "an 'aborted' status, but containing a solution")
#     223             else:
# --> 224                 raise ValueError("Cannot load a SolverResults object "
#     225                                  "with bad status: %s"
#     226                                  % str(results.solver.status))
#
# ValueError: Cannot load a SolverResults object with bad status: error
