# %%
from binary_param import linear, constant
import pandas as pd
from HFC32_emimTf2N_PR import configuration

# %%
data = pd.read_csv('R32_emimTf2N.csv')

# %%
constant(data, configuration, 'R32', 'emimTf2N', "x_R32", "x_emimTf2N",
    init_temp =  298.15, init_press =   399400 , init_x_c1 =    0.417, init_x_c2 = 0.583,
    init_kappa_2_1A = -0.012, init_kappa_1_2A = -0.030,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-03-08 13:48:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:48:49 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-03-08 13:48:50 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-03-08 13:48:50 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-03-08 13:48:51 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-03-08 13:48:52 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# ...

# %%
from HFC125_emimTf2N_PR import configuration as configuration2

# %%
data2 = pd.read_csv('R125_emimTf2N.csv')

# %%
constant(data2, configuration2, 'R125', 'emimTf2N', "x_R125", "x_emimTf2N",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = -0.007, init_kappa_1_2A = -0.011,
    eps = 0.1, scaling_fac = 1e-5)
# Out:
# 2022-03-08 13:36:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:36:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:36:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:36:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:36:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:36:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:36:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:36:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# ...

# %%
linear(data, configuration, 'R32', 'emimTf2N', "x_R32", "x_emimTf2N",
    init_temp =  298.15, init_press =   399400 , init_x_c1 =    0.417, init_x_c2 = 0.583,
    init_kappa_2_1A = -0.0496, init_kappa_1_2A = -0.023, init_kappa_2_1B = -0.0496, init_kappa_1_2B = -0.023,
    eps = 0.1, scaling_fac = 1e-5)
# Out:
# 2022-03-08 13:37:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:37:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:37:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:37:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:37:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:37:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:37:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 13:37:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# ...

# %%
linear(data2, configuration2, 'R125', 'emimTf2N', "x_R125", "x_emimTf2N",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = -0.007, init_kappa_1_2A = -0.011,init_kappa_2_1B = -0.0496, init_kappa_1_2B = -0.023,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-03-08 14:49:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 14:49:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 14:49:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 14:49:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 14:49:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 14:49:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 14:49:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-08 14:49:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# ...
