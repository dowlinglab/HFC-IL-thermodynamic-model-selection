# %%
from binary_param import linear, constant
import pandas as pd
from HFC32_hmimFAP_PR import configuration

# %%
data = pd.read_csv('R32_hmimFAP.csv')

# %%
constant(data, configuration, 'R32', 'hmimFAP', "x_R32", "x_hmimFAP",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = -0.05, init_kappa_1_2A = -0.03,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-02-22 16:47:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-22 16:47:23 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-02-22 16:47:24 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-02-22 16:47:25 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-02-22 16:47:26 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-02-22 16:47:27 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# ...

# %%
from HFC125_hmimFAP_PR import configuration as configuration2

# %%
data2 = pd.read_csv('R125_hmimFAP.csv')

# %%
constant(data2, configuration2, 'R125', 'hmimFAP', "x_R125", "x_hmimFAP",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = -0.20, init_kappa_1_2A = -0.016,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-02-22 16:47:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-22 16:47:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-22 16:47:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-22 16:47:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-22 16:47:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-22 16:47:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-22 16:47:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.13.2:
#
# ******************************************************************************
# ...
