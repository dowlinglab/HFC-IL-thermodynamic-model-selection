# %%
from pyomo.environ import (Constraint,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value)

from pyomo.network import Arc, SequentialDecomposition

from idaes.core.util.initialization import propagate_state

# Import plotting functions
import matplotlib.pyplot as plt

# Import numpy library 
import numpy as np

import pandas as pd

# Import the main FlowsheetBlock from IDAES. The flowsheet block will contain the unit model
from idaes.core import FlowsheetBlock

import idaes.logger as idaeslog
from pyomo.opt import TerminationCondition, SolverStatus

# Import the degrees_of_freedom function from the idaes.core.util.model_statistics package
# DOF = Number of Model Variables - Number of Model Constraints
from idaes.core.util.model_statistics import degrees_of_freedom

# Import the Generic Parameter Block
from idaes.generic_models.properties.core.generic.generic_property import (
        GenericParameterBlock)

# Import unit models from the model library
from idaes.generic_models.unit_models import Flash

# %%
from HFC125_bmimAc_PR import configuration
data = pd.read_csv('R125_bmimAc.csv')

solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6}

# %%
m = ConcreteModel()

m.fs = FlowsheetBlock(default={"dynamic": False})

m.fs.properties = GenericParameterBlock(default=configuration)

m.fs.F101 = Flash(default={"property_package": m.fs.properties,
                           "has_heat_transfer": True,
                           "has_pressure_change": True})

m.fs.F101.inlet.flow_mol.fix(1)
m.fs.F101.inlet.temperature.fix(323.15)
m.fs.F101.inlet.pressure.fix(399800)
m.fs.F101.inlet.mole_frac_comp[0,'R125'].fix(0.5)

m.fs.properties.PR_kappa_A['bmimAc', 'R125'].fix(-0.284997)
m.fs.properties.PR_kappa_A['R125', 'bmimAc'].fix(-0.112733)
m.fs.properties.PR_kappa_B['bmimAc', 'R125'].fix(0.0)
m.fs.properties.PR_kappa_B['R125', 'bmimAc'].fix(0.0)

# m.fs.properties.PR_kappa_A['bmimAc', 'R125'].fix(-0.00551)
# m.fs.properties.PR_kappa_A['R125', 'bmimAc'].fix(-0.00470)
# m.fs.properties.PR_kappa_B['bmimAc', 'R125'].fix(0.0)
# m.fs.properties.PR_kappa_B['R125', 'bmimAc'].fix(0.0)

# Initialize the flash unit
m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)

# Fix the state variables on the state block
# m.fs.F101.inlet.pressure.unfix()
m.fs.F101.inlet.mole_frac_comp[0,'bmimAc'].unfix()

# %%
bmim = np.linspace(data["x_bmimAc"].iloc[6], data["x_bmimAc"].iloc[0], 15)

P = np.zeros((len(bmim)))
P0 = np.zeros((len(bmim)))
R125_x1 = np.zeros((len(bmim)))
m.fs.liq = Param(mutable=True,default=0.040)
m.fs.liquid = Constraint(expr=m.fs.F101.liq_outlet.mole_frac_comp[0, "bmimAc"] == m.fs.liq)

for i in range(len(bmim)-1):
    print(i)
    m.fs.liq = bmim[i]
    a = bmim[i]
#     print(a)
    b = 1-(bmim[i])
#     print(b)
#     P0[i] = 1817227.28*b**2 + 1070035.75*b - 17132.62 for R32
    P0[i] = 1955312.94*b**2 - 19036.50*b + 63292.70
    print(P0[i])

    m.fs.F101.inlet.temperature.fix(298.001)
    m.fs.F101.inlet.pressure.fix(P0[i])
    m.fs.F101.inlet.mole_frac_comp[0,'R125'].fix(1-(bmim[i]-0.1))
    m.fs.F101.inlet.mole_frac_comp[0,'bmimAc'].fix(bmim[i]-0.1)
    m.fs.F101.vap_outlet.temperature.fix(298.001)
    m.fs.F101.vap_outlet.pressure.fix(P0[i])
    m.fs.F101.vap_outlet.pressure.unfix()
    
    m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)
    
    try:
        m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)

        status = solver.solve(m, tee = False)

        if (status.solver.status == SolverStatus.ok) and (status.solver.termination_condition == TerminationCondition.optimal):

            R125_x1[i] = value(m.fs.F101.liq_outlet.mole_frac_comp[0,'R125']) 
            P[i] = value(m.fs.F101.vap_outlet.pressure[0])

        else:
            print('Infeasible.')
            
    except ValueError:
        
            R125_x1[i] = "NaN"
            P[i] = "NaN"
# Out:
# 0
# 986448.4177001598
# 1
# 869128.9848413256
# 2
# 759778.928673783
# 3
# 658398.2491975314
# 4
# 564986.9464125715
# 5
# 479545.0203189029
# 6
# 402072.47091652587
# 7
# 332569.29820544017
# 8
# 271035.50218564586
# 9
# 217471.08285714296
# 10
# 171876.0402199315
# 11
# 134250.37427401147
# 12
# 104594.08501938288
# 13
# 82907.17245604574

# %%
print(P)
print(data["pressure"])
print(data["x_R125"])
# Out:
# [995820.11353869 862296.2349279  745017.64914148 642312.6224539
#  552223.78069626 472883.6483818  402643.06558565 340096.00125833
#  284063.59703578 233564.77320754 187784.94542145 146047.36287736
#  107788.47631057  72537.42648232      0.        ]
# 0      50000
# 1     100000
# 2     200000
# 3     400000
# 4     600000
# 5     800000
# 6    1000000
# Name: pressure, dtype: int64
# 0    0.060
# 1    0.122
# 2    0.240
# 3    0.429
# 4    0.536
# 5    0.620
# 6    0.692
# Name: x_R125, dtype: float64

# %%
P1 = np.zeros((len(P)))

for i in range(len(P)):
    P1[i] = P[i]/1e6

# P1[1] = 0.6888

plt.plot(R125_x1,P1,"-",label="Calc 298 K")  
plt.plot(data["x_R125"][0:8],data["pressure"][0:8]/1e6,"*",color='b',label="Data 298 K")  
plt.title('Isotherm R125-[bmim][Ac]',fontsize=20)
plt.ylabel('Pressure [MPa]',fontsize=20)
plt.xlabel('x R125 [mole/mole]',fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(True)
# plt.ylim(0,1.110000)
plt.xlim(0,1)
plt.legend(fontsize=10)
# plt.savefig('Isotherm R125-[bmim][Ac]_bin.png', bbox_inches='tight',dpi=300)
plt.show()

# %%
m.fs.F101.report()
# Out:
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Fixed : Bounds
#           Heat Duty :  359.07 : False : (None, None)
#     Pressure Change : -10370. : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                             Inlet  Vapor Outlet  Liquid Outlet
#     flow_mol               1.0000      0.11175     0.88825
#     mole_frac_comp bmimAc 0.79486   1.0000e-08     0.89486
#     mole_frac_comp R125   0.20514       1.0000     0.10514
#     temperature            298.00       298.00      298.00
#     pressure               82907.       72537.      72537.
# ====================================================================================

# %%
# print(P1)

# %%
df = pd.DataFrame(P)
# df.to_csv('P_cons_125.csv')
# df.to_csv('P_lin_125.csv')
# df.to_csv('P_ter_125.csv')

# %%
m.display()
# Out:
# Model unknown
#
#   Variables:
#     None
#
#   Objectives:
#     None
#
#   Constraints:
#     None
#
#   Blocks:
#     Block fs
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         liquid : Size=1
#             Key  : Lower              : Body               : Upper
#             None : 0.8948571428571428 : 0.8948571428571428 : 0.8948571428571428
#
#       Blocks:
#         Block fs.properties
#
#           Variables:
#             PR_kappa_A : PRA binary interaction parameters
#                 Size=4, Index=fs.properties.PR_kappa_A_index
#                 Key                  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     ('R125', 'R125') :  None :       0.0 :  None :  True :  True :  Reals
#                   ('R125', 'bmimAc') :  None : -0.112733 :  None :  True :  True :  Reals
#                   ('bmimAc', 'R125') :  None : -0.284997 :  None :  True :  True :  Reals
#                 ('bmimAc', 'bmimAc') :  None :       0.0 :  None :  True :  True :  Reals
#             PR_kappa_B : PRB binary interaction parameters
#                 Size=4, Index=fs.properties.PR_kappa_B_index
#                 Key                  : Lower : Value : Upper : Fixed : Stale : Domain
#                     ('R125', 'R125') :  None :   0.0 :  None :  True :  True :  Reals
#                   ('R125', 'bmimAc') :  None :   0.0 :  None :  True :  True :  Reals
#                   ('bmimAc', 'R125') :  None :   0.0 :  None :  True :  True :  Reals
#                 ('bmimAc', 'bmimAc') :  None :   0.0 :  None :  True :  True :  Reals
#             PR_kappa_C : PRC binary interaction parameters
#                 Size=4, Index=fs.properties.PR_kappa_C_index
#                 Key                  : Lower : Value : Upper : Fixed : Stale : Domain
#                     ('R125', 'R125') :  None :   0.0 :  None :  True :  True :  Reals
#                   ('R125', 'bmimAc') :  None :   0.0 :  None :  True :  True :  Reals
#                   ('bmimAc', 'R125') :  None :   0.0 :  None :  True :  True :  Reals
#                 ('bmimAc', 'bmimAc') :  None :   0.0 :  None :  True :  True :  Reals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#
#           Blocks:
#             Block fs.properties.Liq
#
#               Variables:
#                 None
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.Vap
#
#               Variables:
#                 None
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.bmimAc
#
#               Variables:
#                 pressure_crit : Size=1, Index=None, Units=kg/m/s**2
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 2500000.0 :  None :  True :  True :  Reals
#                 temperature_crit : Size=1, Index=None, Units=K
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None :  1000 :  None :  True :  True :  Reals
#                 omega : Size=1, Index=None
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None :   0.5 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_A : Parameter A for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K/mol
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 3259.5745 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_B : Parameter B for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**2/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : -28.561 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_C : Parameter C for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**3/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 0.09354 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_D : Parameter D for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**4/mol
#                     Key  : Lower : Value         : Upper : Fixed : Stale : Domain
#                     None :  None : -0.0001000673 :  None :  True :  True :  Reals
#                 enth_mol_form_vap_comp_ref : Vapor phase molar heat of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/mol/s**2
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 0.145 :  None :  True :  True :  Reals
#                 entr_mol_form_vap_comp_ref : Vapor phase molar entropy of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/K/mol/s**2
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 137.5 :  None :  True :  True :  Reals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.R125
#
#               Variables:
#                 pressure_crit : Size=1, Index=None, Units=kg/m/s**2
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 3629000.0 :  None :  True :  True :  Reals
#                 temperature_crit : Size=1, Index=None, Units=K
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : 339.16 :  None :  True :  True :  Reals
#                 omega : Size=1, Index=None
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 0.305 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_A : Parameter A for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 38.7614 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_B : Parameter B for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**2/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 0.78561 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_C : Parameter C for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**3/mol
#                     Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                     None :  None : -0.00468 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_D : Parameter D for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**4/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 9.09976 :  None :  True :  True :  Reals
#                 enth_mol_form_vap_comp_ref : Vapor phase molar heat of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/mol/s**2
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 22800.0 :  None :  True :  True :  Reals
#                 entr_mol_form_vap_comp_ref : Vapor phase molar entropy of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/K/mol/s**2
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : -269.0 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_A : Antoine A coefficient for calculating Psat
#                     Size=1, Index=None
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : 4.7694 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_B : Antoine B coefficient for calculating Psat
#                     Size=1, Index=None, Units=K
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 1153.2136 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_C : Antoine C coefficient for calculating Psat
#                     Size=1, Index=None, Units=K
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 19.5064 :  None :  True :  True :  Reals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#         Block fs.F101
#
#           Variables:
#             _flow_mol_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  1000 :  True :  True : NonNegativeReals
#             _mole_frac_comp_inlet_ref : Size=2, Index=fs.F101._mole_frac_comp_inlet_ref_index
#                 Key             : Lower : Value               : Upper : Fixed : Stale : Domain
#                   (0.0, 'R125') :     0 : 0.20514285714285718 :  None :  True :  True :  Reals
#                 (0.0, 'bmimAc') :     0 :  0.7948571428571428 :  None :  True :  True :  Reals
#             _temperature_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower : Value   : Upper : Fixed : Stale : Domain
#                 0.0 :    10 : 298.001 :   500 :  True :  True : NonNegativeReals
#             _pressure_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower  : Value             : Upper         : Fixed : Stale : Domain
#                 0.0 : 0.0005 : 82907.17245604574 : 10000000000.0 :  True :  True : NonNegativeReals
#             heat_duty : Size=1, Index=fs._time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 359.0685881299499 :  None : False : False :  Reals
#             deltaP : Size=1, Index=fs._time
#                 Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                 0.0 :  None : -10369.745973721601 :  None : False : False :  Reals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#
#           Blocks:
#             Block fs.F101.control_volume
#
#               Variables:
#                 heat : Heat transferred into control volume
#                     Size=1, Index=fs._time, Units=kg*m**2/s**3
#                     Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                     0.0 :  None : 359.0685881299499 :  None : False : False :  Reals
#                 deltaP : Pressure difference across unit
#                     Size=1, Index=fs._time, Units=kg/m/s**2
#                     Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                     0.0 :  None : -10369.745973721601 :  None : False : False :  Reals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 material_balances : Size=2
#                     Key             : Lower : Body                   : Upper
#                       (0.0, 'R125') :   0.0 : -7.105427357601002e-14 :   0.0
#                     (0.0, 'bmimAc') :   0.0 :  7.105427357601002e-14 :   0.0
#                 enthalpy_balances : Size=1
#                     Key : Lower : Body                 : Upper
#                     0.0 :   0.0 : 2.54414709388584e-06 :   0.0
#                 pressure_balance : Size=1
#                     Key : Lower : Body                   : Upper
#                     0.0 :   0.0 : -3.637978807091713e-12 :   0.0
#
#               Blocks:
#                 Block fs.F101.control_volume.properties_in[0.0]
#
#                   Variables:
#                     flow_mol :  Total molar flowrate
#                         Size=1, Index=None, Units=mol/s
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :     0 :     1 :  1000 :  True :  True : NonNegativeReals
#                     mole_frac_comp : Mixture mole fractions
#                         Size=2, Index=fs.properties.component_list
#                         Key    : Lower : Value               : Upper : Fixed : Stale : Domain
#                           R125 :     0 : 0.20514285714285718 :  None :  True :  True :  Reals
#                         bmimAc :     0 :  0.7948571428571428 :  None :  True :  True :  Reals
#                     pressure : State pressure
#                         Size=1, Index=None, Units=kg/m/s**2
#                         Key  : Lower  : Value             : Upper         : Fixed : Stale : Domain
#                         None : 0.0005 : 82907.17245604574 : 10000000000.0 :  True :  True : NonNegativeReals
#                     temperature : State temperature
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                         None :    10 : 298.001 :   500 :  True :  True : NonNegativeReals
#                     flow_mol_phase : Phase molar flow rates
#                         Size=2, Index=fs.properties.phase_list, Units=mol/s
#                         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                         Liq :     0 :  0.9020135663464822 :  1000 : False : False : NonNegativeReals
#                         Vap :     0 : 0.09798643365351781 :  1000 : False : False : NonNegativeReals
#                     mole_frac_phase_comp : Phase mole fractions
#                         Size=3, Index=fs.properties._phase_component_set
#                         Key               : Lower : Value               : Upper : Fixed : Stale : Domain
#                           ('Liq', 'R125') :     0 : 0.11879690892384911 :  None : False : False :  Reals
#                         ('Liq', 'bmimAc') :     0 :  0.8812030910761509 :  None : False : False :  Reals
#                           ('Vap', 'R125') :     0 :                 1.0 :  None : False : False :  Reals
#                     phase_frac : Phase fractions
#                         Size=2, Index=fs.properties.phase_list
#                         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                         Liq :     0 :  0.9020135663464822 :  None : False : False :  Reals
#                         Vap :     0 : 0.09798643365351781 :  None : False : False :  Reals
#                     _teq : Temperature for calculating phase equilibrium
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :  None : 298.0010013363605 :  None : False : False :  Reals
#                     _t1_Vap_Liq : Intermediate temperature for calculating Teq
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#                         None :  None : 298.0010013363605 :  None : False : False :  Reals
#                     temperature_bubble : Bubble point temperature
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :    10 : 279.2934746282529 :   500 : False : False :  Reals
#                     _mole_frac_tbub : Vapor mole fractions at bubble temperature
#                         Size=2, Index=fs.F101.control_volume.properties_in[0.0]._mole_frac_tbub_index
#                         Key                      : Lower : Value                 : Upper : Fixed : Stale : Domain
#                           ('Vap', 'Liq', 'R125') :     0 :                   1.0 :  None : False : False :  Reals
#                         ('Vap', 'Liq', 'bmimAc') :     0 : 4.235164736271502e-22 :  None : False : False :  Reals
#
#                   Objectives:
#                     None
#
#                   Constraints:
#                     total_flow_balance : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     component_flow_balances : Size=2
#                         Key    : Lower : Body : Upper
#                           R125 :   0.0 :  0.0 :   0.0
#                         bmimAc :   0.0 :  0.0 :   0.0
#                     sum_mole_frac : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     phase_fraction_constraint : Size=2
#                         Key : Lower : Body : Upper
#                         Liq :   0.0 :  0.0 :   0.0
#                         Vap :   0.0 :  0.0 :   0.0
#                     _t1_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body                  : Upper
#                         None :   0.0 : 5.684341886080802e-14 :   0.0
#                     eq_temperature_bubble : Size=2
#                         Key                      : Lower : Body                   : Upper
#                           ('Vap', 'Liq', 'R125') :   0.0 : -5.471179065352771e-13 :   0.0
#                         ('Vap', 'Liq', 'bmimAc') :   0.0 :  4.235164736271502e-22 :   0.0
#                     eq_mole_frac_tbub : Size=1
#                         Key            : Lower : Body : Upper
#                         ('Vap', 'Liq') :   1.0 :  1.0 :   1.0
#                     _teq_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     equilibrium_constraint : Size=1
#                         Key                    : Lower : Body                   : Upper
#                         ('Vap', 'Liq', 'R125') :   0.0 : 1.0294542995836764e-13 :   0.0
#                 Block fs.F101.control_volume.properties_out[0.0]
#
#                   Variables:
#                     flow_mol :  Total molar flowrate
#                         Size=1, Index=None, Units=mol/s
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :     0 :   1.0 :  1000 : False : False : NonNegativeReals
#                     mole_frac_comp : Mixture mole fractions
#                         Size=2, Index=fs.properties.component_list
#                         Key    : Lower : Value               : Upper : Fixed : Stale : Domain
#                           R125 :     0 : 0.20514285714285718 :  None : False : False :  Reals
#                         bmimAc :     0 :  0.7948571428571428 :  None : False : False :  Reals
#                     pressure : State pressure
#                         Size=1, Index=None, Units=kg/m/s**2
#                         Key  : Lower  : Value             : Upper         : Fixed : Stale : Domain
#                         None : 0.0005 : 72537.42648232414 : 10000000000.0 : False : False : NonNegativeReals
#                     temperature : State temperature
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                         None :    10 : 298.001 :   500 :  True :  True : NonNegativeReals
#                     flow_mol_phase : Phase molar flow rates
#                         Size=2, Index=fs.properties.phase_list, Units=mol/s
#                         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                         Liq :     0 :  0.8882503192847226 :  1000 : False : False : NonNegativeReals
#                         Vap :     0 : 0.11174968071527748 :  1000 : False : False : NonNegativeReals
#                     mole_frac_phase_comp : Phase mole fractions
#                         Size=3, Index=fs.properties._phase_component_set
#                         Key               : Lower : Value               : Upper : Fixed : Stale : Domain
#                           ('Liq', 'R125') :     0 : 0.10514285714285707 :  None : False : False :  Reals
#                         ('Liq', 'bmimAc') :     0 :  0.8948571428571428 :  None : False : False :  Reals
#                           ('Vap', 'R125') :     0 :  0.9999999999999999 :  None : False : False :  Reals
#                     phase_frac : Phase fractions
#                         Size=2, Index=fs.properties.phase_list
#                         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                         Liq :     0 :  0.8882503192847226 :  None : False : False :  Reals
#                         Vap :     0 : 0.11174968071527748 :  None : False : False :  Reals
#                     _teq : Temperature for calculating phase equilibrium
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :  None : 298.0010011180473 :  None : False : False :  Reals
#                     _t1_Vap_Liq : Intermediate temperature for calculating Teq
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#                         None :  None : 298.0010011180473 :  None : False : False :  Reals
#                     temperature_bubble : Bubble point temperature
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value              : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :    10 : 275.64058851403524 :   500 : False : False :  Reals
#                     _mole_frac_tbub : Vapor mole fractions at bubble temperature
#                         Size=2, Index=fs.F101.control_volume.properties_out[0.0]._mole_frac_tbub_index
#                         Key                      : Lower : Value                 : Upper : Fixed : Stale : Domain
#                           ('Vap', 'Liq', 'R125') :     0 :                   1.0 :  None : False : False :  Reals
#                         ('Vap', 'Liq', 'bmimAc') :     0 : 4.235164736271502e-22 :  None : False : False :  Reals
#
#                   Objectives:
#                     None
#
#                   Constraints:
#                     sum_mole_frac_out : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   1.0 :  1.0 :   1.0
#                     total_flow_balance : Size=1
#                         Key  : Lower : Body                  : Upper
#                         None :   0.0 : 2.220446049250313e-16 :   0.0
#                     component_flow_balances : Size=2
#                         Key    : Lower : Body                   : Upper
#                           R125 :   0.0 : -7.105427357601002e-14 :   0.0
#                         bmimAc :   0.0 :  7.105427357601002e-14 :   0.0
#                     sum_mole_frac : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     phase_fraction_constraint : Size=2
#                         Key : Lower : Body : Upper
#                         Liq :   0.0 :  0.0 :   0.0
#                         Vap :   0.0 :  0.0 :   0.0
#                     _t1_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     eq_temperature_bubble : Size=2
#                         Key                      : Lower : Body                   : Upper
#                           ('Vap', 'Liq', 'R125') :   0.0 : -6.935074736702518e-11 :   0.0
#                         ('Vap', 'Liq', 'bmimAc') :   0.0 :  4.235164736271502e-22 :   0.0
#                     eq_mole_frac_tbub : Size=1
#                         Key            : Lower : Body : Upper
#                         ('Vap', 'Liq') :   1.0 :  1.0 :   1.0
#                     _teq_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     equilibrium_constraint : Size=1
#                         Key                    : Lower : Body                  : Upper
#                         ('Vap', 'Liq', 'R125') :   0.0 : 2.306860258372012e-11 :   0.0
#             Block fs.F101.split
#
#               Variables:
#                 _flow_mol_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                     0.0 :     0 :   1.0 :  1000 : False : False : NonNegativeReals
#                 _mole_frac_comp_inlet_ref : Size=2, Index=fs.F101.split._mole_frac_comp_inlet_ref_index
#                     Key             : Lower : Value               : Upper : Fixed : Stale : Domain
#                       (0.0, 'R125') :     0 : 0.20514285714285718 :  None : False : False :  Reals
#                     (0.0, 'bmimAc') :     0 :  0.7948571428571428 :  None : False : False :  Reals
#                 _temperature_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower : Value   : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 298.001 :   500 :  True :  True : NonNegativeReals
#                 _pressure_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value             : Upper         : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 72537.42648232414 : 10000000000.0 : False : False : NonNegativeReals
#                 _Vap_temperature_ref : Size=1, Index=fs._time
#                     Key : Lower : Value   : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 298.001 :   500 :  True :  True : NonNegativeReals
#                 _Vap_pressure_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value             : Upper         : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 72537.42648232414 : 10000000000.0 : False : False : NonNegativeReals
#                 _Liq_temperature_ref : Size=1, Index=fs._time
#                     Key : Lower : Value   : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 298.001 :   500 :  True :  True : NonNegativeReals
#                 _Liq_pressure_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value             : Upper         : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 72537.42648232414 : 10000000000.0 : False : False : NonNegativeReals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
