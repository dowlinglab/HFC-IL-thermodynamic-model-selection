# %%
from binary_param import linear, constant
import pandas as pd
from HFC32_bmimPF6_PR import configuration

# %%
data = pd.read_csv('R32IL.csv')

# %%
constant(data, configuration, 'R32', 'bmimPF6', "x_R32", "x_bmimPF6",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 0.5, init_kappa_1_2A = 0.3,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-20 13:54:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:22 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-20 13:54:23 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-20 13:54:23 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# ...

# %%
from HFC125_bmimPF6_PR import configuration as configuration2

# %%
data2 = pd.read_csv('R125IL.csv')

# %%
constant(data2, configuration2, 'R125', 'bmimPF6', "x_R125", "x_bmimPF6",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 0.05, init_kappa_1_2A = 0.03,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-20 13:54:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:54:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# ...
