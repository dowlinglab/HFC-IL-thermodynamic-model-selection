# %%
from binary_param import linear, constant
import pandas as pd
from HFC32_bmimBF4_PR import configuration

# %%
data = pd.read_csv('R32_bmimBF4.csv')

# %%
constant(data, configuration, 'R32', 'bmimBF4', "x_R32", "x_bmimBF4",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = -0.05, init_kappa_1_2A = -0.03,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-20 13:14:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# ...

# %%
from HFC125_bmimBF4_PR import configuration as configuration2

# %%
data2 = pd.read_csv('R125_bmimBF4.csv')

# %%
constant(data2, configuration2, 'R125', 'bmimBF4', "x_R125", "x_bmimBF4",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 0.05, init_kappa_1_2A = 0.03,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-20 13:14:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:40 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-20 13:14:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 13:14:42 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# Ipopt 3.13.2:
#
# ...
