# %%
import pandas as pd
import numpy as np
from HFC125_hmimCl_PR import configuration
from pyomo.environ import (ConcreteModel,
                           SolverFactory,
                           units as pyunits)

import idaes.logger as idaeslog
import pyomo.contrib.parmest.parmest as parmest

import pytest

from idaes.core import FlowsheetBlock
from idaes.generic_models.properties.core.generic.generic_property import (
        GenericParameterBlock)

from idaes.core.util.model_statistics import degrees_of_freedom

# %%
def PR_model(data):
    """
    Function which returns initilized model.

    Args:
        data: pandas DataFrame with data

    Returns:
        initialized model
    """
    eps = 0.1
    init_kappa_2_1A = -0.05
    init_kappa_1_2A = -0.05
    m = ConcreteModel()

    m.fs = FlowsheetBlock(default={"dynamic": False})

    m.fs.properties = GenericParameterBlock(default=configuration)

    m.fs.state_block = m.fs.properties.state_block_class(
        default={"parameters": m.fs.properties,
                 "defined_state": True})
    x = float(data['x_R125'])+eps
    m.fs.state_block.flow_mol.fix(1)
    m.fs.state_block.temperature.fix(float(data["temperature"]))
    m.fs.state_block.pressure.fix(float(data["pressure"]))
    m.fs.state_block.mole_frac_comp['hmimCl'].fix(1-x)
    m.fs.state_block.mole_frac_comp['R125'].fix(x)

    # parameter - kappa_A_ij (set at 0.3, 0 if i=j)
    m.fs.properties.PR_kappa_A['hmimCl','hmimCl'].fix(0)
    m.fs.properties.PR_kappa_A['hmimCl', 'R125'].fix(init_kappa_2_1A)
    m.fs.properties.PR_kappa_A['R125', 'R125'].fix(0)
    m.fs.properties.PR_kappa_A['R125', 'hmimCl'].fix(init_kappa_1_2A)
    m.fs.properties.PR_kappa_B['hmimCl', 'hmimCl'].fix(0)
    m.fs.properties.PR_kappa_B['hmimCl', 'R125'].fix(0)
    m.fs.properties.PR_kappa_B['R125', 'R125'].fix(0)
    m.fs.properties.PR_kappa_B['R125', 'hmimCl'].fix(0)
    m.fs.properties.PR_kappa_C['hmimCl', 'hmimCl'].fix(0)
    m.fs.properties.PR_kappa_C['hmimCl', 'R125'].fix(0)
    m.fs.properties.PR_kappa_C['R125', 'R125'].fix(0)
    m.fs.properties.PR_kappa_C['R125', 'hmimCl'].fix(0)
    # Initialize the flash unit
    m.fs.state_block.initialize(outlvl=idaeslog.CRITICAL)

    # Fix the state variables on the state block
    m.fs.state_block.pressure.unfix()
    m.fs.state_block.mole_frac_comp['hmimCl'].unfix()
    m.fs.state_block.mole_frac_comp['R125'].unfix()
    m.fs.state_block.temperature.fix(float(data["temperature"]))
    m.fs.state_block.mole_frac_phase_comp['Liq', 'R125'].fix(float(data['x_R125']))
    m.fs.state_block.mole_frac_phase_comp['Liq', 'hmimCl'].fix(float(data['x_hmimCl']))
    m.fs.state_block.mole_frac_comp['R125'].fix(float(data['x_R125'])+eps)
    m.fs.state_block.mole_frac_comp['hmimCl'].unfix()

    # Set bounds on variables to be estimated
    m.fs.properties.PR_kappa_A['hmimCl', 'R125'].setlb(-5)
    m.fs.properties.PR_kappa_A['hmimCl', 'R125'].setub(5)

    m.fs.properties.PR_kappa_A['R125', 'hmimCl'].setlb(-5)
    m.fs.properties.PR_kappa_A['R125', 'hmimCl'].setub(5)

    # Return initialized flash model
    return m

def SSE(m, data):
    """
    returns objective function expresion.

    Args:
        m: model
        data: pandas DataFrame with data

    Returns:
        objectuve function scaled expresion
    """
    expr = ((float(data["pressure"]) - m.fs.state_block.pressure)**2)

    return expr * 1e-6

variable_name = ["fs.properties.PR_kappa_A['hmimCl', 'R125']",
                 "fs.properties.PR_kappa_A['R125', 'hmimCl']"]

# %%
data = pd.read_csv('R125_hmimCl.csv')

print(data)
# Out:
#    temperature  pressure  x_R125  x_hmimCl
# 0       298.15     50000   0.040     0.960
# 1       298.15    100000   0.079     0.921
# 2       298.15    200000   0.160     0.840
# 3       298.15    400000   0.290     0.710
# 4       298.15    600000   0.414     0.586
# 5       298.15    800000   0.543     0.457
# 6       298.15   1000000   0.654     0.346

# %%
N = 100 #number of samples
results_params = np.zeros((N,2))
results_obj = np.zeros((N,1))

st_dev_T = 0.01 #C
st_dev_P = 9771 #MPa
st_dev_x = 0.10 #mole fraction

for i in range(N):
    print(i)
    noise_x = np.random.normal(loc=0,scale=st_dev_x)
    print(noise_x)
    data_ = data.copy()
    data_["x_hmimCl"] += data_["x_hmimCl"] * noise_x
    data_.loc[data_['x_hmimCl'] <= 0.0001, 'x_hmimCl'] = 0.0001
    data_.loc[data_['x_hmimCl'] >= 0.9999 , 'x_hmimCl'] = 0.9999      

    try:
        pest = parmest.Estimator(PR_model, data_, variable_name, SSE, tee=False)

        obj_value, parameters = pest.theta_est()

        for k,v in parameters.items():
            print(k, "=", v)

        line = 0

        for k,v in parameters.items():
            results_params[i,line] = v
            line += 1
        results_obj[i] = obj_value

    except ValueError:
        results_params[i,0] = 'NaN'
        results_params[i,1] = 'NaN'
# Out:
# 0
# -0.13297316939561651
# 2022-03-06 15:29:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.07622286461872735
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.05747699310951432
# 1
# 0.006090203872051765
# 2022-03-06 15:29:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="_Q_opt";
#       - termination condition: infeasible
#       - message from solver: Ipopt 3.13.2\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.0631421014104397
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.04819997796533704
# 2
# 0.11809523325984095
# 2022-03-06 15:29:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="_Q_opt";
#       - termination condition: infeasible
#       - message from solver: Ipopt 3.13.2\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.05935726207651149
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.04930459360753319
# 3
# 0.05311646549233663
# 2022-03-06 15:29:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:29:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="_Q_opt";
#       - termination condition: infeasible
#       - message from solver: Ipopt 3.13.2\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.062205594383028195
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.0488015340139867
# 4
# 0.14064387902018727
# 2022-03-06 15:30:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="_Q_opt";
#       - termination condition: infeasible
#       - message from solver: Ipopt 3.13.2\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.05828894904261986
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.04944658779154557
# 5
# 0.02560153508618971
# 2022-03-06 15:30:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="_Q_opt";
#       - termination condition: infeasible
#       - message from solver: Ipopt 3.13.2\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.06306544650249023
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.04850446876661449
# 6
# -0.07473101262046213
# 2022-03-06 15:30:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.06706132841255029
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.052719814373760214
# 7
# 0.1035939590486184
# 2022-03-06 15:30:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="_Q_opt";
#       - termination condition: infeasible
#       - message from solver: Ipopt 3.13.2\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.06006196955361753
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.049210588110137087
# 8
# 0.01776349683612649
# 2022-03-06 15:30:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-03-06 15:30:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="_Q_opt";
#       - termination condition: infeasible
#       - message from solver: Ipopt 3.13.2\x3a Converged to a locally
#         infeasible point. Problem may be infeasible.
# fs.properties.PR_kappa_A[hmimCl,R125] = -0.0631905513133734
# fs.properties.PR_kappa_A[R125,hmimCl] = -0.