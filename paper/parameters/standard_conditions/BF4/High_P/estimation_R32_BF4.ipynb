# %%
from binary_param import linear, constant
import pandas as pd
from R32_bmimBF4_PR import configuration

# %%
data = pd.read_csv('R32_bmimBF4.csv')
print(data)
# 283
data_283= data[(data.temperature > 282) & (data.temperature< 284)]

# 298
data_298 = data[(data.temperature > 297) & (data.temperature< 299)]
data_298 = data_298.reset_index(drop=True)

# 323
data_323 = data[(data.temperature > 322) & (data.temperature< 324)]
data_323 = data_323.reset_index(drop=True)

# 323
data_348 = data[(data.temperature > 347) & (data.temperature< 349)]
data_348 = data_348.reset_index(drop=True)
# Out:
#     temperature  pressure  x_R32  x_bmimBF4
# 0         283.1     10000  0.009      0.991
# 1         283.1     99800  0.099      0.901
# 2         283.2    249900  0.241      0.759
# 3         283.2    399500  0.374      0.626
# 4         283.0    549900  0.501      0.499
# 5         283.1    699900  0.627      0.373
# 6         283.1    849700  0.759      0.241
# 7         298.2      9700  0.007      0.993
# 8         298.2     99700  0.071      0.929
# 9         298.2    249600  0.175      0.825
# 10        298.2    399900  0.272      0.728
# 11        298.2    549800  0.359      0.641
# 12        298.2    699600  0.438      0.562
# 13        298.2    849500  0.515      0.485
# 14        298.2    999900  0.588      0.412
# 15        323.2      9800  0.004      0.996
# 16        323.1     99600  0.040      0.960
# 17        323.2    249700  0.099      0.901
# 18        323.2    399600  0.154      0.846
# 19        323.1    549600  0.206      0.794
# 20        323.1    699500  0.255      0.745
# 21        323.0    849900  0.301      0.699
# 22        323.2    999600  0.345      0.655
# 23        348.2      9700  0.002      0.998
# 24        348.1     99600  0.024      0.976
# 25        348.1    249500  0.058      0.942
# 26        348.2    399500  0.092      0.908
# 27        348.1    549500  0.125      0.875
# 28        348.2    699600  0.156      0.844
# 29        348.1    849600  0.186      0.814
# 30        348.1    999900  0.214      0.786

# %%
linear(data, configuration, 'R32', 'bmimBF4', "x_R32", "x_bmimBF4",
    init_temp =  283.1, init_press =   399300 , init_x_c1 =    0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 1.2354, init_kappa_1_2A = 0.1695,
    init_kappa_2_1B = -1.387, init_kappa_1_2B = -0.2075, eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-26 15:42:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:36 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-26 15:42:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:42:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1294
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1643
#
# Total number of variables............................:      496
#                      variables with only lower bounds:      186
#                 variables with lower and upper bounds:      248
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      492
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 7.95e+00 2.84e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa_A[R32,bmimBF4] = 0.006454845744195051
# fs.properties.PR_kappa_A[bmimBF4,R32] = 0.026944479280841094
# fs.properties.PR_kappa_B[R32,bmimBF4] = -0.05512744444989291
# fs.properties.PR_kappa_B[bmimBF4,R32] = -0.07896471900849697

# %%
constant(data, configuration, 'R32', 'bmimBF4', "x_R32", "x_bmimBF4",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 0.1, init_kappa_1_2A = 0.10,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-26 15:49:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:51 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-26 15:49:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:49:57 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-26 15:49:58 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-26 15:49:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:50:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1050
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1054
#
# Total number of variables............................:      434
#                      variables with only lower bounds:      186
#                 variables with lower and upper bounds:      186
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      432
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.61e+00 3.35e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  8.7006203e-01 2.75e-01 6.09e+04  -1.0 1.04e+05    -  4.66e-01 9.90e-01h  1
#    2  3.4085068e-01 8.23e-03 3.76e+02  -1.0 9.15e+04    -  6.14e-01 9.90e-01h  1
#    3  3.3189946e-01 2.92e-05 1.75e+03  -1.0 6.39e+03    -  9.82e-01 1.00e+00h  1
#    4  3.3153695e-01 2.90e-08 9.90e+04  -1.0 2.05e+02    -  9.90e-01 1.00e+00h  1
#    5  3.2220732e-01 4.05e-05 9.90e+02  -1.0 7.67e+03    -  9.90e-01 1.00e+00f  1
#    6  3.1046440e-01 3.49e-05 2.74e+04  -2.5 6.10e+03    -  9.97e-01 1.00e+00f  1
#    7  3.1043344e-01 9.15e-09 3.71e+01  -2.5 9.14e+01    -  9.99e-01 1.00e+00h  1
#    8  3.1043344e-01 7.14e-12 2.83e-08  -2.5 1.34e-02    -  1.00e+00 1.00e+00h  1
#    9  3.1042516e-01 4.66e-08 1.63e+01  -8.6 1.84e+02    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.1042520e-01 1.15e-11 3.15e-14  -8.6 3.52e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.1042519820607567e-01    3.1042519820607567e-01
# Dual infeasibility......:   3.1506526853849226e-14    3.1506526853849226e-14
# Constraint violation....:   1.1519674103510624e-11    1.1519674103510624e-11
# Complementarity.........:   2.5059468154079154e-09    2.5059468154079154e-09
# Overall NLP error.......:   2.5059468154079154e-09    2.5059468154079154e-09
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.034
# Total CPU secs in NLP function evaluations           =      0.243
#
# EXIT: Optimal Solution Found.
# The SSE at the optimal solution is 0.310425
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa_A[bmimBF4,R32] = -0.10438425436270532
# fs.properties.PR_kappa_A[R32,bmimBF4] = -0.05529989858696247
