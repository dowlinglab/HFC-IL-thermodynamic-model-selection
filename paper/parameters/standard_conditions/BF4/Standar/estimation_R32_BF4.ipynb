# %%
from binary_param import linear, constant
import pandas as pd
from R32_bmimBF4_PR import configuration

# %%
data = pd.read_csv('R32_bmimBF4.csv')
print(data)
# 283
data_283= data[(data.temperature > 282) & (data.temperature< 284)]

# 298
data_298 = data[(data.temperature > 297) & (data.temperature< 299)]
data_298 = data_298.reset_index(drop=True)

# 323
data_323 = data[(data.temperature > 322) & (data.temperature< 324)]
data_323 = data_323.reset_index(drop=True)

# 323
data_348 = data[(data.temperature > 347) & (data.temperature< 349)]
data_348 = data_348.reset_index(drop=True)
# Out:
#     temperature  pressure  x_R32  x_bmimBF4
# 0         283.1     10000  0.009      0.991
# 1         283.1     99800  0.099      0.901
# 2         283.2    249900  0.241      0.759
# 3         283.2    399500  0.374      0.626
# 4         283.0    549900  0.501      0.499
# 5         283.1    699900  0.627      0.373
# 6         283.1    849700  0.759      0.241
# 7         298.2      9700  0.007      0.993
# 8         298.2     99700  0.071      0.929
# 9         298.2    249600  0.175      0.825
# 10        298.2    399900  0.272      0.728
# 11        298.2    549800  0.359      0.641
# 12        298.2    699600  0.438      0.562
# 13        298.2    849500  0.515      0.485
# 14        298.2    999900  0.588      0.412
# 15        323.2      9800  0.004      0.996
# 16        323.1     99600  0.040      0.960
# 17        323.2    249700  0.099      0.901
# 18        323.2    399600  0.154      0.846
# 19        323.1    549600  0.206      0.794
# 20        323.1    699500  0.255      0.745
# 21        323.0    849900  0.301      0.699
# 22        323.2    999600  0.345      0.655
# 23        348.2      9700  0.002      0.998
# 24        348.1     99600  0.024      0.976
# 25        348.1    249500  0.058      0.942
# 26        348.2    399500  0.092      0.908
# 27        348.1    549500  0.125      0.875
# 28        348.2    699600  0.156      0.844
# 29        348.1    849600  0.186      0.814
# 30        348.1    999900  0.214      0.786

# %%
linear(data, configuration, 'R32', 'bmimBF4', "x_R32", "x_bmimBF4",
    init_temp =  283.1, init_press =   399300 , init_x_c1 =    0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 1.2354, init_kappa_1_2A = 0.1695,
    init_kappa_2_1B = -1.387, init_kappa_1_2B = -0.2075, eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-26 15:45:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:45:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:45:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:45:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:45:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:45:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:45:57 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-26 15:45:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:45:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1294
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1643
#
# Total number of variables............................:      496
#                      variables with only lower bounds:      186
#                 variables with lower and upper bounds:      248
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      492
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.22e-01 2.84e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.8451262e-03 5.61e-01 8.71e+02  -1.0 3.69e+04    -  6.05e-01 1.13e-01h  1
#    2  5.5657319e-02 7.81e+00 3.43e+03  -1.0 2.90e+04    -  8.43e-01 4.95e-01h  2
#    3  9.0322961e-02 4.06e+00 1.98e+03  -1.0 1.52e+04    -  5.46e-02 4.95e-01h  2
#    4  1.7437537e-01 3.32e+00 4.64e+02  -1.0 1.35e+04    -  8.37e-03 9.90e-01h  1
#    5  1.7647773e-01 1.65e+00 7.30e+02  -1.0 2.30e+03    -  8.25e-01 9.90e-01h  1
#    6  1.8581270e-01 7.07e-01 1.75e+05  -1.0 4.70e+03    -  5.91e-01 1.00e+00h  1
#    7  1.9242051e-01 2.33e-01 1.24e+05  -1.0 2.24e+03    -  9.87e-01 1.00e+00h  1
#    8  2.3694466e-01 1.33e-01 3.65e+03  -1.0 1.77e+04    -  9.71e-01 5.00e-01f  2
#    9  2.3779691e-01 1.29e-01 7.67e+06  -1.7 1.63e+04    -  9.90e-01 3.12e-02h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2
-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.3478043e-01 1.01e-11 2.16e-13  -8.6 9.39e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 40
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.3478043459216321e-01    1.3478043459216321e-01
# Dual infeasibility......:   2.1646107742453775e-13    2.1646107742453775e-13
# Constraint violation....:   1.0147438445073931e-11    1.0147438445073931e-11
# Complementarity.........:   2.5059043301605680e-09    2.5059043301605680e-09
# Overall NLP error.......:   2.5059043301605680e-09    2.5059043301605680e-09
#
#
# Number of objective function evaluations             = 181
# Number of objective gradient evaluations             = 41
# Number of equality constraint evaluations            = 181
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 42
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 40
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.118
# Total CPU secs in NLP function evaluations           =      2.143
#
# EXIT: Optimal Solution Found.
# The SSE at the optimal solution is 0.134780
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa_A[R32,bmimBF4] = -0.025878810010696997
# fs.properties.PR_kappa_A[bmimBF4,R32] = -0.00740611787754728
# fs.properties.PR_kappa_B[R32,bmimBF4] = 0.016844410579314056
# fs.properties.PR_kappa_B[bmimBF4,R32] = -0.040942302827882235

# %%
constant(data, configuration, 'R32', 'bmimBF4', "x_R32", "x_bmimBF4",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 0.1, init_kappa_1_2A = 0.10,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-26 15:46:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:30 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-26 15:46:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-26 15:46:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1050
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1054
#
# Total number of variables............................:      434
#                      variables with only lower bounds:      186
#                 variables with lower and upper bounds:      186
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      432
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 9.84e-01 2.84e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.7828924e-01 8.83e-02 8.20e+02  -1.0 4.27e+04    -  3.14e-02 9.90e-01h  1
#    2  1.8281870e-01 4.26e-04 1.10e+01  -1.0 6.63e+02    -  9.79e-01 9.90e-01h  1
#    3  1.8279565e-01 1.94e-08 1.00e+03  -1.0 2.38e+01    -  9.90e-01 1.00e+00h  1
#    4  1.7773495e-01 6.44e-06 1.14e+05  -1.0 1.95e+03    -  9.88e-01 1.00e+00f  1
#    5  1.8193603e-01 1.58e-04 1.13e+03  -1.0 9.69e+03    -  9.90e-01 1.00e+00f  1
#    6  1.7335367e-01 4.53e-05 2.63e+04  -2.5 5.45e+03    -  9.97e-01 1.00e+00h  1
#    7  1.7336454e-01 1.74e-09 2.84e-08  -2.5 3.75e+01    -  1.00e+00 1.00e+00h  1
#    8  1.7335631e-01 4.81e-08 1.90e+01  -8.6 1.75e+02    -  1.00e+00 1.00e+00h  1
#    9  1.7335633e-01 7.65e-12 2.63e-14  -8.6 3.52e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.7335632994365041e-01    1.7335632994365041e-01
# Dual infeasibility......:   2.6251166936046112e-14    2.6251166936046112e-14
# Constraint violation....:   7.6472161936180783e-12    7.6472161936180783e-12
# Complementarity.........:   2.5059520386498349e-09    2.5059520386498349e-09
# Overall NLP error.......:   2.5059520386498349e-09    2.5059520386498349e-09
#
#
# Number of objective function evaluations             = 10
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 10
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.028
# Total CPU secs in NLP function evaluations           =      0.222
#
# EXIT: Optimal Solution Found.
# The SSE at the optimal solution is 0.173356
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa_A[bmimBF4,R32] = -0.02825362421913725
# fs.properties.PR_kappa_A[R32,bmimBF4] = -0.006843707623581316
