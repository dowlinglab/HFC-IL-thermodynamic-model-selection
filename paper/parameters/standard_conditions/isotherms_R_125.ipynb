# %%
from pyomo.environ import (Constraint,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value)

from pyomo.network import Arc, SequentialDecomposition

from idaes.core.util.initialization import propagate_state

# Import plotting functions
import matplotlib.pyplot as plt

# Import numpy library 
import numpy as np

import pandas as pd

# Import the main FlowsheetBlock from IDAES. The flowsheet block will contain the unit model
from idaes.core import FlowsheetBlock

import idaes.logger as idaeslog
from pyomo.opt import TerminationCondition, SolverStatus

# Import the degrees_of_freedom function from the idaes.core.util.model_statistics package
# DOF = Number of Model Variables - Number of Model Constraints
from idaes.core.util.model_statistics import degrees_of_freedom

# Import the Generic Parameter Block
from idaes.generic_models.properties.core.generic.generic_property import (
        GenericParameterBlock)

# Import unit models from the model library
from idaes.generic_models.unit_models import Flash

# %%
from R125_bmimPF6_PR import configuration
data = pd.read_csv('R125IL.csv')

solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6}

# %%
m = ConcreteModel()

m.fs = FlowsheetBlock(default={"dynamic": False})

m.fs.properties = GenericParameterBlock(default=configuration)

m.fs.F101 = Flash(default={"property_package": m.fs.properties,
                           "has_heat_transfer": True,
                           "has_pressure_change": True})

m.fs.F101.inlet.flow_mol.fix(1)
m.fs.F101.inlet.temperature.fix(323.15)
m.fs.F101.inlet.pressure.fix(399800)
m.fs.F101.inlet.mole_frac_comp[0,'R125'].fix(0.5)

# m.fs.properties.PR_kappa_A['bmimPF6', 'R125'].fix(-1.195988)
# m.fs.properties.PR_kappa_A['R125', 'bmimPF6'].fix(-0.08814)
# m.fs.properties.PR_kappa_B['bmimPF6', 'R125'].fix(1.56874)
# m.fs.properties.PR_kappa_B['R125', 'bmimPF6'].fix(0.08489)

m.fs.properties.PR_kappa_A['bmimPF6', 'R125'].fix(0.28636)
m.fs.properties.PR_kappa_A['R125', 'bmimPF6'].fix(-0.00356)
m.fs.properties.PR_kappa_B['bmimPF6', 'R125'].fix(0.0)
m.fs.properties.PR_kappa_B['R125', 'bmimPF6'].fix(0.0)

# Initialize the flash unit
m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)

# Fix the state variables on the state block
# m.fs.F101.inlet.pressure.unfix()
m.fs.F101.inlet.mole_frac_comp[0,'bmimPF6'].unfix()

R125_x = np.zeros((len(data)))
P = np.zeros((len(data)))

m.fs.liq = Param(mutable=True,default=0.040)
m.fs.liquid = Constraint(expr=m.fs.F101.liq_outlet.mole_frac_comp[0, "bmimPF6"] == m.fs.liq)

for i in range(len(data)):
    m.fs.liq = data["x_bmimPF6"].iloc[i]
    m.fs.F101.inlet.temperature.fix(float(data["temperature"].iloc[i]))
    m.fs.F101.inlet.pressure.fix(float(data["pressure"].iloc[i]))
    m.fs.F101.inlet.mole_frac_comp[0,'R125'].fix(float(data["x_R125"].iloc[i])+0.05)
    m.fs.F101.inlet.mole_frac_comp[0,'bmimPF6'].fix(float(1-(data["x_R125"].iloc[i]+0.05)))
    m.fs.F101.vap_outlet.temperature.fix(float(data["temperature"].iloc[i]))
    
    print("x =", data["x_bmimPF6"].iloc[i])
    
    try:
        
        m.fs.F101.initialize(outlvl=idaeslog.CRITICAL)
        status = solver.solve(m, tee = False)

        if (status.solver.status == SolverStatus.ok) and (status.solver.termination_condition == TerminationCondition.optimal):

            R125_x[i] = value(m.fs.F101.liq_outlet.mole_frac_comp[0,'R125']) 
            P[i] = value(m.fs.F101.vap_outlet.pressure[0])

        else:
            print('Infeasible.')

    except ValueError:

        R125_x[i] = 'NaN'
        P[i] = 'NaN'
# Out:
# x = 0.987
# x = 0.966
# x = 0.925
# x = 0.874
# x = 0.815
# x = 0.745
# x = 0.658
# x = 0.538
# x = 0.977
# x = 0.95
# x = 0.92
# x = 0.889
# x = 0.857
# x = 0.82
# x = 0.739
# x = 0.637
# x = 0.987
# x = 0.972
# x = 0.958
# x = 0.943
# x = 0.928
# x = 0.913
# x = 0.88
# x = 0.846
# x = 0.993
# x = 0.984
# x = 0.975
# x = 0.967
# x = 0.957
# x = 0.947
# x = 0.93
# x = 0.912

# %%
print(P)
print(data["pressure"])
print(R125_x)
print(data["x_R125"])
# Out:
# [  33492.51578893   86790.53167279  187111.97865225  302153.87719759
#   423307.54659128  540272.70584127  652144.31409459  725571.54404927
#    87063.31850117  187249.34379837  294882.84919507  403834.5403917
#   510896.54456284  627895.67860284  853111.09390904 1057454.88580155
#    84794.63326403  182519.28395884  274110.03266962  370874.0980818
#   468817.52052781  564457.95789385  775133.5419152   988643.65304606
#    70923.402203    162773.66246201  255378.77946518  337303.62073867
#   440735.12029522  544738.28556017  724073.35278327  913304.29126708]
# 0       9900
# 1      99600
# 2     199600
# 3     299600
# 4     399600
# 5     499700
# 6     599700
# 7     699600
# 8      99600
# 9     199800
# 10    299500
# 11    399800
# 12    499500
# 13    599500
# 14    799600
# 15    999800
# 16     99600
# 17    199800
# 18    300000
# 19    399700
# 20    499900
# 21    599600
# 22    799700
# 23    999600
# 24     99700
# 25    199600
# 26    299700
# 27    399700
# 28    499800
# 29    599800
# 30    800000
# 31    999600
# Name: pressure, dtype: int64
# [0.013 0.034 0.075 0.126 0.185 0.255 0.342 0.462 0.023 0.05  0.08  0.111
#  0.143 0.18  0.261 0.363 0.013 0.028 0.042 0.057 0.072 0.087 0.12  0.154
#  0.007 0.016 0.025 0.033 0.043 0.053 0.07  0.088]
# 0     0.013
# 1     0.034
# 2     0.075
# 3     0.126
# 4     0.185
# 5     0.255
# 6     0.342
# 7     0.462
# 8     0.023
# 9     0.050
# 10    0.080
# 11    0.111
# 12    0.143
# 13    0.180
# 14    0.261
# 15    0.363
# 16    0.013
# 17    0.028
# 18    0.042
# 19    0.057
# 20    0.072
# 21    0.087
# 22    0.120
# 23    0.154
# 24    0.007
# 25    0.016
# 26    0.025
# 27    0.033
# 28    0.043
# 29    0.053
# 30    0.070
# 31    0.088
# Name: x_R125, dtype: float64

# %%
# for i in range(len(P)):
#     P[i] = P[i]*1e6
P1= np.zeros((len(P)))

for i in range(len(P)):
    P1[i] = P[i]/1e6

    
plt.plot(R125_x[0:8],P1[0:8],"b",label="Calc 283 K")  
plt.plot(R125_x[8:16],P1[8:16],"r",label="Calc 298 K") 
plt.plot(R125_x[16:24],P1[16:24],"c",label="Calc 323 K") 
plt.plot(R125_x[24:],P1[24:],"m",label="Calc 348 K")
plt.plot(data["x_R125"][0:8],data["pressure"][0:8]/1e6,"*",color='b',label="Data 283 K")  
plt.plot(data["x_R125"][8:16],data["pressure"][8:16]/1e6,"*",color='r',label="Data 298 K") 
plt.plot(data["x_R125"][16:24],data["pressure"][16:24]/1e6,"*",color='c',label="Data 323 K") 
plt.plot(data["x_R125"][24:],data["pressure"][24:]/1e6,"*",color='m',label="Data 348 K") 
plt.title('Isotherm R125-[bmim][PF6]',fontsize=20)
plt.ylabel('Pressure [MPa]',fontsize=20)
plt.xlabel('x R125 [mole/mole]',fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(True)
plt.ylim(0,1.110000)
plt.xlim(0,0.5)
plt.legend(fontsize=10)
plt.savefig('Isotherm R125-[bmim][PF6]_bin_noT.png', bbox_inches='tight',dpi=300)
plt.show()

# %%
m.fs.F101.report()
# Out:
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Fixed : Bounds
#           Heat Duty :  59.665 : False : (None, None)
#     Pressure Change : -86296. : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                               Inlet    Vapor Outlet  Liquid Outlet
#     flow_mol                   1.0000     0.054825       0.94518
#     mole_frac_comp bmimPF6    0.86200   1.0000e-08       0.91200
#     mole_frac_comp R125       0.13800       1.0000      0.088000
#     temperature                348.20       348.20        348.20
#     pressure               9.9960e+05   9.1330e+05    9.1330e+05
# ====================================================================================

# %%
# print(P1)

# %%
df = pd.DataFrame(P)
# df.to_csv('P_cons_125.csv')
# df.to_csv('P_lin_125.csv')
# df.to_csv('P_ter_125.csv')

# %%
m.display()
# Out:
# Model unknown
#
#   Variables:
#     None
#
#   Objectives:
#     None
#
#   Constraints:
#     None
#
#   Blocks:
#     Block fs
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         liquid : Size=1
#             Key  : Lower : Body  : Upper
#             None : 0.912 : 0.912 : 0.912
#
#       Blocks:
#         Block fs.properties
#
#           Variables:
#             PR_kappa_A : PRA binary interaction parameters
#                 Size=4, Index=fs.properties.PR_kappa_A_index
#                 Key                    : Lower : Value    : Upper : Fixed : Stale : Domain
#                       ('R125', 'R125') :  None :      0.0 :  None :  True :  True :  Reals
#                    ('R125', 'bmimPF6') :  None : -0.00356 :  None :  True :  True :  Reals
#                    ('bmimPF6', 'R125') :  None :  0.28636 :  None :  True :  True :  Reals
#                 ('bmimPF6', 'bmimPF6') :  None :      0.0 :  None :  True :  True :  Reals
#             PR_kappa_B : PRB binary interaction parameters
#                 Size=4, Index=fs.properties.PR_kappa_B_index
#                 Key                    : Lower : Value : Upper : Fixed : Stale : Domain
#                       ('R125', 'R125') :  None :   0.0 :  None :  True :  True :  Reals
#                    ('R125', 'bmimPF6') :  None :   0.0 :  None :  True :  True :  Reals
#                    ('bmimPF6', 'R125') :  None :   0.0 :  None :  True :  True :  Reals
#                 ('bmimPF6', 'bmimPF6') :  None :   0.0 :  None :  True :  True :  Reals
#             PR_kappa_C : PRC binary interaction parameters
#                 Size=4, Index=fs.properties.PR_kappa_C_index
#                 Key                    : Lower : Value : Upper : Fixed : Stale : Domain
#                       ('R125', 'R125') :  None :   0.0 :  None :  True :  True :  Reals
#                    ('R125', 'bmimPF6') :  None :   0.0 :  None :  True :  True :  Reals
#                    ('bmimPF6', 'R125') :  None :   0.0 :  None :  True :  True :  Reals
#                 ('bmimPF6', 'bmimPF6') :  None :   0.0 :  None :  True :  True :  Reals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#
#           Blocks:
#             Block fs.properties.Liq
#
#               Variables:
#                 None
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.Vap
#
#               Variables:
#                 None
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.bmimPF6
#
#               Variables:
#                 pressure_crit : Size=1, Index=None, Units=kg/m/s**2
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 2900000.0 :  None :  True :  True :  Reals
#                 temperature_crit : Size=1, Index=None, Units=K
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None :  1050 :  None :  True :  True :  Reals
#                 omega : Size=1, Index=None
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None :  0.65 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_A : Parameter A for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K/mol
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 3259.5745 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_B : Parameter B for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**2/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : -28.561 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_C : Parameter C for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**3/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 0.09354 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_D : Parameter D for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**4/mol
#                     Key  : Lower : Value         : Upper : Fixed : Stale : Domain
#                     None :  None : -0.0001000673 :  None :  True :  True :  Reals
#                 enth_mol_form_vap_comp_ref : Vapor phase molar heat of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/mol/s**2
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 0.145 :  None :  True :  True :  Reals
#                 entr_mol_form_vap_comp_ref : Vapor phase molar entropy of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/K/mol/s**2
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 137.5 :  None :  True :  True :  Reals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#             Block fs.properties.R125
#
#               Variables:
#                 pressure_crit : Size=1, Index=None, Units=kg/m/s**2
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 3629000.0 :  None :  True :  True :  Reals
#                 temperature_crit : Size=1, Index=None, Units=K
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : 339.16 :  None :  True :  True :  Reals
#                 omega : Size=1, Index=None
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :  None : 0.305 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_A : Parameter A for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 38.7614 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_B : Parameter B for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**2/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 0.78561 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_C : Parameter C for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**3/mol
#                     Key  : Lower : Value    : Upper : Fixed : Stale : Domain
#                     None :  None : -0.00468 :  None :  True :  True :  Reals
#                 cp_mol_ig_comp_coeff_D : Parameter D for ideal gas molar heat capacity
#                     Size=1, Index=None, Units=J/K**4/mol
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 9.09976 :  None :  True :  True :  Reals
#                 enth_mol_form_vap_comp_ref : Vapor phase molar heat of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/mol/s**2
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 22800.0 :  None :  True :  True :  Reals
#                 entr_mol_form_vap_comp_ref : Vapor phase molar entropy of formation @ Tref
#                     Size=1, Index=None, Units=kg*m**2/K/mol/s**2
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : -269.0 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_A : Antoine A coefficient for calculating Psat
#                     Size=1, Index=None
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :  None : 4.7694 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_B : Antoine B coefficient for calculating Psat
#                     Size=1, Index=None, Units=K
#                     Key  : Lower : Value     : Upper : Fixed : Stale : Domain
#                     None :  None : 1153.2136 :  None :  True :  True :  Reals
#                 pressure_sat_comp_coeff_C : Antoine C coefficient for calculating Psat
#                     Size=1, Index=None, Units=K
#                     Key  : Lower : Value   : Upper : Fixed : Stale : Domain
#                     None :  None : 19.5064 :  None :  True :  True :  Reals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
#         Block fs.F101
#
#           Variables:
#             _flow_mol_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  1000 :  True :  True : NonNegativeReals
#             _mole_frac_comp_inlet_ref : Size=2, Index=fs.F101._mole_frac_comp_inlet_ref_index
#                 Key              : Lower : Value : Upper : Fixed : Stale : Domain
#                    (0.0, 'R125') :     0 : 0.138 :  None :  True :  True :  Reals
#                 (0.0, 'bmimPF6') :     0 : 0.862 :  None :  True :  True :  Reals
#             _temperature_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :    10 : 348.2 :  5000 :  True :  True : NonNegativeReals
#             _pressure_inlet_ref : Size=1, Index=fs._time
#                 Key : Lower  : Value    : Upper           : Fixed : Stale : Domain
#                 0.0 : 0.0005 : 999600.0 : 1000000000000.0 :  True :  True : NonNegativeReals
#             heat_duty : Size=1, Index=fs._time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 59.66471234833695 :  None : False : False :  Reals
#             deltaP : Size=1, Index=fs._time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :  None : -86295.70873291956 :  None : False : False :  Reals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#
#           Blocks:
#             Block fs.F101.control_volume
#
#               Variables:
#                 heat : Heat transferred into control volume
#                     Size=1, Index=fs._time, Units=kg*m**2/s**3
#                     Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                     0.0 :  None : 59.66471234833695 :  None : False : False :  Reals
#                 deltaP : Pressure difference across unit
#                     Size=1, Index=fs._time, Units=kg/m/s**2
#                     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                     0.0 :  None : -86295.70873291956 :  None : False : False :  Reals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 material_balances : Size=2
#                     Key              : Lower : Body                    : Upper
#                        (0.0, 'R125') :   0.0 :                     0.0 :   0.0
#                     (0.0, 'bmimPF6') :   0.0 : -1.1102230246251565e-16 :   0.0
#                 enthalpy_balances : Size=1
#                     Key : Lower : Body                   : Upper
#                     0.0 :   0.0 : -8.070968249285215e-08 :   0.0
#                 pressure_balance : Size=1
#                     Key : Lower : Body                    : Upper
#                     0.0 :   0.0 : -2.9103830456733704e-11 :   0.0
#
#               Blocks:
#                 Block fs.F101.control_volume.properties_in[0.0]
#
#                   Variables:
#                     flow_mol :  Total molar flowrate
#                         Size=1, Index=None, Units=mol/s
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :     0 :     1 :  1000 :  True :  True : NonNegativeReals
#                     mole_frac_comp : Mixture mole fractions
#                         Size=2, Index=fs.properties.component_list
#                         Key     : Lower : Value : Upper : Fixed : Stale : Domain
#                            R125 :     0 : 0.138 :  None :  True :  True :  Reals
#                         bmimPF6 :     0 : 0.862 :  None :  True :  True :  Reals
#                     pressure : State pressure
#                         Size=1, Index=None, Units=kg/m/s**2
#                         Key  : Lower  : Value    : Upper           : Fixed : Stale : Domain
#                         None : 0.0005 : 999600.0 : 1000000000000.0 :  True :  True : NonNegativeReals
#                     temperature : State temperature
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :    10 : 348.2 :  5000 :  True :  True : NonNegativeReals
#                     flow_mol_phase : Phase molar flow rates
#                         Size=2, Index=fs.properties.phase_list, Units=mol/s
#                         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                         Liq :     0 :  0.9536428668606126 :  1000 : False : False : NonNegativeReals
#                         Vap :     0 : 0.04635713313938725 :  1000 : False : False : NonNegativeReals
#                     mole_frac_phase_comp : Phase mole fractions
#                         Size=3, Index=fs.properties._phase_component_set
#                         Key                : Lower : Value               : Upper : Fixed : Stale : Domain
#                            ('Liq', 'R125') :     0 : 0.09609767979736546 :  None : False : False :  Reals
#                         ('Liq', 'bmimPF6') :     0 :  0.9039023202026346 :  None : False : False :  Reals
#                            ('Vap', 'R125') :     0 :  1.0000000000000002 :  None : False : False :  Reals
#                     phase_frac : Phase fractions
#                         Size=2, Index=fs.properties.phase_list
#                         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                         Liq :     0 :  0.9536428668606126 :  None : False : False :  Reals
#                         Vap :     0 : 0.04635713313938725 :  None : False : False :  Reals
#                     _teq : Temperature for calculating phase equilibrium
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value              : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :  None : 348.20000128220136 :  None : False : False :  Reals
#                     _t1_Vap_Liq : Intermediate temperature for calculating Teq
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value              : Upper : Fixed : Stale : Domain
#                         None :  None : 348.20000128220136 :  None : False : False :  Reals
#                     temperature_bubble : Bubble point temperature
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :    10 : 328.7022834417704 :  5000 : False : False :  Reals
#                     _mole_frac_tbub : Vapor mole fractions at bubble temperature
#                         Size=2, Index=fs.F101.control_volume.properties_in[0.0]._mole_frac_tbub_index
#                         Key                       : Lower : Value : Upper : Fixed : Stale : Domain
#                            ('Vap', 'Liq', 'R125') :     0 :   1.0 :  None : False : False :  Reals
#                         ('Vap', 'Liq', 'bmimPF6') :     0 :   0.0 :  None : False : False :  Reals
#
#                   Objectives:
#                     None
#
#                   Constraints:
#                     total_flow_balance : Size=1
#                         Key  : Lower : Body                    : Upper
#                         None :   0.0 : -1.1102230246251565e-16 :   0.0
#                     component_flow_balances : Size=2
#                         Key     : Lower : Body                   : Upper
#                            R125 :   0.0 :                    0.0 :   0.0
#                         bmimPF6 :   0.0 : 1.1102230246251565e-16 :   0.0
#                     sum_mole_frac : Size=1
#                         Key  : Lower : Body                   : Upper
#                         None :   0.0 : -2.220446049250313e-16 :   0.0
#                     phase_fraction_constraint : Size=2
#                         Key : Lower : Body : Upper
#                         Liq :   0.0 :  0.0 :   0.0
#                         Vap :   0.0 :  0.0 :   0.0
#                     _t1_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body                  : Upper
#                         None :   0.0 : 5.684341886080802e-14 :   0.0
#                     eq_temperature_bubble : Size=2
#                         Key                       : Lower : Body                    : Upper
#                            ('Vap', 'Liq', 'R125') :   0.0 : -1.5987211554602254e-14 :   0.0
#                         ('Vap', 'Liq', 'bmimPF6') :   0.0 :                     0.0 :   0.0
#                     eq_mole_frac_tbub : Size=1
#                         Key            : Lower : Body : Upper
#                         ('Vap', 'Liq') :   1.0 :  1.0 :   1.0
#                     _teq_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     equilibrium_constraint : Size=1
#                         Key                    : Lower : Body                  : Upper
#                         ('Vap', 'Liq', 'R125') :   0.0 : 3.197442310920451e-14 :   0.0
#                 Block fs.F101.control_volume.properties_out[0.0]
#
#                   Variables:
#                     flow_mol :  Total molar flowrate
#                         Size=1, Index=None, Units=mol/s
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :     0 :   1.0 :  1000 : False : False : NonNegativeReals
#                     mole_frac_comp : Mixture mole fractions
#                         Size=2, Index=fs.properties.component_list
#                         Key     : Lower : Value : Upper : Fixed : Stale : Domain
#                            R125 :     0 : 0.138 :  None : False : False :  Reals
#                         bmimPF6 :     0 : 0.862 :  None : False : False :  Reals
#                     pressure : State pressure
#                         Size=1, Index=None, Units=kg/m/s**2
#                         Key  : Lower  : Value             : Upper           : Fixed : Stale : Domain
#                         None : 0.0005 : 913304.2912670805 : 1000000000000.0 : False : False : NonNegativeReals
#                     temperature : State temperature
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                         None :    10 : 348.2 :  5000 :  True :  True : NonNegativeReals
#                     flow_mol_phase : Phase molar flow rates
#                         Size=2, Index=fs.properties.phase_list, Units=mol/s
#                         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                         Liq :     0 :  0.9451754385964912 :  1000 : False : False : NonNegativeReals
#                         Vap :     0 : 0.05482456140350883 :  1000 : False : False : NonNegativeReals
#                     mole_frac_phase_comp : Phase mole fractions
#                         Size=3, Index=fs.properties._phase_component_set
#                         Key                : Lower : Value               : Upper : Fixed : Stale : Domain
#                            ('Liq', 'R125') :     0 : 0.08799999999999994 :  None : False : False :  Reals
#                         ('Liq', 'bmimPF6') :     0 :               0.912 :  None : False : False :  Reals
#                            ('Vap', 'R125') :     0 :                 1.0 :  None : False : False :  Reals
#                     phase_frac : Phase fractions
#                         Size=2, Index=fs.properties.phase_list
#                         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                         Liq :     0 :  0.9451754385964912 :  None : False : False :  Reals
#                         Vap :     0 : 0.05482456140350883 :  None : False : False :  Reals
#                     _teq : Temperature for calculating phase equilibrium
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :  None : 348.2000010495742 :  None : False : False :  Reals
#                     _t1_Vap_Liq : Intermediate temperature for calculating Teq
#                         Size=1, Index=None, Units=K
#                         Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#                         None :  None : 348.2000010495742 :  None : False : False :  Reals
#                     temperature_bubble : Bubble point temperature
#                         Size=1, Index=fs.properties._pe_pairs, Units=K
#                         Key            : Lower : Value             : Upper : Fixed : Stale : Domain
#                         ('Vap', 'Liq') :    10 : 324.3808175934006 :  5000 : False : False :  Reals
#                     _mole_frac_tbub : Vapor mole fractions at bubble temperature
#                         Size=2, Index=fs.F101.control_volume.properties_out[0.0]._mole_frac_tbub_index
#                         Key                       : Lower : Value : Upper : Fixed : Stale : Domain
#                            ('Vap', 'Liq', 'R125') :     0 :   1.0 :  None : False : False :  Reals
#                         ('Vap', 'Liq', 'bmimPF6') :     0 :   0.0 :  None : False : False :  Reals
#
#                   Objectives:
#                     None
#
#                   Constraints:
#                     sum_mole_frac_out : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   1.0 :  1.0 :   1.0
#                     total_flow_balance : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     component_flow_balances : Size=2
#                         Key     : Lower : Body : Upper
#                            R125 :   0.0 :  0.0 :   0.0
#                         bmimPF6 :   0.0 :  0.0 :   0.0
#                     sum_mole_frac : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     phase_fraction_constraint : Size=2
#                         Key : Lower : Body : Upper
#                         Liq :   0.0 :  0.0 :   0.0
#                         Vap :   0.0 :  0.0 :   0.0
#                     _t1_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body                  : Upper
#                         None :   0.0 : 5.684341886080802e-14 :   0.0
#                     eq_temperature_bubble : Size=2
#                         Key                       : Lower : Body                   : Upper
#                            ('Vap', 'Liq', 'R125') :   0.0 : -7.105427357601002e-15 :   0.0
#                         ('Vap', 'Liq', 'bmimPF6') :   0.0 :                    0.0 :   0.0
#                     eq_mole_frac_tbub : Size=1
#                         Key            : Lower : Body : Upper
#                         ('Vap', 'Liq') :   1.0 :  1.0 :   1.0
#                     _teq_constraint_Vap_Liq : Size=1
#                         Key  : Lower : Body : Upper
#                         None :   0.0 :  0.0 :   0.0
#                     equilibrium_constraint : Size=1
#                         Key                    : Lower : Body                   : Upper
#                         ('Vap', 'Liq', 'R125') :   0.0 : -4.574118861455645e-14 :   0.0
#             Block fs.F101.split
#
#               Variables:
#                 _flow_mol_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                     0.0 :     0 :   1.0 :  1000 : False : False : NonNegativeReals
#                 _mole_frac_comp_inlet_ref : Size=2, Index=fs.F101.split._mole_frac_comp_inlet_ref_index
#                     Key              : Lower : Value : Upper : Fixed : Stale : Domain
#                        (0.0, 'R125') :     0 : 0.138 :  None : False : False :  Reals
#                     (0.0, 'bmimPF6') :     0 : 0.862 :  None : False : False :  Reals
#                 _temperature_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 348.2 :  5000 :  True :  True : NonNegativeReals
#                 _pressure_inlet_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value             : Upper           : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 913304.2912670805 : 1000000000000.0 : False : False : NonNegativeReals
#                 _Vap_temperature_ref : Size=1, Index=fs._time
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 348.2 :  5000 :  True :  True : NonNegativeReals
#                 _Vap_pressure_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value             : Upper           : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 913304.2912670805 : 1000000000000.0 : False : False : NonNegativeReals
#                 _Liq_temperature_ref : Size=1, Index=fs._time
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                     0.0 :    10 : 348.2 :  5000 :  True :  True : NonNegativeReals
#                 _Liq_pressure_ref : Size=1, Index=fs._time
#                     Key : Lower  : Value             : Upper           : Fixed : Stale : Domain
#                     0.0 : 0.0005 : 913304.2912670805 : 1000000000000.0 : False : False : NonNegativeReals
#
#               Objectives:
#                 None
#
#               Constraints:
#                 None
