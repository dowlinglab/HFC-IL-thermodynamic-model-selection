# %%
import pandas as pd
import numpy as np
from R125_bmimPF6_PR import configuration
from pyomo.environ import (ConcreteModel,
                           SolverFactory,
                           units as pyunits)

import idaes.logger as idaeslog
import pyomo.contrib.parmest.parmest as parmest

import pytest

from idaes.core import FlowsheetBlock
from idaes.generic_models.unit_models import Flash
from idaes.generic_models.properties.core.generic.generic_property import (
        GenericParameterBlock)

from idaes.core.util.model_statistics import degrees_of_freedom

# %%
def PR_model(data):
    """
    Function which returns initilized model.

    Args:
        data: pandas DataFrame with data

    Returns:
        initialized model
    """
    eps = 0.1
    init_kappa_2_1A = 0.3
    init_kappa_1_2A = 0.05
    
    m = ConcreteModel()

    m.fs = FlowsheetBlock(default={"dynamic": False})

    m.fs.properties = GenericParameterBlock(default=configuration)

    m.fs.state_block = m.fs.properties.state_block_class(
        default={"parameters": m.fs.properties,
                 "defined_state": True})
    x = float(data['x_R125'])+eps
    m.fs.state_block.flow_mol.fix(1)
    m.fs.state_block.temperature.fix(float(data["temperature"]))
    m.fs.state_block.pressure.fix(float(data["pressure"]))
    m.fs.state_block.mole_frac_comp['bmimPF6'].fix(1-x)
    m.fs.state_block.mole_frac_comp['R125'].fix(x)

    # parameter - kappa_A_ij (set at 0.3, 0 if i=j)
    m.fs.properties.PR_kappa_A['bmimPF6','bmimPF6'].fix(0)
    m.fs.properties.PR_kappa_A['bmimPF6', 'R125'].fix(init_kappa_2_1A)
    m.fs.properties.PR_kappa_A['R125', 'R125'].fix(0)
    m.fs.properties.PR_kappa_A['R125', 'bmimPF6'].fix(init_kappa_1_2A)
    m.fs.properties.PR_kappa_B['bmimPF6', 'bmimPF6'].fix(0)
    m.fs.properties.PR_kappa_B['bmimPF6', 'R125'].fix(0)
    m.fs.properties.PR_kappa_B['R125', 'R125'].fix(0)
    m.fs.properties.PR_kappa_B['R125', 'bmimPF6'].fix(0)
    m.fs.properties.PR_kappa_C['bmimPF6', 'bmimPF6'].fix(0)
    m.fs.properties.PR_kappa_C['bmimPF6', 'R125'].fix(0)
    m.fs.properties.PR_kappa_C['R125', 'R125'].fix(0)
    m.fs.properties.PR_kappa_C['R125', 'bmimPF6'].fix(0)
    # Initialize the flash unit
    m.fs.state_block.initialize(outlvl=idaeslog.CRITICAL)

    # Fix the state variables on the state block
    m.fs.state_block.pressure.unfix()
    m.fs.state_block.mole_frac_comp['bmimPF6'].unfix()
    m.fs.state_block.mole_frac_comp['R125'].unfix()
    m.fs.state_block.temperature.fix(float(data["temperature"]))
    m.fs.state_block.mole_frac_phase_comp['Liq', 'R125'].fix(float(data['x_R125']))
    m.fs.state_block.mole_frac_phase_comp['Liq', 'bmimPF6'].fix(float(data['x_bmimPF6']))
    m.fs.state_block.mole_frac_comp['R125'].fix(float(data['x_R125'])+eps)
    m.fs.state_block.mole_frac_comp['bmimPF6'].unfix()

    # Set bounds on variables to be estimated
    m.fs.properties.PR_kappa_A['bmimPF6', 'R125'].setlb(-5)
    m.fs.properties.PR_kappa_A['bmimPF6', 'R125'].setub(5)

    m.fs.properties.PR_kappa_A['R125', 'bmimPF6'].setlb(-5)
    m.fs.properties.PR_kappa_A['R125', 'bmimPF6'].setub(5)

    # Return initialized flash model
    return m

def SSE(m, data):
    """
    returns objective function expresion.

    Args:
        m: model
        data: pandas DataFrame with data

    Returns:
        objectuve function scaled expresion
    """
    expr = ((float(data["pressure"]) - m.fs.state_block.pressure)**2)

    return expr * 1e-6

variable_name = ["fs.properties.PR_kappa_A['bmimPF6', 'R125']",
                 "fs.properties.PR_kappa_A['R125', 'bmimPF6']"]

#     pest = parmest.Estimator(PR_model, data, variable_name, SSE, tee=True)

#     obj_value, parameters,a= pest.theta_est(calc_cov=True)

# %%
data = pd.read_csv('R125IL.csv')

# %%
pest = parmest.Estimator(PR_model, data, variable_name, SSE, tee=False)

obj_value, parameters = pest.theta_est()

for k,v in parameters.items():
    print(k, "=", v)

bootstrap_theta = pest.theta_est_bootstrap(bootstrap_samples=50, samplesize=30, seed=408)
display(bootstrap_theta)
# Out:
# 2022-04-08 15:08:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# fs.properties.PR_kappa_A[bmimPF6,R125] = 0.34907357497135233
# fs.properties.PR_kappa_A[R125,bmimPF6] = 0.058856151938321305
# 2022-04-08 15:09:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# WARNING: Loading a SolverResults object with a warning status into
#     model.name="_Q_opt";
#       - termination condition: maxIterations
#       - message from solver: Ipopt 3.13.2\x3a Maximum Number of Iterations
#         Exceeded.
# 2022-04-08 15:13:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:17:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:18:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:19:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# ...
# 2022-04-08 15:40:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:40:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:41:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
#     fs.properties.PR_kappa_A[bmimPF6,R125]  \
# 0                                 0.714027
# 1                                 0.351806
# 2                                 0.518057
# 3                                 0.700685
# 4                                 0.669561
# 5                                 0.361838
# 6                                 0.351480
# 7                                 0.344856
# 8                                 0.354403
# 9                                 1.230743
# 10                                0.685556
# 11                                0.697461
# 12                                0.361058
# 13                                0.341045
# 14                                0.346103
# 15                                0.345894
# 16                                0.707989
# 17                                0.347245
# 18                                0.347580
# 19                                0.357578
# 20                                0.350518
# 21                                0.351727
# 22                                0.678353
# 23                                0.347073
# 24                                0.349192
# 25                                0.681306
# 26                                0.334244
# 27                                0.351046
# 28                                0.358204
# 29                                0.671812
# 30                                0.355779
# 31                                0.674284
# 32                                0.346699
# 33                                0.660570
# 34                                0.351375
# 35                                0.362513
# 36                                0.365787
# 37                                0.361371
# 38                                0.681137
# 39                                0.354327
# 40                                0.357275
# 41                                0.355218
# 42                                0.345733
# 43                                0.358124
# 44                                0.699644
# 45                                0.337912
# 46                                0.687231
# 47                                0.694831
# 48                                1.059315
# 49                                0.685553
#
#     fs.properties.PR_kappa_A[R125,bmimPF6]
# 0                                 0.069587
# 1                                 0.058259
# 2                                 0.069198
# 3                                 0.072381
# 4                                 0.072652
# 5                                 0.056042
# 6                                 0.058326
# 7                                 0.059768
# 8                                 0.057662
# 9                                 0.084815
# 10                                0.070072
# 11                                0.073172
# 12                                0.056229
# 13                                0.060600
# 14                                0.059482
# 15                                0.059534
# 16                                0.070492
# 17                                0.059264
# 18                                0.059179
# 19                                0.056976
# 20                                0.058514
# 21                                0.058277
# 22                                0.071342
# 23                                0.059291
# 24                                0.058837
# 25                                0.070773
# 26                                0.062088
# 27                                0.058420
# 28                                0.056852
# 29                                0.072281
# 30                                0.057386
# 31                                0.072011
# 32                                0.059371
# 33                                0.074176
# 34                                0.058350
# 35                                0.055884
# 36                                0.055186
# 37                                0.056152
# 38                                0.070811
# 39                                0.057672
# 40                                0.057051
# 41                                0.057499
# 42                                0.059579
# 43                                0.056847
# 44                                0.067652
# 45                                0.061288
# 46                                0.069786
# 47                                0.073887
# 48                                0.079830
# 49                                0.070071

# %%
results = pd.DataFrame(bootstrap_theta)
results.to_csv('R125_boot.csv')
