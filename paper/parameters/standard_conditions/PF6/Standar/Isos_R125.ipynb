# %%
# Import plotting functions
import matplotlib.pyplot as plt

# Import numpy library 
import numpy as np

import pandas as pd

# %%
data = pd.read_csv('R125IL.csv')
data_M1 = pd.read_csv('P_M1_125.csv')
data_M2 = pd.read_csv('P_M2_125.csv')
data_M3 = pd.read_csv('P_M3_125.csv')
data_M4 = pd.read_csv('P_M4_125.csv')
data_M5 = pd.read_csv('P_M5_125.csv')

# %%
linestyle =[
     (0, ()),
     (0, (5, 5)),
     (0, (1, 1)),
     (0, (3, 5, 1, 5)),
     (0, (3, 1, 1, 1, 1, 1))]

# %%
plt.plot(data_M1["x1"][0:15],data_M1["P1"][0:15],linestyle=linestyle[0], color='blue')  
plt.plot(data_M1["x2"][0:15],data_M1["P2"][0:15],linestyle=linestyle[0], color='red')  
plt.plot(data_M1["x3"][0:15],data_M1["P3"][0:15],linestyle=linestyle[0], color='cyan')  
plt.plot(data_M1["x4"][0:15],data_M1["P4"][0:15],linestyle=linestyle[0], color='magenta')  

plt.plot(data_M2["x1"][0:15],data_M2["P1"][0:15],linestyle=linestyle[1], color='blue')  
plt.plot(data_M2["x2"][0:15],data_M2["P2"][0:15],linestyle=linestyle[1], color='red')  
plt.plot(data_M2["x3"][0:15],data_M2["P3"][0:15],linestyle=linestyle[1], color='cyan')  
plt.plot(data_M2["x4"][0:15],data_M2["P4"][0:15],linestyle=linestyle[1], color='magenta')  

# plt.plot(data_M3["x1"][0:15],data_M3["P1"][0:15],linestyle=linestyle[2], color='blue')  
# plt.plot(data_M3["x2"][0:15],data_M3["P2"][0:15],linestyle=linestyle[2], color='red')  
# plt.plot(data_M3["x3"][0:15],data_M3["P3"][0:15],linestyle=linestyle[2], color='cyan')  
# plt.plot(data_M3["x4"][0:15],data_M3["P4"][0:15],linestyle=linestyle[2], color='magenta')  

# plt.plot(data_M4["x1"][0:15],data_M4["P1"][0:15],linestyle=linestyle[3], color='blue')  
# plt.plot(data_M4["x2"][0:15],data_M4["P2"][0:15],linestyle=linestyle[3], color='red')  
# plt.plot(data_M4["x3"][0:15],data_M4["P3"][0:15],linestyle=linestyle[3], color='cyan')  
# plt.plot(data_M4["x4"][0:15],data_M4["P4"][0:15],linestyle=linestyle[3], color='magenta') 

# plt.plot(data_M5["x1"][0:15],data_M5["P1"][0:15],linestyle=linestyle[4], color='blue')  
# plt.plot(data_M5["x2"][0:15],data_M5["P2"][0:15],linestyle=linestyle[4], color='red')  
# plt.plot(data_M5["x3"][0:15],data_M5["P3"][0:15],linestyle=linestyle[4], color='cyan')  
# plt.plot(data_M5["x4"][0:15],data_M5["P4"][0:15],linestyle=linestyle[4], color='magenta') 

plt.plot(data["x_R125"][0:8],data["pressure"][0:8]/1e6,"*",color='b',label="Binary 283 K")  
plt.plot(data["x_R125"][8:16],data["pressure"][8:16]/1e6,"D",color='r',label="Binary 298 K") 
plt.plot(data["x_R125"][16:24],data["pressure"][16:24]/1e6,"^",color='c',label="Binary 323 K") 
plt.plot(data["x_R125"][24:],data["pressure"][24:]/1e6,"o",color='m',label="Binary 348 K") 
plt.plot([0.027,0.072],[0.1,0.25],"go",label="Ternary 298 K")

# plt.title('Isotherm R125-[bmim][PF6]',fontsize=20)
plt.ylabel('Pressure [MPa]',fontsize=20)
plt.xlabel('x HFC-125 [mole/mole]',fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(True)
plt.ylim(0,1.110000)
plt.xlim(0,0.5)
plt.legend(fontsize=14,bbox_to_anchor=(0.53, 0.55))

plt.savefig('Isotherm R125-[bmim][PF6]_M1_M2.png', bbox_inches='tight',dpi=300)
# plt.savefig('Isotherm R125-[bmim][PF6]_M3_M4_M5.png', bbox_inches='tight',dpi=300)
plt.show()
