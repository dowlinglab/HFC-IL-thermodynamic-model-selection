# %%
import pandas as pd
import numpy as np
from R32_bmimPF6_PR import configuration
from pyomo.environ import (ConcreteModel,
                           SolverFactory,
                           units as pyunits)

import idaes.logger as idaeslog
import pyomo.contrib.parmest.parmest as parmest

import pytest

from idaes.core import FlowsheetBlock
from idaes.generic_models.unit_models import Flash
from idaes.generic_models.properties.core.generic.generic_property import (
        GenericParameterBlock)

from idaes.core.util.model_statistics import degrees_of_freedom

# %%
def PR_model(data):
    """
    Function which returns initilized model.

    Args:
        data: pandas DataFrame with data

    Returns:
        initialized model
    """
    eps = 0.1
    init_kappa_2_1A = -0.07
    init_kappa_1_2A = -0.02
    m = ConcreteModel()

    m.fs = FlowsheetBlock(default={"dynamic": False})

    m.fs.properties = GenericParameterBlock(default=configuration)

    m.fs.state_block = m.fs.properties.state_block_class(
        default={"parameters": m.fs.properties,
                 "defined_state": True})
    x = float(data['x_R32'])+eps
    m.fs.state_block.flow_mol.fix(1)
    m.fs.state_block.temperature.fix(float(data["temperature"]))
    m.fs.state_block.pressure.fix(float(data["pressure"]))
    m.fs.state_block.mole_frac_comp['bmimPF6'].fix(1-x)
    m.fs.state_block.mole_frac_comp['R32'].fix(x)

    # parameter - kappa_A_ij (set at 0.3, 0 if i=j)
    m.fs.properties.PR_kappa_A['bmimPF6','bmimPF6'].fix(0)
    m.fs.properties.PR_kappa_A['bmimPF6', 'R32'].fix(init_kappa_2_1A)
    m.fs.properties.PR_kappa_A['R32', 'R32'].fix(0)
    m.fs.properties.PR_kappa_A['R32', 'bmimPF6'].fix(init_kappa_1_2A)
    m.fs.properties.PR_kappa_B['bmimPF6', 'bmimPF6'].fix(0)
    m.fs.properties.PR_kappa_B['bmimPF6', 'R32'].fix(0)
    m.fs.properties.PR_kappa_B['R32', 'R32'].fix(0)
    m.fs.properties.PR_kappa_B['R32', 'bmimPF6'].fix(0)
    m.fs.properties.PR_kappa_C['bmimPF6', 'bmimPF6'].fix(0)
    m.fs.properties.PR_kappa_C['bmimPF6', 'R32'].fix(0)
    m.fs.properties.PR_kappa_C['R32', 'R32'].fix(0)
    m.fs.properties.PR_kappa_C['R32', 'bmimPF6'].fix(0)
    # Initialize the flash unit
    m.fs.state_block.initialize(outlvl=idaeslog.CRITICAL)

    # Fix the state variables on the state block
    m.fs.state_block.pressure.unfix()
    m.fs.state_block.mole_frac_comp['bmimPF6'].unfix()
    m.fs.state_block.mole_frac_comp['R32'].unfix()
    m.fs.state_block.temperature.fix(float(data["temperature"]))
    m.fs.state_block.mole_frac_phase_comp['Liq', 'R32'].fix(float(data['x_R32']))
    m.fs.state_block.mole_frac_phase_comp['Liq', 'bmimPF6'].fix(float(data['x_bmimPF6']))
    m.fs.state_block.mole_frac_comp['R32'].fix(float(data['x_R32'])+eps)
    m.fs.state_block.mole_frac_comp['bmimPF6'].unfix()

    # Set bounds on variables to be estimated
    m.fs.properties.PR_kappa_A['bmimPF6', 'R32'].setlb(-5)
    m.fs.properties.PR_kappa_A['bmimPF6', 'R32'].setub(5)

    m.fs.properties.PR_kappa_A['R32', 'bmimPF6'].setlb(-5)
    m.fs.properties.PR_kappa_A['R32', 'bmimPF6'].setub(5)

    # Return initialized flash model
    return m

def SSE(m, data):
    """
    returns objective function expresion.

    Args:
        m: model
        data: pandas DataFrame with data

    Returns:
        objectuve function scaled expresion
    """
    expr = ((float(data["pressure"]) - m.fs.state_block.pressure)**2)

    return expr * 1e-6

variable_name = ["fs.properties.PR_kappa_A['bmimPF6', 'R32']",
                 "fs.properties.PR_kappa_A['R32', 'bmimPF6']"]

#     pest = parmest.Estimator(PR_model, data, variable_name, SSE, tee=True)

#     obj_value, parameters,a= pest.theta_est(calc_cov=True)

# %%
data = pd.read_csv('R32IL.csv')

# print(data)

# %%
pest = parmest.Estimator(PR_model, data, variable_name, SSE, tee=False)

obj_value, parameters = pest.theta_est()

for k,v in parameters.items():
    print(k, "=", v)

bootstrap_theta = pest.theta_est_bootstrap(bootstrap_samples=50, samplesize=30, seed=408)
display(bootstrap_theta)
# Out:
# 2022-04-08 15:08:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:08:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# fs.properties.PR_kappa_A[bmimPF6,R32] = -0.07040544962498223
# fs.properties.PR_kappa_A[R32,bmimPF6] = -0.02608835309035705
# 2022-04-08 15:09:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:09:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:10:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:11:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:12:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:13:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:14:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:15:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:16:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# ...
# 2022-04-08 15:35:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:18 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:19 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:57 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:35:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:37 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:38 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-04-08 15:36:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
#     fs.properties.PR_kappa_A[bmimPF6,R32]  \
# 0                               -0.078062
# 1                               -0.144092
# 2                               -0.135509
# 3                               -0.073198
# 4                               -0.132904
# 5                               -0.053872
# 6                               -0.064081
# 7                               -0.031753
# 8                               -0.128958
# 9                               -0.125384
# 10                              -0.036431
# 11                              -0.057288
# 12                              -0.082322
# 13                              -0.135312
# 14                              -0.059015
# 15                              -0.066394
# 16                              -0.047801
# 17                              -0.132205
# 18                              -0.086177
# 19                              -0.147357
# 20                              -0.125736
# 21                              -0.083572
# 22                              -0.140487
# 23                              -0.049097
# 24                              -0.070072
# 25                              -0.165990
# 26                              -0.070633
# 27                              -0.047105
# 28                              -0.041908
# 29                              -0.067136
# 30                              -0.075576
# 31                              -0.059976
# 32                              -0.063364
# 33                              -0.073085
# 34                              -0.066812
# 35                              -0.036967
# 36                              -0.044232
# 37                              -0.127563
# 38                              -0.077518
# 39                              -0.129205
# 40                              -0.059545
# 41                              -0.075265
# 42                              -0.051059
# 43                              -0.149870
# 44                              -0.127640
# 45                              -0.146010
# 46                              -0.071237
# 47                              -0.138990
# 48                              -0.135324
# 49                              -0.042624
#
#     fs.properties.PR_kappa_A[R32,bmimPF6]
# 0                               -0.026443
# 1                               -0.029957
# 2                               -0.029862
# 3                               -0.026560
# 4                               -0.029661
# 5                               -0.025922
# 6                               -0.025255
# 7                               -0.026132
# 8                               -0.029330
# 9                               -0.028682
# 10                              -0.024768
# 11                              -0.026052
# 12                              -0.026139
# 13                              -0.029254
# 14                              -0.025179
# 15                              -0.026693
# 16                              -0.025173
# 17                              -0.029342
# 18                              -0.027043
# 19                              -0.030493
# 20                              -0.029112
# 21                              -0.026179
# 22                              -0.029712
# 23                              -0.025135
# 24                              -0.025786
# 25                              -0.030898
# 26                              -0.025672
# 27                              -0.023408
# 28                              -0.025254
# 29                              -0.025741
# 30                              -0.026078
# 31                              -0.026006
# 32                              -0.025517
# 33                              -0.025590
# 34                              -0.025109
# 35                              -0.022726
# 36                              -0.025212
# 37                              -0.029317
# 38                              -0.026546
# 39                              -0.029291
# 40                              -0.026004
# 41                              -0.025401
# 42                              -0.025085
# 43                              -0.030809
# 44                              -0.029269
# 45                              -0.030669
# 46                              -0.026378
# 47                              -0.030187
# 48                              -0.030096
# 49                              -0.025606

# %%
results = pd.DataFrame(bootstrap_theta)
results.to_csv('R32_boot.csv')
