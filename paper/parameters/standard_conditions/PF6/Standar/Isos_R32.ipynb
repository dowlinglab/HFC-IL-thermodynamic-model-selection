# %%
# Import plotting functions
import matplotlib.pyplot as plt

# Import numpy library 
import numpy as np

import pandas as pd

# %%
data = pd.read_csv('R32IL.csv')
data_M1 = pd.read_csv('P_M1_32.csv')
data_M2 = pd.read_csv('P_M2_32.csv')
data_M3 = pd.read_csv('P_M3_32.csv')
data_M4 = pd.read_csv('P_M4_32.csv')
data_M5 = pd.read_csv('P_M5_32.csv')

# %%
linestyle =[
     (0, ()),
     (0, (5, 5)),
     (0, (1, 1)),
     (0, (3, 5, 1, 5)),
     (0, (3, 1, 1, 1, 1, 1))]

# %%
# plt.plot(data_M1["x1"][0:15],data_M1["P1"][0:15],linestyle=linestyle[0], color='blue',label="M$_B$")  
# plt.plot(data_M1["x2"][0:15],data_M1["P2"][0:15],linestyle=linestyle[0], color='red')  
# plt.plot(data_M1["x3"][0:15],data_M1["P3"][0:15],linestyle=linestyle[0], color='cyan')  
# plt.plot(data_M1["x4"][0:15],data_M1["P4"][0:15],linestyle=linestyle[0], color='magenta')  

# plt.plot(data_M2["x1"][0:15],data_M2["P1"][0:15],linestyle=linestyle[1], color='blue',label="M$_{B,K}$")  
# plt.plot(data_M2["x2"][0:15],data_M2["P2"][0:15],linestyle=linestyle[1], color='red')  
# plt.plot(data_M2["x3"][0:15],data_M2["P3"][0:15],linestyle=linestyle[1], color='cyan')  
# plt.plot(data_M2["x4"][0:15],data_M2["P4"][0:15],linestyle=linestyle[1], color='magenta')  

plt.plot(data_M3["x1"][0:15],data_M3["P1"][0:15],linestyle=linestyle[2], color='blue',label="M$_T$")  
plt.plot(data_M3["x2"][0:15],data_M3["P2"][0:15],linestyle=linestyle[2], color='red')  
plt.plot(data_M3["x3"][0:15],data_M3["P3"][0:15],linestyle=linestyle[2], color='cyan')  
plt.plot(data_M3["x4"][0:15],data_M3["P4"][0:15],linestyle=linestyle[2], color='magenta')  

plt.plot(data_M4["x1"][0:15],data_M4["P1"][0:15],linestyle=linestyle[3], color='blue',label="M$_{BT}$")  
plt.plot(data_M4["x2"][0:15],data_M4["P2"][0:15],linestyle=linestyle[3], color='red')  
plt.plot(data_M4["x3"][0:15],data_M4["P3"][0:15],linestyle=linestyle[3], color='cyan')  
plt.plot(data_M4["x4"][0:15],data_M4["P4"][0:15],linestyle=linestyle[3], color='magenta') 

plt.plot(data_M5["x1"][0:15],data_M5["P1"][0:15],linestyle=linestyle[4], color='blue',label="M$_{BT,K}$")  
plt.plot(data_M5["x2"][0:15],data_M5["P2"][0:15],linestyle=linestyle[4], color='red')  
plt.plot(data_M5["x3"][0:15],data_M5["P3"][0:15],linestyle=linestyle[4], color='cyan')  
plt.plot(data_M5["x4"][0:15],data_M5["P4"][0:15],linestyle=linestyle[4], color='magenta')  

plt.plot(data["x_R32"][0:8],data["pressure"][0:8]/1e6,"*",color='b')  
plt.plot(data["x_R32"][8:16],data["pressure"][8:16]/1e6,"D",color='r') 
plt.plot(data["x_R32"][16:24],data["pressure"][16:24]/1e6,"^",color='c') 
plt.plot(data["x_R32"][24:],data["pressure"][24:]/1e6,"o",color='m') 
plt.plot([0.088,0.198],[0.1,0.25],"go")

plt.ylabel('Pressure [MPa]',fontsize=20)
plt.xlabel('x HFC-32 [mole/mole]',fontsize=20)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.grid(True)
plt.ylim(0,1.110000)
# plt.xlim(0,0.5)
plt.legend(fontsize=14,bbox_to_anchor=(0.98, 0.40))
# plt.legend(fontsize=14,bbox_to_anchor=(1.05, 1.0), loc='upper left')
# plt.savefig('Isotherm R32-[bmim][PF6]_M1_M2.png', bbox_inches='tight',dpi=300)
plt.savefig('Isotherm R32-[bmim][PF6]_M3_M4_M5.png', bbox_inches='tight',dpi=300)
plt.show()
