# %%
from binary_param import linear, constant
import pandas as pd
from R32_bmimBF4_PR import configuration

# %%
# binary_params_peng('R32IL298.csv', configuration, 'R32', 'bmimPF6', "x_R32", "x_bmimPF6", 
#     init_temp = 323.15, init_press = 399800, init_x_c1 = 0.5, init_x_c2 = 0.5,
#     init_kappa_2_1 = -0.05, init_kappa_1_2 = -0.03, eps = 0.1, scaling_fac = 1e-9)

# %%
data = pd.read_csv('R32_bmimBF4.csv')
print(data)
# 283
data_283= data[(data.temperature > 282) & (data.temperature< 284)]

# 298
data_298 = data[(data.temperature > 297) & (data.temperature< 299)]
data_298 = data_298.reset_index(drop=True)

# 323
data_323 = data[(data.temperature > 322) & (data.temperature< 324)]
data_323 = data_323.reset_index(drop=True)

# 323
data_348 = data[(data.temperature > 347) & (data.temperature< 349)]
data_348 = data_348.reset_index(drop=True)
# Out:
#     temperature  pressure  x_R32  x_bmimBF4
# 0         283.1     10000  0.009      0.991
# 1         283.1     99800  0.099      0.901
# 2         283.2    249900  0.241      0.759
# 3         283.2    399500  0.374      0.626
# 4         283.0    549900  0.501      0.499
# 5         283.1    699900  0.627      0.373
# 6         283.1    849700  0.759      0.241
# 7         298.2      9700  0.007      0.993
# 8         298.2     99700  0.071      0.929
# 9         298.2    249600  0.175      0.825
# 10        298.2    399900  0.272      0.728
# 11        298.2    549800  0.359      0.641
# 12        298.2    699600  0.438      0.562
# 13        298.2    849500  0.515      0.485
# 14        298.2    999900  0.588      0.412
# 15        323.2      9800  0.004      0.996
# 16        323.1     99600  0.040      0.960
# 17        323.2    249700  0.099      0.901
# 18        323.2    399600  0.154      0.846
# 19        323.1    549600  0.206      0.794
# 20        323.1    699500  0.255      0.745
# 21        323.0    849900  0.301      0.699
# 22        323.2    999600  0.345      0.655
# 23        348.2      9700  0.002      0.998
# 24        348.1     99600  0.024      0.976
# 25        348.1    249500  0.058      0.942
# 26        348.2    399500  0.092      0.908
# 27        348.1    549500  0.125      0.875
# 28        348.2    699600  0.156      0.844
# 29        348.1    849600  0.186      0.814
# 30        348.1    999900  0.214      0.786

# %%
linear(data, configuration, 'R32', 'bmimBF4', "x_R32", "x_bmimBF4",
    init_temp =  283.1, init_press =   399300 , init_x_c1 =    0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 1.2354, init_kappa_1_2A = 0.1695,
    init_kappa_2_1B = -1.387, init_kappa_1_2B = -0.2075, eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2021-10-18 13:29:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:36 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:37 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2021-10-18 13:29:38 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2021-10-18 13:29:39 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:40 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:41 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:42 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:44 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2021-10-18 13:29:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:46 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:50 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:53 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:29:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.12.13: bound_relax_factor=0
# honor_original_bounds=no
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1294
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1643
#
# Total number of variables............................:      496
#                      variables with only lower bounds:      186
#                 variables with lower and upper bounds:      248
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      492
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.35e+00 2.84e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.0690724e-08 8.34e+00 1.22e+02  -1.0 3.66e+04    -  6.47e-04 5.73e-04h  1
#    2  6.7920811e-02 1.29e+01 3.19e+05  -1.0 4.28e+04    -  5.54e-04 4.95e-01h  2
#    3  8.8284449e-02 9.22e+00 1.69e+05  -1.0 2.05e+04    -  1.22e-03 4.95e-01h  2
#    4  1.8693084e-01 7.70e+00 6.52e+04  -1.0 2.88e+04    -  5.71e-02 4.95e-01h  2
#    5  2.3313908e-01 6.24e+00 4.83e+04  -1.0 2.04e+04    -  4.26e-01 2.47e-01h  3
-01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 35
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1456160824161546e-01    1.1456160824161546e-01
# Dual infeasibility......:   4.2500238543577580e-09    4.2500238543577580e-09
# Constraint violation....:   1.6194801055746666e-10    1.6194801055746666e-10
# Complementarity.........:   2.5265777326904539e-09    2.5265777326904539e-09
# Overall NLP error.......:   2.0715912994847444e-10    4.2500238543577580e-09
#
#
# Number of objective function evaluations             = 124
# Number of objective gradient evaluations             = 36
# Number of equality constraint evaluations            = 124
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 36
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 35
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.071
# Total CPU secs in NLP function evaluations           =      1.422
#
# EXIT: Optimal Solution Found.
# The SSE at the optimal solution is 0.114562
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa_A[R32,bmimBF4] = 0.0008075530598152958
# fs.properties.PR_kappa_A[bmimBF4,R32] = 0.01571075807561415
# fs.properties.PR_kappa_B[R32,bmimBF4] = -0.03428462764597864
# fs.properties.PR_kappa_B[bmimBF4,R32] = -0.068962084853002
# covariance_matrix                                        fs.properties.PR_kappa_A[R32,bmimBF4]  \
# fs.properties.PR_kappa_A[R32,bmimBF4]                               0.000100
# fs.properties.PR_kappa_A[bmimBF4,R32]                               0.000845
# fs.properties.PR_kappa_B[R32,bmimBF4]                              -0.000092
# fs.properties.PR_kappa_B[bmimBF4,R32]                              -0.000795
#
#                                        fs.properties.PR_kappa_A[bmimBF4,R32]  \
# fs.properties.PR_kappa_A[R32,bmimBF4]                               0.000845
# fs.properties.PR_kappa_A[bmimBF4,R32]                               0.007144
# fs.properties.PR_kappa_B[R32,bmimBF4]                              -0.000776
# fs.properties.PR_kappa_B[bmimBF4,R32]                              -0.006718
#
#                                        fs.properties.PR_kappa_B[R32,bmimBF4]  \
# fs.properties.PR_kappa_A[R32,bmimBF4]                              -0.000092
# fs.properties.PR_kappa_A[bmimBF4,R32]                              -0.000776
# fs.properties.PR_kappa_B[R32,bmimBF4]                               0.000085
# fs.properties.PR_kappa_B[bmimBF4,R32]                               0.000734
#
#                                        fs.properties.PR_kappa_B[bmimBF4,R32]
# fs.properties.PR_kappa_A[R32,bmimBF4]                              -0.000795
# fs.properties.PR_kappa_A[bmimBF4,R32]                              -0.006718
# fs.properties.PR_kappa_B[R32,bmimBF4]                               0.000734
# fs.properties.PR_kappa_B[bmimBF4,R32]                               0.006386

# %%
constant(data, configuration, 'R32', 'bmimBF4', "x_R32", "x_bmimBF4",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 0.1, init_kappa_1_2A = 0.10,
    eps = 0.1, scaling_fac = 1e4)
# Out:
# 2021-10-18 13:30:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:11 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2021-10-18 13:30:12 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2021-10-18 13:30:13 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2021-10-18 13:30:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:15 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:16 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:18 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2021-10-18 13:30:19 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2021-10-18 13:30:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:21 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:23 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2021-10-18 13:30:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.12.13: bound_relax_factor=0
# honor_original_bounds=no
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1050
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1054
#
# Total number of variables............................:      434
#                      variables with only lower bounds:      186
#                 variables with lower and upper bounds:      186
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      432
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.44e+00 2.84e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.3271959e+01 1.87e-01 6.17e+04  -1.0 1.00e+05    -  6.61e-01 9.90e-01h  1
#    2  3.3200265e+01 9.94e-03 6.49e+02  -1.0 8.33e+04    -  3.41e-01 9.90e-01f  1
#    3  3.2700572e+01 1.33e-04 8.20e+02  -1.0 4.42e+03    -  9.82e-01 9.90e-01h  1
#    4  3.1919481e+01 1.33e-06 5.44e+04  -1.0 5.28e+03    -  9.85e-01 9.90e-01H  1
#    5  3.1914953e+01 1.32e-06 9.82e+08  -1.0 1.12e+04    -  9.86e-01 3.87e-03h  9
#    6  3.1910326e+01 1.32e-06 1.97e+09  -1.0 1.18e+04    -  9.90e-01 3.87e-03h  9
#    7  3.1905733e+01 1.31e-06 2.96e+09  -1.0 1.18e+04    -  9.94e-01 3.87e-03h  9
#    8  3.1901176e+01 1.31e-06 3.95e+09  -1.0 1.17e+04    -  1.00e+00 3.87e-03h  9
#    9  3.1896654e+01 1.30e-06 4.95e+09  -1.0 1.17e+04    -  1.00e+00 3.87e-03h  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.1892168e+01 1.30e-06 5.95e+09  -1.0 1.16e+04    -  1.00e+00 3.87e-03h  9
#   11  3.1887717e+01 1.29e-06 6.94e+09  -1.0 1.16e+04    -  1.00e+00 3.87e-03h  9
#   12  3.1883301e+01 1.29e-06 7.94e+09  -1.0 1.15e+04    -  1.00e+00 3.87e-03h  9
#   13  3.1878920e+01 1.28e-06 8.94e+09  -1.0 1.15e+04    -  1.00e+00 3.87e-03h  9
#   14  3.1874573e+01 1.28e-06 9.93e+09  -1.0 1.14e+04    -  1.00e+00 3.87e-03h  9
#   15  3.1326383e+01 9.68e-05 1.10e+08  -1.0 1.14e+04    -  1.00e+00 9.90e-01w  1
#   16  3.1326805e+01 9.74e-07 1.04e+09  -1.0 1.01e+02    -  1.00e+00 9.90e-01w  1
#   17  3.1326810e+01 9.74e-09 1.04e+11  -1.0 1.01e+00    -  1.00e+00 9.90e-01h  1
# In iteration 17, 31 Slacks too small, adjusting variable bounds
#   18  3.1326810e+01 9.75e-11 1.04e+13  -1.0 1.01e-02    -  1.00e+00 9.90e-01h  1
#   19  3.1326810e+01 5.79e-11 1.00e-06  -1.0 9.79e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.1326568e+01 2.15e-11 1.15e+08  -9.0 1.56e+02    -  1.00e+00 1.00e+00F  1
#   21  3.1326568e+01 2.30e-11 8.96e-09  -9.0 2.54e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 21
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.1326568129995788e+01    3.1326568129995788e+01
# Dual infeasibility......:   8.9639797806739807e-09    8.9639797806739807e-09
# Constraint violation....:   2.2970958468704339e-11    2.2970958468704339e-11
# Complementarity.........:   9.0966311773436314e-10    9.0966311773436314e-10
# Overall NLP error.......:   1.4959466045442061e-10    8.9639797806739807e-09
#
#
# Number of objective function evaluations             = 134
# Number of objective gradient evaluations             = 22
# Number of equality constraint evaluations            = 134
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 22
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 21
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.039
# Total CPU secs in NLP function evaluations           =      1.186
#
# EXIT: Optimal Solution Found.
# The SSE at the optimal solution is 31.326568
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa_A[bmimBF4,R32] = -0.07533220872663852
# fs.properties.PR_kappa_A[R32,bmimBF4] = -0.03569681435866255
# covariance_matrix                                        fs.properties.PR_kappa_A[bmimBF4,R32]  \
# fs.properties.PR_kappa_A[bmimBF4,R32]                               0.000723
# fs.properties.PR_kappa_A[R32,bmimBF4]                               0.000026
#
#                                        fs.properties.PR_kappa_A[R32,bmimBF4]
# fs.properties.PR_kappa_A[bmimBF4,R32]                               0.000026
# fs.properties.PR_kappa_A[R32,bmimBF4]                               0.000002
# c:\users\agarc\anaconda32\envs\kappa\lib\site-packages\pyomo\contrib\interior_point\interface.py:418: RuntimeWarning: divide by zero encountered in true_divide
#   data = (duals_primals_lb/(primals - self._nlp.primals_lb()) +
