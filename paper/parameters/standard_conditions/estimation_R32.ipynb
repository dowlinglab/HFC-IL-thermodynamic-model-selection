# %%
from binary_param import linear, constant
import pandas as pd
from R32_bmimPF6_PR import configuration

# %%
# binary_params_peng('R32IL298.csv', configuration, 'R32', 'bmimPF6', "x_R32", "x_bmimPF6", 
#     init_temp = 323.15, init_press = 399800, init_x_c1 = 0.5, init_x_c2 = 0.5,
#     init_kappa_2_1 = -0.05, init_kappa_1_2 = -0.03, eps = 0.1, scaling_fac = 1e-9)

# %%
data = pd.read_csv('R32IL.csv')
print(data)
# 283
data_283= data[(data.temperature > 282) & (data.temperature< 284)]

# 298
data_298 = data[(data.temperature > 297) & (data.temperature< 299)]
data_298 = data_298.reset_index(drop=True)

# 323
data_323 = data[(data.temperature > 322) & (data.temperature< 324)]
data_323 = data_323.reset_index(drop=True)

# 323
data_348 = data[(data.temperature > 347) & (data.temperature< 349)]
data_348 = data_348.reset_index(drop=True)
# Out:
#     temperature  pressure   x_R32  x_bmimPF6
# 0         283.2      9800  0.0206     0.9794
# 1         283.2     99600  0.1060     0.8940
# 2         283.2    249700  0.2710     0.7290
# 3         283.2    399600  0.4280     0.5720
# 4         283.2    549700  0.5580     0.4420
# 5         283.2    699600  0.6500     0.3500
# 6         283.2    849500  0.8150     0.1850
# 7         298.1      9700  0.0180     0.9820
# 8         298.2     99500  0.0760     0.9240
# 9         298.2    249700  0.1900     0.8100
# 10        298.2    399800  0.2970     0.7030
# 11        298.1    549700  0.3900     0.6100
# 12        298.1    699500  0.4750     0.5250
# 13        298.2    850100  0.5520     0.4480
# 14        298.1    999900  0.6280     0.3720
# 15        322.8      9900  0.0060     0.9940
# 16        323.1     99500  0.0470     0.9530
# 17        323.1    249600  0.1130     0.8870
# 18        323.1    399500  0.1740     0.8260
# 19        323.1    549700  0.2310     0.7690
# 20        323.1    699600  0.2850     0.7150
# 21        323.2    849600  0.3350     0.6650
# 22        323.2    999600  0.3820     0.6180
# 23        348.2      9900  0.0030     0.9970
# 24        348.2     99700  0.0290     0.9710
# 25        348.2    249500  0.0700     0.9300
# 26        348.2    399400  0.1090     0.8910
# 27        348.1    549800  0.1460     0.8540
# 28        348.1    699700  0.1820     0.8180
# 29        348.2    849600  0.2140     0.7860
# 30        348.2    999900  0.2480     0.7520

# %%
linear(data, configuration, 'R32', 'bmimPF6', "x_R32", "x_bmimPF6",
    init_temp =  283.1, init_press =   399300 , init_x_c1 =    0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 1.2354, init_kappa_1_2A = 0.1695,
    init_kappa_2_1B = -1.387, init_kappa_1_2B = -0.2075, eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-20 14:43:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:00 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:04 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-20 14:43:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:15 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-20 14:43:17 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:20 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:22 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:24 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:25 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:26 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:27 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:28 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:29 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:30 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:31 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:32 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:33 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:34 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:35 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1294
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1643
#
# Total number of variables............................:      496
#                      variables with only lower bounds:      186
#                 variables with lower and upper bounds:      248
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      492
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.05e+01 2.84e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.8645145e-05 1.03e+01 2.63e+01  -1.0 4.76e+04    -  5.30e-01 1.96e-02h  1
#    2  2.0283143e-01 1.34e+01 1.42e+05  -1.0 4.66e+04    -  9.69e-02 9.90e-01h  1
#    3  1.7917232e-01 1.22e+00 2.70e+04  -1.0 5.80e+03    -  2.75e-01 9.90e-01h  1
#    4  1.7963416e-01 4.03e-01 7.51e+04  -1.0 5.75e+02    -  2.99e-01 1.00e+00h  1
#    5  1.7960172e-01 8.95e-02 3.02e+05  -1.0 3.06e+02    -  9.70e-01 1.00e+00h  1
#    6  1.7934312e-01 6.18e-03 3.92e+03  -1.0 8.16e+02    -  9.89e-01 1.00e+00h  1
#    7  1.8380293e-01 8.27e-02 3.95e+02  -1.0 2.45e+04    -  9.64e-01 1.00e+00f  1
#    8  5.4742802e-01 1.99e-01 2.89e+02  -1.0 6.94e+04    -  1.59e-01 1.00e+00f  1
#    9  5.5248161e-01 7.31e-02 2.79e+02  -1.0 9.87e+02  -4.0 9.90e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.5248030e-01 5.26e-03 4.63e+05  -2.5 4.18e+00  -4.5 9.52e-01 1.00e+00h  1
#   11  1.9721690e-01 1.76e-01 7.40e+02  -2.5 6.52e+04    -  9.98e-01 1.00e+00f  1
#   12  1.8002748e-01 1.02e-02 6.89e-01  -2.5 1.63e+04    -  1.00e+00 1.00e+00h  1
#   13  1.6427865e-01 9.28e-01 8.49e+04  -3.8 5.50e+03    -  8.30e-01 5.13e-01h  1
#   14  1.6593717e-01 1.51e-01 8.21e-02  -3.8 1.61e+03    -  1.00e+00 1.00e+00h  1
#   15  1.6612156e-01 1.53e-02 3.30e-02  -3.8 8.08e+01    -  1.00e+00 1.00e+00h  1
#   16  1.6604823e-01 2.46e-04 8.17e-04  -3.8 1.95e+01    -  1.00e+00 1.00e+00h  1
#   17  1.6587911e-01 6.04e-04 9.45e+02  -5.7 1.31e+02    -  1.00e+00 9.36e-01h  1
#   18  1.6587980e-01 6.31e-07 3.61e-06  -5.7 1.25e+01    -  1.00e+00 1.00e+00h  1
#   19  1.6587794e-01 8.04e-08 5.61e-07  -8.6 1.70e+00    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.6587794e-01 1.62e-12 1.45e-13  -8.6 6.61e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 20
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.6587794221613167e-01    1.6587794221613167e-01
# Dual infeasibility......:   1.4521717162097048e-13    1.4521717162097048e-13
# Constraint violation....:   1.6151524562246777e-12    1.6151524562246777e-12
# Complementarity.........:   2.5059046602106956e-09    2.5059046602106956e-09
# Overall NLP error.......:   2.5059046602106956e-09    2.5059046602106956e-09
#
#
# Number of objective function evaluations             = 21
# Number of objective gradient evaluations             = 21
# Number of equality constraint evaluations            = 21
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 21
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 20
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.046
# Total CPU secs in NLP function evaluations           =      0.608
#
# EXIT: Optimal Solution Found.
# The SSE at the optimal solution is 0.165878
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa_A[R32,bmimPF6] = 0.027002707108712335
# fs.properties.PR_kappa_A[bmimPF6,R32] = 0.26803963445553125
# fs.properties.PR_kappa_B[R32,bmimPF6] = -0.04879136133838398
# fs.properties.PR_kappa_B[bmimPF6,R32] = -0.3153993381343163

# %%
constant(data, configuration, 'R32', 'bmimPF6', "x_R32", "x_bmimPF6",
    init_temp =  283.1, init_press = 399300 , init_x_c1 = 0.448, init_x_c2 = 0.552,
    init_kappa_2_1A = 0.1, init_kappa_1_2A = 0.10,
    eps = 0.1, scaling_fac = 1e-9)
# Out:
# 2022-01-20 14:43:43 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:44 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:45 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:47 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:48 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:49 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:50 [INFO] idaes.init.fs.state_block: Property package initialization: infeasible - Converged to a locally infeasible point. Problem may be infeasible..
# 2022-01-20 14:43:51 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:52 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:54 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:55 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:56 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:58 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:43:59 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:01 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:02 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:03 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:04 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:05 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:06 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:07 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:08 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:09 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:10 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:11 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:12 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:13 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# 2022-01-20 14:44:14 [INFO] idaes.init.fs.state_block: Property package initialization: optimal - Optimal Solution Found.
# Ipopt 3.13.2:
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1050
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1054
#
# Total number of variables............................:      434
#                      variables with only lower bounds:      186
#                 variables with lower and upper bounds:      186
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      432
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.92e+00 2.84e-14  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.5762758e-01 2.42e-01 4.99e+03  -1.0 6.45e+04    -  2.25e-02 9.90e-01h  1
#    2  2.8360810e-01 2.50e-02 1.85e+02  -1.0 4.07e+03    -  8.05e-01 9.90e-01h  1
#    3  2.8483456e-01 3.01e-04 3.34e+03  -1.0 5.37e+02    -  9.67e-01 1.00e+00h  1
#    4  2.8445849e-01 1.00e-07 9.97e+04  -1.0 1.20e+02    -  9.90e-01 1.00e+00h  1
#    5  2.6880994e-01 4.84e-05 1.35e+03  -1.0 6.87e+03    -  9.86e-01 1.00e+00f  1
#    6  2.6596541e-01 3.86e-05 7.98e+04  -1.7 7.36e+03    -  9.90e-01 1.00e+00h  1
#    7  2.6614400e-01 1.80e-08 6.21e+02  -1.7 1.55e+02    -  9.92e-01 1.00e+00h  1
#    8  2.6614407e-01 4.76e-12 2.00e-07  -1.7 5.10e-02    -  1.00e+00 1.00e+00h  1
#    9  2.6573322e-01 2.24e-06 9.06e+02  -8.6 1.27e+03    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.6573595e-01 8.13e-12 4.17e-11  -8.6 1.69e+00    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.6573595273532752e-01    2.6573595273532752e-01
# Dual infeasibility......:   4.1684187807334506e-11    4.1684187807334506e-11
# Constraint violation....:   8.1312734323546465e-12    8.1312734323546465e-12
# Complementarity.........:   2.6099482226983570e-09    2.6099482226983570e-09
# Overall NLP error.......:   2.6099482226983570e-09    2.6099482226983570e-09
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.015
# Total CPU secs in NLP function evaluations           =      0.239
#
# EXIT: Optimal Solution Found.
# The SSE at the optimal solution is 0.265736
#
# The values for the parameters are as follows:
# fs.properties.PR_kappa_A[bmimPF6,R32] = -0.07040532395154804
# fs.properties.PR_kappa_A[R32,bmimPF6] = -0.026088350772152862
