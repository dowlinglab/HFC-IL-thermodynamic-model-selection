# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
import mpl_toolkits.mplot3d
import pandas as pd
import random as random

import pytest

# %%
data = pd.read_csv('sens229803.csv')

# %%
# Import numpy libabrary 
import numpy as np

# %%
plt.scatter(data['1'], data['2'], c=data['3'])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))

ax.set_title("Pressure",fontsize=20)
cntr = ax.tricontourf(data['1'], data['2'], data['3'], cmap='jet')
contours = ax.tricontour(data['1'], data['2'], data['3'], colors='black')
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
ax.clabel(contours, inline=True, fontsize=18, fmt='%1.0f')
# Out:
# <a list of 7 text.Text objects>

# %%
data = pd.read_csv('sens2.csv')
print(data.head())
is_298 =  data['4'] >= 298 
is_299 =  data['4'] <= 299
data_298 = data[is_298]
data_299 = data_298[is_299]
print(data_299)

is_390 =  data_299['5'] == 0.390
data_390 = data_299[is_390]
print(data_390)
# Out:
#    Unnamed: 0    1         2              3      4       5
# 0           0 -0.5 -0.500000     405.536774  348.2  0.0030
# 1           1 -0.5 -0.388889  344538.703700  283.2  0.8150
# 2           2 -0.5 -0.388889     797.920422  322.8  0.0060
# 3           3 -0.5 -0.388889     930.820015  348.2  0.0030
# 4           4 -0.5 -0.277778    1530.566939  283.2  0.0206
#      Unnamed: 0    1         2             3      4      5
# 6             6 -0.5 -0.277778  2.475727e+03  298.1  0.018
# 12           12 -0.5 -0.166667  6.704454e+03  298.1  0.018
# 13           13 -0.5 -0.166667  1.530345e+05  298.2  0.297
# 14           14 -0.5 -0.166667  2.311427e+05  298.1  0.390
# 15           15 -0.5 -0.166667  4.497355e+05  298.2  0.552
# ..          ...  ...       ...           ...    ...    ...
# 942         942  0.5  0.166667  1.321923e+05  298.1  0.018
# 943         943  0.5  0.166667  5.563989e+05  298.2  0.076
# 944         944  0.5  0.166667  1.356734e+06  298.2  0.190
# ...

# %%
fig, ax = plt.subplots(figsize=(5,5))

ax.set_title("Pressure",fontsize=20)
cntr = ax.tricontourf(data_390['1'], data_390['2'], data_390['3'], cmap='jet')
contours = ax.tricontour(data_390['1'], data_390['2'], data_390['3'], colors='black')
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
ax.clabel(contours, inline=True, fontsize=18, fmt='%1.0f')
plt.show()

# %%
data = pd.read_csv('sens2.csv')

is_298 =  data['4'] >= 298 
is_299 =  data['4'] <= 299
data_298 = data[is_298]
data_299 = data_298[is_299]

is_390 =  data_299['5'] == 0.475
data_390 = data_299[is_390]


fig, ax = plt.subplots(figsize=(5,5))

ax.set_title("Pressure",fontsize=20)
cntr = ax.tricontourf(data_390['1'], data_390['2'], data_390['3'], cmap='jet')
contours = ax.tricontour(data_390['1'], data_390['2'], data_390['3'], colors='black')
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
ax.clabel(contours, inline=True, fontsize=18, fmt='%1.0f')
plt.show()
# Out:
# c:\users\agarc\anaconda32\envs\txy2\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
data = pd.read_csv('sens2.csv')

is_298 =  data['4'] >= 298 
is_299 =  data['4'] <= 299
data_298 = data[is_298]
data_299 = data_298[is_299]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = data_299['1'] 
y = data_299['2']
z = data_299['5']

ax.scatter(x, y, z, c=data_299['3'], marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.view_init(65, 120)
plt.show()
# Out:
# c:\users\agarc\anaconda32\envs\txy2\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
data = pd.read_csv('sens2.csv')
for i in (data['1'].unique()):
    print(i)
# Out:
# -0.5
# -0.388888889
# -0.277777778
# -0.166666667
# -0.055555556
# 0.055555556
# 0.166666667
# 0.277777778
# 0.388888889
# 0.5
